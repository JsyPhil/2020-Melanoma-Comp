# %% [markdown]
# ## Cross Validation Workflow Notebook v3

# %% [markdown]
# #### Sources of information, code and discussions

# %% [markdown]
# 1. This notebook follows the 5 step process presented in the Chris Deotte "How to compete with GPUs Workshop" [here][1].
# 2. Triple stratified KFold TFRecords used for image data is explained [here][2].
# 3. Some code sections have been reused from AgentAuers' notebook [here][3]
# 4. The advantage of using different input sizes is discussed [here][4]
# 5. Use external data by changing the variables `INC2019` and `INC2018`.These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][5]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [4]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147
# [5]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %% [markdown]
# ####  Initiatialise environment and import necessary libraries

# %% [markdown]
# # Initialize Environment

# %%
# Use if running in Kaggle environment
#!pip install -q efficientnet >> /dev/null

# %%
# import KaggleDatasets if running in Kaggle environment
#from kaggle_datasets import KaggleDatasets

import os, re, math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K

import efficientnet.tfkeras as efn

from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score 
from sklearn.utils import class_weight

# %% [markdown]
# ## Configuration
#
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 for conistent number of train and validation samples across folds
# * IMG_SIZES - These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter. Consider early stopping in Callbacks.
# * EFF_NETS - These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %% [markdown]
# Image sizes used in the Efficientnet model:
#
# - efficientnet-b0-224 -cv train with 192
# - efficientnet-b1-240 -cv train with 256
# - efficientnet-b2-260 -cv train with 256
# - efficientnet-b3-300 -cv train with 384
# - efficientnet-b4-380 -cv train with 384
# - efficientnet-b5-456 -cv train with 512
# - efficientnet-b6-528 -cv train with 512
# - efficientnet-b7-600 -cv train with 768
#
# Better to train with a larger size and let the model scale down rather than up.

# %%
ENV = "LOCAL" #or "KAGGLE"

# DEFAULT TO TPU TO ENSURE KAGGLE TPU COMPATIABILITY
# https://www.kaggle.com/docs/tpu
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 45

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 
IMG_SIZES = [256]*FOLDS

# META DATA? YES=1 NO=0
META = 1

# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0]*FOLDS
INC2018 = [1]*FOLDS

# UPSAMPLE MALIGNANT
M1 = [1]*FOLDS #2020 malig
M2 = [1]*FOLDS #ISIC malig
M3 = [1]*FOLDS #2019 good malig
M4 = [1]*FOLDS #2018 2017 malig - Malignant only images from HAM10000

# COARSE DROPOUT
DROP_FREQ = [0]*FOLDS # between 0 and 1
DROP_CT = [0]*FOLDS # may slow training if CT>16
DROP_SIZE = [0]*FOLDS # between 0 and 1

# BATCH SIZE AND EPOCHS
# TRY 8, 16, 32, 64, 128, 256. REDUCE IF OOM ERROR, HIGHER FOR TPUS
BATCH_SIZES = [32]*FOLDS
EPOCHS = [50]*FOLDS

#EARLY TOPPING
EARLY_STOPPING = 0 # Yes:1, No:0
PATIENCE = 10 

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [1]*FOLDS

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 25

# %% [markdown]
# #### Configure environment to use TPUs, Multiple GPUs, Single GPU or just CPU

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and GPU")
    

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    if len(tf.config.experimental.list_physical_devices('GPU')) > 1:
        strategy = tf.distribute.MirroredStrategy()
    else:
        strategy = tf.distribute.get_strategy()
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync

print(f'REPLICAS: {REPLICAS}')
# Out:
# connecting to TPU...
# Could not connect to TPU
# Using default strategy for CPU and GPU
# Num GPUs Available:  2
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# REPLICAS: 2

# %% [markdown]
# ### Step 1: Preprocess and file handling
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section.

# %%
# Load file locations
if ENV == 'KAGGLE':
    #Use GCS if running in Kaggle environment
    PATH = [None]*FOLDS; PATH2 = [None]*FOLDS; PATH3 = [None]*FOLDS
    for i,k in enumerate(IMG_SIZES):
        PATH[i] = KaggleDatasets().get_gcs_path('melanoma-%ix%i'%(k,k))
        PATH2[i] = KaggleDatasets().get_gcs_path('isic2019-%ix%i'%(k,k))
        PATH3[i] = KaggleDatasets().get_gcs_path('malignant-v2-%ix%i'%(k,k))
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))
       
if ENV == 'LOCAL':  
    # Use LDS if running in local environment
    PATH = [None]*FOLDS; PATH2 = [None]*FOLDS; PATH3 = [None]*FOLDS
    for i,k in enumerate(IMG_SIZES):
        PATH[i] = f"./siim-isic-melanoma-classification/tfrecords{k}"
        PATH2[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Ext"
        PATH3[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Mal"
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))

# %%
# Save file locations
if ENV == 'KAGGLE':
    LOG_PATH = ''
    CV_OOF_PREDS_PATH = ''
    CV_TEST_PREDS_PATH = ''
    CV_FOLDS_PATH = ''

if ENV == 'LOCAL':
    LOG_PATH = './logs/'
    CV_OOF_PREDS_PATH = './cv_oof_preds/'
    CV_TEST_PREDS_PATH = './cv_test_preds/'
    CV_FOLDS_PATH = './cv_folds/'

# %%
# File handling functions
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']

def read_meta_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge'], example['target']

def read_meta_tfrecord_test(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge']

def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
# Function to stream datasets into model when training, validating and predicting
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256,
                droprate=0, dropct=0, dropsize=0):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO)      
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim,
                                               droprate=droprate, dropct=dropct, dropsize=dropsize),
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %%
# Function to stream datasets into model when training, validating and predicting
column_names = ['image_name', 'sex', 'age_approx', 'anatom', 'target']
column_names_test = ['image_name', 'sex', 'age_approx', 'anatom']

def get_meta(files, batch_size=16, test=0):
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    if test:
        ds = ds.map(lambda example: read_meta_tfrecord_test(example), num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_meta_tfrecord(example), num_parallel_calls=AUTO)      
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
        
    return ds

def meta_unbatch(files, test=0):
    if test:
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy()]
                for img_name, sex, age, anatomy in iter(files.unbatch())])
        meta_df = pd.DataFrame(data = meta_np, columns=column_names_test)

    else:        
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy(),
                  target.numpy()] 
                for img_name, sex, age, anatomy, target in iter(files.unbatch())])
        
        meta_df = pd.DataFrame(data = meta_np, columns=column_names)
        meta_df = meta_df.astype({"target": int})
    return meta_df

# %% [markdown]
# ### Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation. This notebook also uses horizontal flip, saturation, contrast, brightness augmentation similar to last years winner.

# %%
# Assign variables
ROT_ = 180.0
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def dropout(image, DIM=256, PROBABILITY = 0.75, CT = 8, SZ = 0.2):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image with CT squares of side size SZ*DIM removed
    
    # DO DROPOUT WITH PROBABILITY DEFINED ABOVE
    P = tf.cast( tf.random.uniform([],0,1)<PROBABILITY, tf.int32)
    if (P==0)|(CT==0)|(SZ==0): return image
    
    for k in range(CT):
        # CHOOSE RANDOM LOCATION
        x = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        y = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        # COMPUTE SQUARE 
        WIDTH = tf.cast( SZ*DIM,tf.int32) * P
        ya = tf.math.maximum(0,y-WIDTH//2)
        yb = tf.math.minimum(DIM,y+WIDTH//2)
        xa = tf.math.maximum(0,x-WIDTH//2)
        xb = tf.math.minimum(DIM,x+WIDTH//2)
        # DROPOUT IMAGE
        one = image[ya:yb,0:xa,:]
        two = tf.zeros([yb-ya,xb-xa,3]) 
        three = image[ya:yb,xb:DIM,:]
        middle = tf.concat([one,two,three],axis=1)
        image = tf.concat([image[0:ya,:,:],middle,image[yb:DIM,:,:]],axis=0)
            
    # RESHAPE HACK SO TPU COMPILER KNOWS SHAPE OF OUTPUT TENSOR 
    image = tf.reshape(image,[DIM,DIM,3])
    return image

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

def prepare_image(img, augment=True, dim=256, droprate=0, dropct=0, dropsize=0):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        if (droprate!=0)&(dropct!=0)&(dropsize!=0): 
            img = dropout(img, DIM=dim, PROBABILITY=droprate, CT=dropct, SZ=dropsize)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

# %% [markdown]
# ### Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN. Also consider different models to provide diversity of predictions which may benefit the final ensemble.

# %%
EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7]

def build_model(dim=128, ef=0, v=0):
    inputs = tf.keras.layers.Input(shape=(dim,dim,3))
    
    base = EFNS[ef](input_shape=(dim,dim,3),weights='noisy-student',include_top=False)
    
    x = base(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=inputs,outputs=x)
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    
    if v:
        model.summary()
    
    return model

# Visualise model in use
build_model(dim=IMG_SIZES[0],ef=EFF_NETS[0],v=1)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnet-b1 (Functional) (None, 8, 8, 1280)        6575232
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1281
# =================================================================
# Total params: 6,576,513
# Trainable params: 6,514,465
# Non-trainable params: 62,048
# _________________________________________________________________

# %%
# META DATA FUNCTION

# Function to get meta data
def meta_model(meta_train, meta_val):
    L = 15
    feat = ['sex','age_approx','anatom']
    M = meta_train.target.mean()
    te = meta_train.groupby(feat)['target'].agg(['mean','count']).reset_index()
    te['ll'] = ((te['mean']*te['count'])+(M*L))/(te['count']+L)
    del te['mean'], te['count']
    meta_val = meta_val.merge( te, on=feat, how='left' )
    meta_val['ll'] = meta_val['ll'].fillna(M)
    return meta_val

# %% [markdown]
# ### Step 4: Training and Cross Validation

# %% [markdown]
# #### Training Schedule
# Thism is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
TS_CFG = dict(
    lr_start   = 0.000006, 
    lr_max     = 0.00000145 * REPLICAS * BATCH_SIZES[0],
    lr_min     = 0.000001,
    lr_ramp_ep = 5,
    lr_sus_ep  = 0,
    lr_decay   = 0.85
    )

# %%
def get_lr_callback(ts_cfg, batch_size=8):
    lr_start   = ts_cfg['lr_start']
    lr_max     = ts_cfg['lr_max']
    lr_min     = ts_cfg['lr_min']
    lr_ramp_ep = ts_cfg['lr_ramp_ep']
    lr_sus_ep  = ts_cfg['lr_sus_ep']
    lr_decay   = ts_cfg['lr_decay']
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    
    return lr_callback

# %% [markdown]
# #### Visualise Training Schedule

# %%
# Quick test and visualisation of learning rate schedule
# Important not to have a high learning rate which would destroy the pre-trained parameters
lr_start   = TS_CFG['lr_start']
lr_max     = TS_CFG['lr_max']
lr_min     = TS_CFG['lr_min']
lr_ramp_ep = TS_CFG['lr_ramp_ep']
lr_sus_ep  = TS_CFG['lr_sus_ep']
lr_decay   = TS_CFG['lr_decay']

def lrfn_sched(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

# Visualise learning rate schedule
rng = [i for i in range(20)]
y = [lrfn_sched(x) for x in rng]
plt.plot(rng, y)
plt.xlabel('epoch', size=14); plt.ylabel('learning rate', size=14)
plt.title('Training Schedule', size=16); plt.show()

# %% [markdown]
# #### Class Imbalance Analysis

# %%
# Analyze class imbalance in the targets
# Number of positive samples in training data: 470 (1.77% of total 33126)
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / (33126-470))*(33126)/2.0 
weight_for_1 = (1 / 470)*(33126)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.51
# Weight for class 1: 35.24

# %% [markdown]
# #### Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []
oof_tar = []
oof_val = []
oof_names = []
oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_meta_ls = np.zeros((count_data_items(files_test),1))

best_val_auc_ls = []
best_epoch_val_auc_ls = []

best_val_loss_ls = []
best_epoch_val_loss_ls = []

best_meta_wgts = []

#TESTING ONLY
loops = 0
max_loops = FOLDS #Use FOLDS or a number less than FOLDS if testing

#FITTING LOOP    
for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25)
    print('#### FOLD',fold+1)
    print('#'*25)
    print('#### Using the following TFRecords:')
    print(idxT,idxV)
    print(f'#### Image Size {IMG_SIZES[fold]} with EfficientNet B{EFF_NETS[fold]} and batch_size {BATCH_SIZES[fold]*REPLICAS}')
    print(f'#### DropoutFreq {DROP_FREQ[fold]} Count{DROP_CT[fold]} Size {DROP_SIZE[fold]}')
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    if M1[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT])
        print('#### Upsample MALIG-1 data (2020 comp)')
    if M2[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT+15])
        print('#### Upsample MALIG-2 data (ISIC website)')
    if M3[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1+30])
        print('#### Upsample MALIG-3 data (2019 comp)')
    if M4[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+30])
        print('#### Upsample MALIG-4 data (2018 2017 comp)')        
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(PATH[fold] + '/test*.tfrec')))
    
    # DETERMINE CLASS WEIGHTS FROM TRAINING DATASET
    # Analyze class imbalance in the targets
    # Scaling by total/2 helps keep the loss to a similar magnitude.
    # The sum of the weights of all examples stays the same.
    ft = get_dataset(files_train, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    ott = np.array([target.numpy() for img, target in iter(ft.unbatch())])
    tot = len(ott)
    counts = np.bincount(ott[:])
    
    weight_for_0 = (1 / counts[0])*(tot)/2.0 
    weight_for_1 = (1 / counts[1])*(tot)/2.0
    class_weight = {0: weight_for_0, 1: weight_for_1}
    print('Weight for class 0: {:.2f}'.format(weight_for_0))
    print('Weight for class 1: {:.2f}'.format(weight_for_1))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold],v=0)
        
    # CALLBACKS - SAVE BEST MODEL EACH FOLD ALSO UTILISE EARLY STOPPING TO ALLOW MORE EPOCHS
    svl = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-loss.h5', monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
    sva = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-auc.h5', monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    if EARLY_STOPPING:
        es = tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=PATIENCE, verbose=VERBOSE, mode='auto')
        callback_list = [svl, sva, es, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
    else:
        callback_list = [svl, sva, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                    dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold],
                    droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]),
        epochs=EPOCHS[fold],
        callbacks = callback_list, 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid, augment=True, shuffle=False, repeat=False, dim=IMG_SIZES[fold],
                                   droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]),
        class_weight=class_weight,
        verbose=VERBOSE
    )
    
    # DETERMINE BEST SCORES AND EPOCHS
    val_auc_ls = history.history['val_auc']
    val_loss_ls = history.history['val_loss']
    
    best_val_auc = max(val_auc_ls)
    best_val_loss = min(val_loss_ls)
    best_val_auc_ls.append(best_val_auc)
    best_val_loss_ls.append(best_val_loss)
    
    opt_epoch_auc = val_auc_ls.index(best_val_auc)
    opt_epoch_loss = val_loss_ls.index(best_val_loss)
    best_epoch_val_auc_ls.append(opt_epoch_auc)
    best_epoch_val_loss_ls.append(opt_epoch_loss)
    
    #RELOAD BEST WEIGHTS AT BEST EPOCH
    print('Loading best model...')
    model.load_weights(f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-auc.h5')
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
                          repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*2,
                          droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/2/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))

    # INCLUDING ENSEMBLE OF META DATA
    meta_wgt_auc = []

    dsp_ft = get_meta(files_train)
    dsp_fv = get_meta(files_valid)
    meta_train = meta_unbatch(dsp_ft)
    meta_val = meta_unbatch(dsp_fv)
    meta_pred = meta_model(meta_train, meta_val)
    meta_pred['oof'] = oof_pred[-1]
    meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])    

    for wgt in range(0, 31, 1):
        wgt = wgt/100
        meta_pred['ens'] = ((1-wgt)*meta_pred.oof + wgt*meta_pred.ll)
        meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])
        meta_ens_auc = roc_auc_score(meta_pred['target'],meta_pred['ens'])    
        meta_wgt_auc.append([wgt, meta_ens_auc])
        #print(f"With Meta Weight {wgt}, Meta and OOF AUC with TTA:", meta_ens_auc)
    best_meta_wgts.append(max(meta_wgt_auc, key=lambda item: item[1]))    
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
                         repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*4,
                         droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/4/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,]
    pred = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += pred * WGTS[fold]
    
    dsp_test = get_meta(files_test, BATCH_SIZES[0], test=1)
    meta_test = meta_unbatch(dsp_test, test=1)
    meta_test = meta_model(meta_train, meta_test)
    meta_test['preds'] = pred
    meta_test['preds_meta'] = best_meta_wgts[-1][0]*meta_test.ll + (1-best_meta_wgts[-1][0])*meta_test.preds
    preds_meta = np.array([meta_test.preds_meta]).T
    preds_meta_ls += preds_meta * WGTS[fold]

    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print(f'#### FOLD {fold+1} OOF AUC without TTA = {oof_val[-1]:.3f}, with TTA = {auc:.3f}')
    print("Meta only AUC:", meta_auc) 
    print(f"The best weight is {best_meta_wgts[-1][0]}, Meta and OOF AUC with TTA: {best_meta_wgts[-1][1]:.3f}")
    
    COMPLETED_EPOCHS = len(history.history['loss'])
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] )
        y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4')
        plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] )
        y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728')
        plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i, M1=%i, M2=%i, M3=%i, M4=%i\n\
        batch_size %i, dropout_freq=%.2f count=%i size=%.3f'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold],M1[fold],M2[fold],M3[fold],
                 M4[fold],BATCH_SIZES[fold]*REPLICAS,DROP_FREQ[fold],DROP_CT[fold],DROP_SIZE[fold]),size=18)
        plt.legend(loc=3)
        plt.show()  
        
        # TESTING ONLY
        loops+=1
        if loops == max_loops:
            break
        else:
            continue
        
        del model; z = gc.collect()
# Out:
# #########################
# #### FOLD 1
# #########################
# #### Using the following TFRecords:
# [ 0  1  2  3  4  5  7 10 11 12 13 14] [6 8 9]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-2 data (ISIC website)
# #### Upsample MALIG-3 data (2019 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.57
# Weight for class 1: 3.89
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Training...
# Epoch 1/50
# WARNING:tensorflow:From /home/phil/anaconda3/envs/tf37/lib/python3.7/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 598/598 [==============================] - ETA: 0s - loss: 0.6102 - auc: 0.7949
# Epoch 00001: val_loss improved from inf to 0.45168, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.82130, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 208s 348ms/step - loss: 0.6102 - auc: 0.7949 - val_loss: 0.4517 - val_auc: 0.8213
# Epoch 2/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4640 - auc: 0.8813
# Epoch 00002: val_loss improved from 0.45168 to 0.30694, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00002: val_auc improved from 0.82130 to 0.84445, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 350ms/step - loss: 0.4640 - auc: 0.8813 - val_loss: 0.3069 - val_auc: 0.8445
# Epoch 3/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4233 - auc: 0.9074
# Epoch 00003: val_loss improved from 0.30694 to 0.27776, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00003: val_auc improved from 0.84445 to 0.88055, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 352ms/step - loss: 0.4233 - auc: 0.9074 - val_loss: 0.2778 - val_auc: 0.8806
# Epoch 4/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4020 - auc: 0.9190
# Epoch 00004: val_loss improved from 0.27776 to 0.26141, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00004: val_auc improved from 0.88055 to 0.89228, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 352ms/step - loss: 0.4020 - auc: 0.9190 - val_loss: 0.2614 - val_auc: 0.8923
# Epoch 5/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3811 - auc: 0.9311
# Epoch 00005: val_loss improved from 0.26141 to 0.23649, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00005: val_auc improved from 0.89228 to 0.91643, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 352ms/step - loss: 0.3811 - auc: 0.9311 - val_loss: 0.2365 - val_auc: 0.9164
# Epoch 6/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3632 - auc: 0.9394
# Epoch 00006: val_loss did not improve from 0.23649
#
# Epoch 00006: val_auc improved from 0.91643 to 0.92058, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.3632 - auc: 0.9394 - val_loss: 0.2730 - val_auc: 0.9206
# Epoch 7/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3416 - auc: 0.9500
# Epoch 00007: val_loss did not improve from 0.23649
#
# Epoch 00007: val_auc did not improve from 0.92058
# 598/598 [==============================] - 209s 350ms/step - loss: 0.3416 - auc: 0.9500 - val_loss: 0.2477 - val_auc: 0.9153
# Epoch 8/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3274 - auc: 0.9554
# Epoch 00008: val_loss improved from 0.23649 to 0.23138, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00008: val_auc improved from 0.92058 to 0.92775, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 352ms/step - loss: 0.3274 - auc: 0.9554 - val_loss: 0.2314 - val_auc: 0.9278
# Epoch 9/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3153 - auc: 0.9599
# Epoch 00009: val_loss did not improve from 0.23138
#
# Epoch 00009: val_auc did not improve from 0.92775
# 598/598 [==============================] - 210s 350ms/step - loss: 0.3153 - auc: 0.9599 - val_loss: 0.2343 - val_auc: 0.9275
# Epoch 10/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3036 - auc: 0.9650
# Epoch 00010: val_loss did not improve from 0.23138
#
# Epoch 00010: val_auc improved from 0.92775 to 0.93719, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 351ms/step - loss: 0.3036 - auc: 0.9650 - val_loss: 0.2412 - val_auc: 0.9372
# Epoch 11/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2936 - auc: 0.9679
# Epoch 00011: val_loss improved from 0.23138 to 0.22839, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00011: val_auc improved from 0.93719 to 0.94583, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2936 - auc: 0.9679 - val_loss: 0.2284 - val_auc: 0.9458
# Epoch 12/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2843 - auc: 0.9713
# Epoch 00012: val_loss improved from 0.22839 to 0.21621, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00012: val_auc improved from 0.94583 to 0.95005, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2843 - auc: 0.9713 - val_loss: 0.2162 - val_auc: 0.9500
# Epoch 13/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2771 - auc: 0.9733
# Epoch 00013: val_loss did not improve from 0.21621
#
# Epoch 00013: val_auc improved from 0.95005 to 0.95288, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2771 - auc: 0.9733 - val_loss: 0.2184 - val_auc: 0.9529
# Epoch 14/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2715 - auc: 0.9754
# Epoch 00014: val_loss improved from 0.21621 to 0.20660, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00014: val_auc did not improve from 0.95288
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2715 - auc: 0.9754 - val_loss: 0.2066 - val_auc: 0.9471
# Epoch 15/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2662 - auc: 0.9773
# Epoch 00015: val_loss did not improve from 0.20660
#
# Epoch 00015: val_auc did not improve from 0.95288
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2662 - auc: 0.9773 - val_loss: 0.2088 - val_auc: 0.9409
# Epoch 16/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2610 - auc: 0.9784
# Epoch 00016: val_loss did not improve from 0.20660
#
# Epoch 00016: val_auc did not improve from 0.95288
# 598/598 [==============================] - 209s 349ms/step - loss: 0.2610 - auc: 0.9784 - val_loss: 0.2073 - val_auc: 0.9521
# Epoch 17/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2593 - auc: 0.9786
# Epoch 00017: val_loss did not improve from 0.20660
#
# Epoch 00017: val_auc improved from 0.95288 to 0.96138, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2593 - auc: 0.9786 - val_loss: 0.2123 - val_auc: 0.9614
# Epoch 18/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2552 - auc: 0.9798
# Epoch 00018: val_loss improved from 0.20660 to 0.20514, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00018: val_auc did not improve from 0.96138
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2552 - auc: 0.9798 - val_loss: 0.2051 - val_auc: 0.9587
# Epoch 19/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2517 - auc: 0.9809
# Epoch 00019: val_loss improved from 0.20514 to 0.20112, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00019: val_auc did not improve from 0.96138
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2517 - auc: 0.9809 - val_loss: 0.2011 - val_auc: 0.9608
# Epoch 20/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2457 - auc: 0.9824
# Epoch 00020: val_loss did not improve from 0.20112
#
# Epoch 00020: val_auc did not improve from 0.96138
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2457 - auc: 0.9824 - val_loss: 0.2144 - val_auc: 0.9564
# Epoch 21/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2456 - auc: 0.9825
# Epoch 00021: val_loss did not improve from 0.20112
#
# Epoch 00021: val_auc did not improve from 0.96138
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2456 - auc: 0.9825 - val_loss: 0.2051 - val_auc: 0.9575
# Epoch 22/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2430 - auc: 0.9834
# Epoch 00022: val_loss did not improve from 0.20112
#
# Epoch 00022: val_auc did not improve from 0.96138
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2430 - auc: 0.9834 - val_loss: 0.2077 - val_auc: 0.9594
# Epoch 23/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2425 - auc: 0.9834
# Epoch 00023: val_loss did not improve from 0.20112
#
# Epoch 00023: val_auc improved from 0.96138 to 0.96317, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2425 - auc: 0.9834 - val_loss: 0.2036 - val_auc: 0.9632
# Epoch 24/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2473 - auc: 0.9820
# Epoch 00024: val_loss did not improve from 0.20112
#
# Epoch 00024: val_auc did not improve from 0.96317
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2473 - auc: 0.9820 - val_loss: 0.2029 - val_auc: 0.9588
# Epoch 25/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2376 - auc: 0.9846
# Epoch 00025: val_loss improved from 0.20112 to 0.19486, saving model to ./cv_folds/EB1-256-fold-0-loss.h5
#
# Epoch 00025: val_auc improved from 0.96317 to 0.96523, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2376 - auc: 0.9846 - val_loss: 0.1949 - val_auc: 0.9652
# Epoch 26/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2399 - auc: 0.9841
# Epoch 00026: val_loss did not improve from 0.19486
#
# Epoch 00026: val_auc did not improve from 0.96523
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2399 - auc: 0.9841 - val_loss: 0.1949 - val_auc: 0.9646
# Epoch 27/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2390 - auc: 0.9843
# Epoch 00027: val_loss did not improve from 0.19486
#
# Epoch 00027: val_auc did not improve from 0.96523
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2390 - auc: 0.9843 - val_loss: 0.2039 - val_auc: 0.9610
# Epoch 28/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2398 - auc: 0.9841
# Epoch 00028: val_loss did not improve from 0.19486
#
# Epoch 00028: val_auc improved from 0.96523 to 0.96941, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2398 - auc: 0.9841 - val_loss: 0.1999 - val_auc: 0.9694
# Epoch 29/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2388 - auc: 0.9839
# Epoch 00029: val_loss did not improve from 0.19486
#
# Epoch 00029: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2388 - auc: 0.9839 - val_loss: 0.1971 - val_auc: 0.9615
# Epoch 30/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2383 - auc: 0.9846
# Epoch 00030: val_loss did not improve from 0.19486
#
# Epoch 00030: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2383 - auc: 0.9846 - val_loss: 0.1979 - val_auc: 0.9518
# Epoch 31/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2358 - auc: 0.9850
# Epoch 00031: val_loss did not improve from 0.19486
#
# Epoch 00031: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2358 - auc: 0.9850 - val_loss: 0.2022 - val_auc: 0.9637
# Epoch 32/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2402 - auc: 0.9838
# Epoch 00032: val_loss did not improve from 0.19486
#
# Epoch 00032: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2402 - auc: 0.9838 - val_loss: 0.1993 - val_auc: 0.9679
# Epoch 33/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2366 - auc: 0.9849
# Epoch 00033: val_loss did not improve from 0.19486
#
# Epoch 00033: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2366 - auc: 0.9849 - val_loss: 0.2016 - val_auc: 0.9669
# Epoch 34/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2362 - auc: 0.9846
# Epoch 00034: val_loss did not improve from 0.19486
#
# Epoch 00034: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2362 - auc: 0.9846 - val_loss: 0.1961 - val_auc: 0.9635
# Epoch 35/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2399 - auc: 0.9840
# Epoch 00035: val_loss did not improve from 0.19486
#
# Epoch 00035: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2399 - auc: 0.9840 - val_loss: 0.1991 - val_auc: 0.9641
# Epoch 36/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2366 - auc: 0.9845
# Epoch 00036: val_loss did not improve from 0.19486
#
# Epoch 00036: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2366 - auc: 0.9845 - val_loss: 0.2017 - val_auc: 0.9558
# Epoch 37/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2362 - auc: 0.9848
# Epoch 00037: val_loss did not improve from 0.19486
#
# Epoch 00037: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2362 - auc: 0.9848 - val_loss: 0.1981 - val_auc: 0.9580
# Epoch 38/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2365 - auc: 0.9848
# Epoch 00038: val_loss did not improve from 0.19486
#
# Epoch 00038: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2365 - auc: 0.9848 - val_loss: 0.1974 - val_auc: 0.9693
# Epoch 39/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2379 - auc: 0.9845
# Epoch 00039: val_loss did not improve from 0.19486
#
# Epoch 00039: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2379 - auc: 0.9845 - val_loss: 0.2031 - val_auc: 0.9680
# Epoch 40/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2381 - auc: 0.9845
# Epoch 00040: val_loss did not improve from 0.19486
#
# Epoch 00040: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2381 - auc: 0.9845 - val_loss: 0.2001 - val_auc: 0.9585
# Epoch 41/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2341 - auc: 0.9856
# Epoch 00041: val_loss did not improve from 0.19486
#
# Epoch 00041: val_auc did not improve from 0.96941
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2341 - auc: 0.9856 - val_loss: 0.2060 - val_auc: 0.9601
# Epoch 42/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2348 - auc: 0.9850
# Epoch 00042: val_loss did not improve from 0.19486
#
# Epoch 00042: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2348 - auc: 0.9850 - val_loss: 0.2020 - val_auc: 0.9551
# Epoch 43/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2330 - auc: 0.9856
# Epoch 00043: val_loss did not improve from 0.19486
#
# Epoch 00043: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2330 - auc: 0.9856 - val_loss: 0.2033 - val_auc: 0.9552
# Epoch 44/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2344 - auc: 0.9853
# Epoch 00044: val_loss did not improve from 0.19486
#
# Epoch 00044: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2344 - auc: 0.9853 - val_loss: 0.2029 - val_auc: 0.9592
# Epoch 45/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2364 - auc: 0.9852
# Epoch 00045: val_loss did not improve from 0.19486
#
# Epoch 00045: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2364 - auc: 0.9852 - val_loss: 0.1987 - val_auc: 0.9664
# Epoch 46/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2348 - auc: 0.9851
# Epoch 00046: val_loss did not improve from 0.19486
#
# Epoch 00046: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2348 - auc: 0.9851 - val_loss: 0.1958 - val_auc: 0.9679
# Epoch 47/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2341 - auc: 0.9854
# Epoch 00047: val_loss did not improve from 0.19486
#
# Epoch 00047: val_auc did not improve from 0.96941
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2341 - auc: 0.9854 - val_loss: 0.1999 - val_auc: 0.9574
# Epoch 48/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2359 - auc: 0.9847
# Epoch 00048: val_loss did not improve from 0.19486
#
# Epoch 00048: val_auc improved from 0.96941 to 0.96969, saving model to ./cv_folds/EB1-256-fold-0-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2359 - auc: 0.9847 - val_loss: 0.1979 - val_auc: 0.9697
# Epoch 49/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2340 - auc: 0.9854
# Epoch 00049: val_loss did not improve from 0.19486
#
# Epoch 00049: val_auc did not improve from 0.96969
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2340 - auc: 0.9854 - val_loss: 0.2012 - val_auc: 0.9523
# Epoch 50/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2315 - auc: 0.9857
# Epoch 00050: val_loss did not improve from 0.19486
#
# Epoch 00050: val_auc did not improve from 0.96969
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2315 - auc: 0.9857 - val_loss: 0.2008 - val_auc: 0.9586
# Loading best model...
# Predicting OOF with TTA...
# 1214/1213 [==============================] - 108s 89ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 180s 168ms/step
# #### FOLD 1 OOF AUC without TTA = 0.970, with TTA = 0.975
# Meta only AUC: 0.6916641507635102
# The best weight is 0.08, Meta and OOF AUC with TTA: 0.975
# #########################
# #### FOLD 2
# #########################
# #### Using the following TFRecords:
# [ 0  1  3  4  5  6  8  9 11 12 13 14] [ 2  7 10]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-2 data (ISIC website)
# #### Upsample MALIG-3 data (2019 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.57
# Weight for class 1: 3.90
# Training...
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 598/598 [==============================] - ETA: 0s - loss: 0.6163 - auc: 0.7935
# Epoch 00001: val_loss improved from inf to 0.48675, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.82590, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 217s 362ms/step - loss: 0.6163 - auc: 0.7935 - val_loss: 0.4867 - val_auc: 0.8259
# Epoch 2/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4609 - auc: 0.8836
# Epoch 00002: val_loss improved from 0.48675 to 0.33646, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00002: val_auc improved from 0.82590 to 0.87134, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 213s 356ms/step - loss: 0.4609 - auc: 0.8836 - val_loss: 0.3365 - val_auc: 0.8713
# Epoch 3/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4258 - auc: 0.9053
# Epoch 00003: val_loss improved from 0.33646 to 0.30181, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00003: val_auc improved from 0.87134 to 0.89281, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.4258 - auc: 0.9053 - val_loss: 0.3018 - val_auc: 0.8928
# Epoch 4/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4009 - auc: 0.9195
# Epoch 00004: val_loss improved from 0.30181 to 0.27590, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00004: val_auc improved from 0.89281 to 0.90421, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.4009 - auc: 0.9195 - val_loss: 0.2759 - val_auc: 0.9042
# Epoch 5/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3812 - auc: 0.9314
# Epoch 00005: val_loss did not improve from 0.27590
#
# Epoch 00005: val_auc improved from 0.90421 to 0.91692, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 354ms/step - loss: 0.3812 - auc: 0.9314 - val_loss: 0.3117 - val_auc: 0.9169
# Epoch 6/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3610 - auc: 0.9403
# Epoch 00006: val_loss improved from 0.27590 to 0.26515, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00006: val_auc improved from 0.91692 to 0.91765, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.3610 - auc: 0.9403 - val_loss: 0.2651 - val_auc: 0.9176
# Epoch 7/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3478 - auc: 0.9471
# Epoch 00007: val_loss improved from 0.26515 to 0.25666, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00007: val_auc improved from 0.91765 to 0.93362, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.3478 - auc: 0.9471 - val_loss: 0.2567 - val_auc: 0.9336
# Epoch 8/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3313 - auc: 0.9539
# Epoch 00008: val_loss improved from 0.25666 to 0.24945, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00008: val_auc improved from 0.93362 to 0.94094, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.3313 - auc: 0.9539 - val_loss: 0.2494 - val_auc: 0.9409
# Epoch 9/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3198 - auc: 0.9587
# Epoch 00009: val_loss did not improve from 0.24945
#
# Epoch 00009: val_auc improved from 0.94094 to 0.94594, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 354ms/step - loss: 0.3198 - auc: 0.9587 - val_loss: 0.2571 - val_auc: 0.9459
# Epoch 10/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3029 - auc: 0.9652
# Epoch 00010: val_loss did not improve from 0.24945
#
# Epoch 00010: val_auc improved from 0.94594 to 0.95353, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.3029 - auc: 0.9652 - val_loss: 0.2512 - val_auc: 0.9535
# Epoch 11/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2986 - auc: 0.9669
# Epoch 00011: val_loss improved from 0.24945 to 0.23098, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00011: val_auc did not improve from 0.95353
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2986 - auc: 0.9669 - val_loss: 0.2310 - val_auc: 0.9507
# Epoch 12/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2859 - auc: 0.9712
# Epoch 00012: val_loss improved from 0.23098 to 0.22979, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00012: val_auc improved from 0.95353 to 0.95653, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2859 - auc: 0.9712 - val_loss: 0.2298 - val_auc: 0.9565
# Epoch 13/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2814 - auc: 0.9723
# Epoch 00013: val_loss improved from 0.22979 to 0.20965, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00013: val_auc did not improve from 0.95653
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2814 - auc: 0.9723 - val_loss: 0.2096 - val_auc: 0.9541
# Epoch 14/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2768 - auc: 0.9739
# Epoch 00014: val_loss did not improve from 0.20965
#
# Epoch 00014: val_auc did not improve from 0.95653
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2768 - auc: 0.9739 - val_loss: 0.2211 - val_auc: 0.9511
# Epoch 15/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2690 - auc: 0.9762
# Epoch 00015: val_loss improved from 0.20965 to 0.20796, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00015: val_auc improved from 0.95653 to 0.96323, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2690 - auc: 0.9762 - val_loss: 0.2080 - val_auc: 0.9632
# Epoch 16/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2633 - auc: 0.9781
# Epoch 00016: val_loss did not improve from 0.20796
#
# Epoch 00016: val_auc did not improve from 0.96323
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2633 - auc: 0.9781 - val_loss: 0.2111 - val_auc: 0.9580
# Epoch 17/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2632 - auc: 0.9778
# Epoch 00017: val_loss did not improve from 0.20796
#
# Epoch 00017: val_auc improved from 0.96323 to 0.96388, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2632 - auc: 0.9778 - val_loss: 0.2122 - val_auc: 0.9639
# Epoch 18/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2589 - auc: 0.9789
# Epoch 00018: val_loss did not improve from 0.20796
#
# Epoch 00018: val_auc did not improve from 0.96388
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2589 - auc: 0.9789 - val_loss: 0.2164 - val_auc: 0.9595
# Epoch 19/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2550 - auc: 0.9802
# Epoch 00019: val_loss did not improve from 0.20796
#
# Epoch 00019: val_auc did not improve from 0.96388
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2550 - auc: 0.9802 - val_loss: 0.2098 - val_auc: 0.9598
# Epoch 20/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2561 - auc: 0.9801
# Epoch 00020: val_loss did not improve from 0.20796
#
# Epoch 00020: val_auc did not improve from 0.96388
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2561 - auc: 0.9801 - val_loss: 0.2146 - val_auc: 0.9586
# Epoch 21/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2510 - auc: 0.9811
# Epoch 00021: val_loss did not improve from 0.20796
#
# Epoch 00021: val_auc improved from 0.96388 to 0.96494, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2510 - auc: 0.9811 - val_loss: 0.2206 - val_auc: 0.9649
# Epoch 22/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2473 - auc: 0.9821
# Epoch 00022: val_loss did not improve from 0.20796
#
# Epoch 00022: val_auc did not improve from 0.96494
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2473 - auc: 0.9821 - val_loss: 0.2150 - val_auc: 0.9632
# Epoch 23/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2497 - auc: 0.9818
# Epoch 00023: val_loss did not improve from 0.20796
#
# Epoch 00023: val_auc improved from 0.96494 to 0.96600, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 354ms/step - loss: 0.2497 - auc: 0.9818 - val_loss: 0.2139 - val_auc: 0.9660
# Epoch 24/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2483 - auc: 0.9819
# Epoch 00024: val_loss did not improve from 0.20796
#
# Epoch 00024: val_auc improved from 0.96600 to 0.96851, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2483 - auc: 0.9819 - val_loss: 0.2158 - val_auc: 0.9685
# Epoch 25/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2445 - auc: 0.9827
# Epoch 00025: val_loss did not improve from 0.20796
#
# Epoch 00025: val_auc improved from 0.96851 to 0.97098, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2445 - auc: 0.9827 - val_loss: 0.2098 - val_auc: 0.9710
# Epoch 26/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2465 - auc: 0.9824
# Epoch 00026: val_loss did not improve from 0.20796
#
# Epoch 00026: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2465 - auc: 0.9824 - val_loss: 0.2153 - val_auc: 0.9626
# Epoch 27/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2425 - auc: 0.9836
# Epoch 00027: val_loss did not improve from 0.20796
#
# Epoch 00027: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2425 - auc: 0.9836 - val_loss: 0.2099 - val_auc: 0.9705
# Epoch 28/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2439 - auc: 0.9830
# Epoch 00028: val_loss did not improve from 0.20796
#
# Epoch 00028: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2439 - auc: 0.9830 - val_loss: 0.2144 - val_auc: 0.9684
# Epoch 29/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2426 - auc: 0.9830
# Epoch 00029: val_loss improved from 0.20796 to 0.20498, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00029: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2426 - auc: 0.9830 - val_loss: 0.2050 - val_auc: 0.9653
# Epoch 30/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2418 - auc: 0.9836
# Epoch 00030: val_loss improved from 0.20498 to 0.20457, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00030: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 354ms/step - loss: 0.2418 - auc: 0.9836 - val_loss: 0.2046 - val_auc: 0.9700
# Epoch 31/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2424 - auc: 0.9833
# Epoch 00031: val_loss did not improve from 0.20457
#
# Epoch 00031: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2424 - auc: 0.9833 - val_loss: 0.2058 - val_auc: 0.9667
# Epoch 32/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2415 - auc: 0.9838
# Epoch 00032: val_loss did not improve from 0.20457
#
# Epoch 00032: val_auc did not improve from 0.97098
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2415 - auc: 0.9838 - val_loss: 0.2064 - val_auc: 0.9670
# Epoch 33/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2400 - auc: 0.9840
# Epoch 00033: val_loss did not improve from 0.20457
#
# Epoch 00033: val_auc improved from 0.97098 to 0.97254, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2400 - auc: 0.9840 - val_loss: 0.2065 - val_auc: 0.9725
# Epoch 34/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2427 - auc: 0.9834
# Epoch 00034: val_loss did not improve from 0.20457
#
# Epoch 00034: val_auc did not improve from 0.97254
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2427 - auc: 0.9834 - val_loss: 0.2113 - val_auc: 0.9577
# Epoch 35/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2402 - auc: 0.9839
# Epoch 00035: val_loss did not improve from 0.20457
#
# Epoch 00035: val_auc did not improve from 0.97254
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2402 - auc: 0.9839 - val_loss: 0.2057 - val_auc: 0.9592
# Epoch 36/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2410 - auc: 0.9840
# Epoch 00036: val_loss did not improve from 0.20457
#
# Epoch 00036: val_auc did not improve from 0.97254
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2410 - auc: 0.9840 - val_loss: 0.2071 - val_auc: 0.9689
# Epoch 37/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2394 - auc: 0.9842
# Epoch 00037: val_loss did not improve from 0.20457
#
# Epoch 00037: val_auc improved from 0.97254 to 0.97363, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 212s 355ms/step - loss: 0.2394 - auc: 0.9842 - val_loss: 0.2056 - val_auc: 0.9736
# Epoch 38/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2428 - auc: 0.9833
# Epoch 00038: val_loss did not improve from 0.20457
#
# Epoch 00038: val_auc did not improve from 0.97363
# 598/598 [==============================] - 215s 360ms/step - loss: 0.2428 - auc: 0.9833 - val_loss: 0.2047 - val_auc: 0.9668
# Epoch 39/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2365 - auc: 0.9847
# Epoch 00039: val_loss did not improve from 0.20457
#
# Epoch 00039: val_auc did not improve from 0.97363
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2365 - auc: 0.9847 - val_loss: 0.2062 - val_auc: 0.9615
# Epoch 40/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2395 - auc: 0.9840
# Epoch 00040: val_loss did not improve from 0.20457
#
# Epoch 00040: val_auc did not improve from 0.97363
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2395 - auc: 0.9840 - val_loss: 0.2055 - val_auc: 0.9670
# Epoch 41/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2357 - auc: 0.9850
# Epoch 00041: val_loss improved from 0.20457 to 0.20342, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00041: val_auc did not improve from 0.97363
# 598/598 [==============================] - 215s 359ms/step - loss: 0.2357 - auc: 0.9850 - val_loss: 0.2034 - val_auc: 0.9720
# Epoch 42/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2422 - auc: 0.9837
# Epoch 00042: val_loss did not improve from 0.20342
#
# Epoch 00042: val_auc did not improve from 0.97363
# 598/598 [==============================] - 214s 358ms/step - loss: 0.2422 - auc: 0.9837 - val_loss: 0.2071 - val_auc: 0.9678
# Epoch 43/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2396 - auc: 0.9843
# Epoch 00043: val_loss did not improve from 0.20342
#
# Epoch 00043: val_auc improved from 0.97363 to 0.97594, saving model to ./cv_folds/EB1-256-fold-1-auc.h5
# 598/598 [==============================] - 214s 357ms/step - loss: 0.2396 - auc: 0.9843 - val_loss: 0.2039 - val_auc: 0.9759
# Epoch 44/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2369 - auc: 0.9846
# Epoch 00044: val_loss improved from 0.20342 to 0.20291, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00044: val_auc did not improve from 0.97594
# 598/598 [==============================] - 214s 358ms/step - loss: 0.2369 - auc: 0.9846 - val_loss: 0.2029 - val_auc: 0.9693
# Epoch 45/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2395 - auc: 0.9843
# Epoch 00045: val_loss improved from 0.20291 to 0.20280, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00045: val_auc did not improve from 0.97594
# 598/598 [==============================] - 214s 357ms/step - loss: 0.2395 - auc: 0.9843 - val_loss: 0.2028 - val_auc: 0.9706
# Epoch 46/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2398 - auc: 0.9838
# Epoch 00046: val_loss improved from 0.20280 to 0.20179, saving model to ./cv_folds/EB1-256-fold-1-loss.h5
#
# Epoch 00046: val_auc did not improve from 0.97594
# 598/598 [==============================] - 211s 354ms/step - loss: 0.2398 - auc: 0.9838 - val_loss: 0.2018 - val_auc: 0.9678
# Epoch 47/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2346 - auc: 0.9854
# Epoch 00047: val_loss did not improve from 0.20179
#
# Epoch 00047: val_auc did not improve from 0.97594
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2346 - auc: 0.9854 - val_loss: 0.2042 - val_auc: 0.9664
# Epoch 48/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2415 - auc: 0.9835
# Epoch 00048: val_loss did not improve from 0.20179
#
# Epoch 00048: val_auc did not improve from 0.97594
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2415 - auc: 0.9835 - val_loss: 0.2056 - val_auc: 0.9611
# Epoch 49/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2386 - auc: 0.9842
# Epoch 00049: val_loss did not improve from 0.20179
#
# Epoch 00049: val_auc did not improve from 0.97594
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2386 - auc: 0.9842 - val_loss: 0.2042 - val_auc: 0.9663
# Epoch 50/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2387 - auc: 0.9844
# Epoch 00050: val_loss did not improve from 0.20179
#
# Epoch 00050: val_auc did not improve from 0.97594
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2387 - auc: 0.9844 - val_loss: 0.2083 - val_auc: 0.9704
# Loading best model...
# Predicting OOF with TTA...
# 1214/1213 [==============================] - 111s 91ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 182s 169ms/step
# #### FOLD 2 OOF AUC without TTA = 0.976, with TTA = 0.980
# Meta only AUC: 0.70605617632531
# The best weight is 0.06, Meta and OOF AUC with TTA: 0.980
# #########################
# #### FOLD 3
# #########################
# #### Using the following TFRecords:
# [ 0  2  3  5  6  7  8  9 10 11 12 13] [ 1  4 14]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-2 data (ISIC website)
# #### Upsample MALIG-3 data (2019 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.57
# Weight for class 1: 3.87
# Training...
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 598/598 [==============================] - ETA: 0s - loss: 0.6478 - auc: 0.7694
# Epoch 00001: val_loss improved from inf to 0.49940, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.78636, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 219s 366ms/step - loss: 0.6478 - auc: 0.7694 - val_loss: 0.4994 - val_auc: 0.7864
# Epoch 2/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4709 - auc: 0.8799
# Epoch 00002: val_loss improved from 0.49940 to 0.33987, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00002: val_auc improved from 0.78636 to 0.83590, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 216s 360ms/step - loss: 0.4709 - auc: 0.8799 - val_loss: 0.3399 - val_auc: 0.8359
# Epoch 3/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4236 - auc: 0.9049
# Epoch 00003: val_loss improved from 0.33987 to 0.33236, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00003: val_auc improved from 0.83590 to 0.85460, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.4236 - auc: 0.9049 - val_loss: 0.3324 - val_auc: 0.8546
# Epoch 4/50
# 598/598 [==============================] - ETA: 0s - loss: 0.4051 - auc: 0.9186
# Epoch 00004: val_loss improved from 0.33236 to 0.31877, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00004: val_auc improved from 0.85460 to 0.86968, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.4051 - auc: 0.9186 - val_loss: 0.3188 - val_auc: 0.8697
# Epoch 5/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3829 - auc: 0.9306
# Epoch 00005: val_loss did not improve from 0.31877
#
# Epoch 00005: val_auc improved from 0.86968 to 0.88785, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 359ms/step - loss: 0.3829 - auc: 0.9306 - val_loss: 0.3700 - val_auc: 0.8878
# Epoch 6/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3643 - auc: 0.9379
# Epoch 00006: val_loss improved from 0.31877 to 0.29148, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00006: val_auc improved from 0.88785 to 0.90377, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.3643 - auc: 0.9379 - val_loss: 0.2915 - val_auc: 0.9038
# Epoch 7/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3506 - auc: 0.9460
# Epoch 00007: val_loss did not improve from 0.29148
#
# Epoch 00007: val_auc did not improve from 0.90377
# 598/598 [==============================] - 214s 358ms/step - loss: 0.3506 - auc: 0.9460 - val_loss: 0.3349 - val_auc: 0.9021
# Epoch 8/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3350 - auc: 0.9526
# Epoch 00008: val_loss improved from 0.29148 to 0.27594, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00008: val_auc improved from 0.90377 to 0.90470, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.3350 - auc: 0.9526 - val_loss: 0.2759 - val_auc: 0.9047
# Epoch 9/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3205 - auc: 0.9585
# Epoch 00009: val_loss did not improve from 0.27594
#
# Epoch 00009: val_auc improved from 0.90470 to 0.93088, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.3205 - auc: 0.9585 - val_loss: 0.2907 - val_auc: 0.9309
# Epoch 10/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3082 - auc: 0.9630
# Epoch 00010: val_loss did not improve from 0.27594
#
# Epoch 00010: val_auc improved from 0.93088 to 0.93269, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 359ms/step - loss: 0.3082 - auc: 0.9630 - val_loss: 0.3107 - val_auc: 0.9327
# Epoch 11/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3007 - auc: 0.9661
# Epoch 00011: val_loss improved from 0.27594 to 0.26469, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00011: val_auc improved from 0.93269 to 0.93706, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.3007 - auc: 0.9661 - val_loss: 0.2647 - val_auc: 0.9371
# Epoch 12/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2886 - auc: 0.9698
# Epoch 00012: val_loss improved from 0.26469 to 0.25745, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00012: val_auc improved from 0.93706 to 0.94211, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.2886 - auc: 0.9698 - val_loss: 0.2574 - val_auc: 0.9421
# Epoch 13/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2794 - auc: 0.9736
# Epoch 00013: val_loss improved from 0.25745 to 0.23725, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00013: val_auc improved from 0.94211 to 0.95032, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 214s 358ms/step - loss: 0.2794 - auc: 0.9736 - val_loss: 0.2372 - val_auc: 0.9503
# Epoch 14/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2787 - auc: 0.9732
# Epoch 00014: val_loss improved from 0.23725 to 0.22865, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00014: val_auc improved from 0.95032 to 0.95259, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 215s 359ms/step - loss: 0.2787 - auc: 0.9732 - val_loss: 0.2286 - val_auc: 0.9526
# Epoch 15/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2742 - auc: 0.9743
# Epoch 00015: val_loss did not improve from 0.22865
#
# Epoch 00015: val_auc did not improve from 0.95259
# 598/598 [==============================] - 214s 359ms/step - loss: 0.2742 - auc: 0.9743 - val_loss: 0.2429 - val_auc: 0.9498
# Epoch 16/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2681 - auc: 0.9765
# Epoch 00016: val_loss did not improve from 0.22865
#
# Epoch 00016: val_auc did not improve from 0.95259
# 598/598 [==============================] - 218s 365ms/step - loss: 0.2681 - auc: 0.9765 - val_loss: 0.2330 - val_auc: 0.9469
# Epoch 17/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2700 - auc: 0.9757
# Epoch 00017: val_loss did not improve from 0.22865
#
# Epoch 00017: val_auc did not improve from 0.95259
# 598/598 [==============================] - 216s 362ms/step - loss: 0.2700 - auc: 0.9757 - val_loss: 0.2325 - val_auc: 0.9494
# Epoch 18/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2625 - auc: 0.9779
# Epoch 00018: val_loss did not improve from 0.22865
#
# Epoch 00018: val_auc did not improve from 0.95259
# 598/598 [==============================] - 216s 361ms/step - loss: 0.2625 - auc: 0.9779 - val_loss: 0.2362 - val_auc: 0.9517
# Epoch 19/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2586 - auc: 0.9791
# Epoch 00019: val_loss improved from 0.22865 to 0.21757, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
#
# Epoch 00019: val_auc did not improve from 0.95259
# 598/598 [==============================] - 216s 362ms/step - loss: 0.2586 - auc: 0.9791 - val_loss: 0.2176 - val_auc: 0.9521
# Epoch 20/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2541 - auc: 0.9804
# Epoch 00020: val_loss improved from 0.21757 to 0.20919, saving model to ./cv_folds/EB1-256-fold-2-loss.h5
# Epoch 00020: val_auc improved from 0.95259 to 0.95548, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# 598/598 [==============================] - 216s 362ms/step - loss: 0.2541 - auc: 0.9804 - val_loss: 0.2092 - val_auc: 0.9555
# Epoch 21/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2585 - auc: 0.9793
# Epoch 00021: val_loss did not improve from 0.20919
#
# Epoch 00021: val_auc improved from 0.95548 to 0.96077, saving model to ./cv_folds/EB1-256-fold-2-auc.h5
# ...
# Epoch 00006: val_loss did not improve from 0.27195
#
# Epoch 00006: val_auc improved from 0.90724 to 0.90874, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 356ms/step - loss: 0.3597 - auc: 0.9411 - val_loss: 0.2746 - val_auc: 0.9087
# Epoch 7/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3403 - auc: 0.9506
# Epoch 00007: val_loss improved from 0.27195 to 0.25816, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00007: val_auc improved from 0.90874 to 0.93298, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 357ms/step - loss: 0.3403 - auc: 0.9506 - val_loss: 0.2582 - val_auc: 0.9330
# Epoch 8/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3311 - auc: 0.9548
# Epoch 00008: val_loss did not improve from 0.25816
#
# Epoch 00008: val_auc improved from 0.93298 to 0.93661, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 217s 363ms/step - loss: 0.3311 - auc: 0.9548 - val_loss: 0.2636 - val_auc: 0.9366
# Epoch 9/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3112 - auc: 0.9615
# Epoch 00009: val_loss did not improve from 0.25816
#
# Epoch 00009: val_auc did not improve from 0.93661
# 598/598 [==============================] - 211s 353ms/step - loss: 0.3112 - auc: 0.9615 - val_loss: 0.2622 - val_auc: 0.9350
# Epoch 10/50
# 598/598 [==============================] - ETA: 0s - loss: 0.3058 - auc: 0.9646
# Epoch 00010: val_loss improved from 0.25816 to 0.23731, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00010: val_auc improved from 0.93661 to 0.94135, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 221s 369ms/step - loss: 0.3058 - auc: 0.9646 - val_loss: 0.2373 - val_auc: 0.9414
# Epoch 11/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2942 - auc: 0.9681
# Epoch 00011: val_loss improved from 0.23731 to 0.21950, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00011: val_auc improved from 0.94135 to 0.94833, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2942 - auc: 0.9681 - val_loss: 0.2195 - val_auc: 0.9483
# Epoch 12/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2815 - auc: 0.9724
# Epoch 00012: val_loss improved from 0.21950 to 0.21711, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00012: val_auc improved from 0.94833 to 0.95300, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2815 - auc: 0.9724 - val_loss: 0.2171 - val_auc: 0.9530
# Epoch 13/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2786 - auc: 0.9732
# Epoch 00013: val_loss did not improve from 0.21711
#
# Epoch 00013: val_auc improved from 0.95300 to 0.95605, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2786 - auc: 0.9732 - val_loss: 0.2229 - val_auc: 0.9560
# Epoch 14/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2735 - auc: 0.9747
# Epoch 00014: val_loss did not improve from 0.21711
#
# Epoch 00014: val_auc did not improve from 0.95605
# 598/598 [==============================] - 208s 348ms/step - loss: 0.2735 - auc: 0.9747 - val_loss: 0.2235 - val_auc: 0.9525
# Epoch 15/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2681 - auc: 0.9766
# Epoch 00015: val_loss did not improve from 0.21711
#
# Epoch 00015: val_auc improved from 0.95605 to 0.96208, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2681 - auc: 0.9766 - val_loss: 0.2257 - val_auc: 0.9621
# Epoch 16/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2629 - auc: 0.9779
# Epoch 00016: val_loss did not improve from 0.21711
#
# Epoch 00016: val_auc did not improve from 0.96208
# 598/598 [==============================] - 212s 354ms/step - loss: 0.2629 - auc: 0.9779 - val_loss: 0.2212 - val_auc: 0.9593
# Epoch 17/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2575 - auc: 0.9790
# Epoch 00017: val_loss improved from 0.21711 to 0.21585, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00017: val_auc did not improve from 0.96208
# 598/598 [==============================] - 222s 372ms/step - loss: 0.2575 - auc: 0.9790 - val_loss: 0.2158 - val_auc: 0.9609
# Epoch 18/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2560 - auc: 0.9799
# Epoch 00018: val_loss improved from 0.21585 to 0.20795, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00018: val_auc did not improve from 0.96208
# 598/598 [==============================] - 220s 368ms/step - loss: 0.2560 - auc: 0.9799 - val_loss: 0.2079 - val_auc: 0.9584
# Epoch 19/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2523 - auc: 0.9809
# Epoch 00019: val_loss did not improve from 0.20795
#
# Epoch 00019: val_auc improved from 0.96208 to 0.96430, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 222s 372ms/step - loss: 0.2523 - auc: 0.9809 - val_loss: 0.2140 - val_auc: 0.9643
# Epoch 20/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2506 - auc: 0.9810
# Epoch 00020: val_loss did not improve from 0.20795
#
# Epoch 00020: val_auc did not improve from 0.96430
# 598/598 [==============================] - 222s 371ms/step - loss: 0.2506 - auc: 0.9810 - val_loss: 0.2086 - val_auc: 0.9622
# Epoch 21/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2511 - auc: 0.9812
# Epoch 00021: val_loss did not improve from 0.20795
#
# Epoch 00021: val_auc did not improve from 0.96430
# 598/598 [==============================] - 231s 387ms/step - loss: 0.2511 - auc: 0.9812 - val_loss: 0.2128 - val_auc: 0.9519
# Epoch 22/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2512 - auc: 0.9810
# Epoch 00022: val_loss improved from 0.20795 to 0.20433, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00022: val_auc did not improve from 0.96430
# 598/598 [==============================] - 222s 370ms/step - loss: 0.2512 - auc: 0.9810 - val_loss: 0.2043 - val_auc: 0.9615
# Epoch 23/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2457 - auc: 0.9826
# Epoch 00023: val_loss did not improve from 0.20433
#
# Epoch 00023: val_auc did not improve from 0.96430
# 598/598 [==============================] - 221s 370ms/step - loss: 0.2457 - auc: 0.9826 - val_loss: 0.2157 - val_auc: 0.9431
# Epoch 24/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2486 - auc: 0.9819
# Epoch 00024: val_loss did not improve from 0.20433
#
# Epoch 00024: val_auc did not improve from 0.96430
# 598/598 [==============================] - 222s 371ms/step - loss: 0.2486 - auc: 0.9819 - val_loss: 0.2155 - val_auc: 0.9631
# Epoch 25/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2417 - auc: 0.9834
# Epoch 00025: val_loss did not improve from 0.20433
#
# Epoch 00025: val_auc did not improve from 0.96430
# 598/598 [==============================] - 219s 367ms/step - loss: 0.2417 - auc: 0.9834 - val_loss: 0.2114 - val_auc: 0.9622
# Epoch 26/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2456 - auc: 0.9829
# Epoch 00026: val_loss did not improve from 0.20433
#
# Epoch 00026: val_auc did not improve from 0.96430
# 598/598 [==============================] - 225s 376ms/step - loss: 0.2456 - auc: 0.9829 - val_loss: 0.2120 - val_auc: 0.9576
# Epoch 27/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2423 - auc: 0.9835
# Epoch 00027: val_loss improved from 0.20433 to 0.20429, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00027: val_auc did not improve from 0.96430
# 598/598 [==============================] - 214s 358ms/step - loss: 0.2423 - auc: 0.9835 - val_loss: 0.2043 - val_auc: 0.9521
# Epoch 28/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2449 - auc: 0.9828
# Epoch 00028: val_loss improved from 0.20429 to 0.20415, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00028: val_auc improved from 0.96430 to 0.96582, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2449 - auc: 0.9828 - val_loss: 0.2041 - val_auc: 0.9658
# Epoch 29/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2463 - auc: 0.9826
# Epoch 00029: val_loss did not improve from 0.20415
#
# Epoch 00029: val_auc did not improve from 0.96582
# 598/598 [==============================] - 221s 370ms/step - loss: 0.2463 - auc: 0.9826 - val_loss: 0.2372 - val_auc: 0.9547
# Epoch 30/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2458 - auc: 0.9827
# Epoch 00030: val_loss improved from 0.20415 to 0.20271, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00030: val_auc improved from 0.96582 to 0.96668, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 236s 395ms/step - loss: 0.2458 - auc: 0.9827 - val_loss: 0.2027 - val_auc: 0.9667
# Epoch 31/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2394 - auc: 0.9843
# Epoch 00031: val_loss improved from 0.20271 to 0.19855, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00031: val_auc improved from 0.96668 to 0.97035, saving model to ./cv_folds/EB1-256-fold-4-auc.h5
# 598/598 [==============================] - 217s 364ms/step - loss: 0.2394 - auc: 0.9843 - val_loss: 0.1986 - val_auc: 0.9704
# Epoch 32/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2440 - auc: 0.9827
# Epoch 00032: val_loss did not improve from 0.19855
#
# Epoch 00032: val_auc did not improve from 0.97035
# 598/598 [==============================] - 222s 371ms/step - loss: 0.2440 - auc: 0.9827 - val_loss: 0.2025 - val_auc: 0.9610
# Epoch 33/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2405 - auc: 0.9840
# Epoch 00033: val_loss did not improve from 0.19855
#
# Epoch 00033: val_auc did not improve from 0.97035
# 598/598 [==============================] - 221s 369ms/step - loss: 0.2405 - auc: 0.9840 - val_loss: 0.2030 - val_auc: 0.9538
# Epoch 34/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2423 - auc: 0.9835
# Epoch 00034: val_loss improved from 0.19855 to 0.19284, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00034: val_auc did not improve from 0.97035
# 598/598 [==============================] - 219s 366ms/step - loss: 0.2423 - auc: 0.9835 - val_loss: 0.1928 - val_auc: 0.9657
# Epoch 35/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2402 - auc: 0.9838
# Epoch 00035: val_loss did not improve from 0.19284
#
# Epoch 00035: val_auc did not improve from 0.97035
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2402 - auc: 0.9838 - val_loss: 0.2030 - val_auc: 0.9543
# Epoch 36/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2416 - auc: 0.9837
# Epoch 00036: val_loss did not improve from 0.19284
#
# Epoch 00036: val_auc did not improve from 0.97035
# 598/598 [==============================] - 224s 374ms/step - loss: 0.2416 - auc: 0.9837 - val_loss: 0.1949 - val_auc: 0.9565
# Epoch 37/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2383 - auc: 0.9841
# Epoch 00037: val_loss did not improve from 0.19284
#
# Epoch 00037: val_auc did not improve from 0.97035
# 598/598 [==============================] - 223s 372ms/step - loss: 0.2383 - auc: 0.9841 - val_loss: 0.5320 - val_auc: 0.9556
# Epoch 38/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2401 - auc: 0.9839
# Epoch 00038: val_loss did not improve from 0.19284
#
# Epoch 00038: val_auc did not improve from 0.97035
# 598/598 [==============================] - 234s 391ms/step - loss: 0.2401 - auc: 0.9839 - val_loss: 0.1950 - val_auc: 0.9575
# Epoch 39/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2367 - auc: 0.9847
# Epoch 00039: val_loss did not improve from 0.19284
#
# Epoch 00039: val_auc did not improve from 0.97035
# 598/598 [==============================] - 224s 374ms/step - loss: 0.2367 - auc: 0.9847 - val_loss: 0.1996 - val_auc: 0.9661
# Epoch 40/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2418 - auc: 0.9836
# Epoch 00040: val_loss did not improve from 0.19284
#
# Epoch 00040: val_auc did not improve from 0.97035
# 598/598 [==============================] - 228s 381ms/step - loss: 0.2418 - auc: 0.9836 - val_loss: 0.1958 - val_auc: 0.9666
# Epoch 41/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2419 - auc: 0.9837
# Epoch 00041: val_loss did not improve from 0.19284
#
# Epoch 00041: val_auc did not improve from 0.97035
# 598/598 [==============================] - 226s 379ms/step - loss: 0.2419 - auc: 0.9837 - val_loss: 0.1967 - val_auc: 0.9601
# Epoch 42/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2374 - auc: 0.9846
# Epoch 00042: val_loss did not improve from 0.19284
#
# Epoch 00042: val_auc did not improve from 0.97035
# 598/598 [==============================] - 225s 377ms/step - loss: 0.2374 - auc: 0.9846 - val_loss: 0.2425 - val_auc: 0.9429
# Epoch 43/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2396 - auc: 0.9842
# Epoch 00043: val_loss did not improve from 0.19284
#
# Epoch 00043: val_auc did not improve from 0.97035
# 598/598 [==============================] - 230s 385ms/step - loss: 0.2396 - auc: 0.9842 - val_loss: 0.1963 - val_auc: 0.9659
# Epoch 44/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2372 - auc: 0.9843
# Epoch 00044: val_loss did not improve from 0.19284
#
# Epoch 00044: val_auc did not improve from 0.97035
# 598/598 [==============================] - 232s 388ms/step - loss: 0.2372 - auc: 0.9843 - val_loss: 0.1931 - val_auc: 0.9632
# Epoch 45/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2377 - auc: 0.9848
# Epoch 00045: val_loss improved from 0.19284 to 0.19051, saving model to ./cv_folds/EB1-256-fold-4-loss.h5
#
# Epoch 00045: val_auc did not improve from 0.97035
# 598/598 [==============================] - 228s 381ms/step - loss: 0.2377 - auc: 0.9848 - val_loss: 0.1905 - val_auc: 0.9574
# Epoch 46/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2377 - auc: 0.9848
# Epoch 00046: val_loss did not improve from 0.19051
#
# Epoch 00046: val_auc did not improve from 0.97035
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2377 - auc: 0.9848 - val_loss: 0.1953 - val_auc: 0.9611
# Epoch 47/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2399 - auc: 0.9840
# Epoch 00047: val_loss did not improve from 0.19051
#
# Epoch 00047: val_auc did not improve from 0.97035
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2399 - auc: 0.9840 - val_loss: 0.1920 - val_auc: 0.9640
# Epoch 48/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2315 - auc: 0.9858
# Epoch 00048: val_loss did not improve from 0.19051
#
# Epoch 00048: val_auc did not improve from 0.97035
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2315 - auc: 0.9858 - val_loss: 0.1920 - val_auc: 0.9588
# Epoch 49/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2377 - auc: 0.9847
# Epoch 00049: val_loss did not improve from 0.19051
#
# Epoch 00049: val_auc did not improve from 0.97035
# 598/598 [==============================] - 212s 355ms/step - loss: 0.2377 - auc: 0.9847 - val_loss: 0.1944 - val_auc: 0.9569
# Epoch 50/50
# 598/598 [==============================] - ETA: 0s - loss: 0.2369 - auc: 0.9844
# Epoch 00050: val_loss did not improve from 0.19051
#
# Epoch 00050: val_auc did not improve from 0.97035
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2369 - auc: 0.9844 - val_loss: 0.1993 - val_auc: 0.9595
# Loading best model...
# Predicting OOF with TTA...
# 1214/1213 [==============================] - 112s 93ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 184s 171ms/step
# #### FOLD 5 OOF AUC without TTA = 0.970, with TTA = 0.973
# Meta only AUC: 0.6921550338217004
# The best weight is 0.0, Meta and OOF AUC with TTA: 0.973

# %% [markdown]
# #### Show the optimal characteristics from CV

# %%
best_epoch_val_auc_mean = np.mean(np.array(best_epoch_val_auc_ls), axis=0)
best_epoch_val_loss_mean = np.mean(np.array(best_epoch_val_loss_ls), axis=0)

print("The best epoch value for AUC over the cv is: ",best_epoch_val_auc_mean)
print("The best epoch value for loss over the cv is: ",best_epoch_val_loss_mean)
# Out:
# The best epoch value for AUC over the cv is:  34.8
# The best epoch value for loss over the cv is:  40.4

# %%
cv_val_auc_mean = np.mean(np.array(best_val_auc_ls), axis=0)
cv_val_auc_std = np.std(np.array(best_val_auc_ls), axis=0)
cv_val_loss_mean = np.mean(np.array(best_val_loss_ls), axis=0)

print(f"The mean AUC score across CV folds is {cv_val_auc_mean:.2f} and the standard deviation is {cv_val_auc_std:.2%}")
# Out:
# The mean AUC score across CV folds is 0.97 and the standard deviation is 0.39%

# %% [markdown]
# #### Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred)
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names)
folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{CV_OOF_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.976
#      image_name  target      pred  fold
# 0  ISIC_9203914       0  0.051709     0
# 1  ISIC_1215482       0  0.020066     0
# 2  ISIC_0348633       0  0.023695     0
# 3  ISIC_4045781       0  0.021452     0
# 4  ISIC_9965556       0  0.028700     0

# %% [markdown]
# #### Calculate OOF AUC with Tabular Data
# Utilising a simple prediction model on the tabular data should add additional information when blending. This can be tested with the OOF data.

# %%
best_wgt = []
best_auc = []
for best in best_meta_wgts:
    best_wgt.append(best[0])
    best_auc.append(best[1])
avg_wgt = sum(best_wgt)/len(best_wgt)
avg_auc = sum(best_auc)/len(best_auc)
print(f"Average of best meta weights = {avg_wgt:.2f}")
print(f"Overall OOF and Meta AUC with TTA = {avg_auc:.3f}")
# Out:
# Average of best meta weights = 0.03
# Overall OOF and Meta AUC with TTA = 0.976

# %% [markdown]
# ### Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.

# %% [markdown]
# ### Log values from the cross validation process

# %%
if ENV == 'LOCAL':
    log_df = pd.read_csv('./logs/experiment_log.csv')
    headers = list(log_df.columns.values)
    
if ENV == 'KAGGLE':
    headers = ['Image Size',
             'Model',
             '2018 Data',
             'Batch Size',
             'Replicas',
             'Total Batch Size',
             'TTA Loops',
             'CV Folds',
             'Mean CV AUC',
             'Std CV AUC',
             'OOF AUC with TTA',
             'OOF AUC and Meta with TTA',
             'Best average Meta weighting' , 
             'Mean CV Loss',
             'Total Epochs',
             'Early Stop',
             'Best AUC Epoch',
             'Best Loss Epoch',
             'Kaggle LB AUC',
             'Kaggle LB AUC w Meta']
    log_df = pd.DataFrame(columns = headers)

# %%
log_items = [IMG_SIZES[0],
            str(f"EFNB{EFF_NETS[0]}"),
            INC2018[0],
            BATCH_SIZES[0],
            REPLICAS,
            BATCH_SIZES[0] * REPLICAS,
            TTA,
            FOLDS,
            cv_val_auc_mean,
            cv_val_auc_std, 
            auc,
            avg_auc,
            avg_wgt,
            cv_val_loss_mean,
            EPOCHS[0],
            EARLY_STOPPING,
            best_epoch_val_auc_mean,
            best_epoch_val_loss_mean,
            0.00,
            0.00]

# %%
for n in range(len(headers)):
    print(headers[n]+":", log_items[n])
    
log_data = pd.DataFrame([log_items], columns=headers)
log_df = log_df.append(log_data)
log_df.sort_values(by=['Model','Image Size'], inplace=True)
log_df.to_csv(f'{LOG_PATH}experiment_log.csv', index=False)
log_df.head(50)
# Out:
# Image Size: 256
# Model: EFNB1
# 2018 Data: 1
# Batch Size: 32
# Replicas: 2
# Total Batch Size: 64
# TTA Loops: 25
# CV Folds: 5
# Mean CV AUC: 0.9723212480545044
# Std CV AUC: 0.0038982342517774643
# OOF AUC with TTA: 0.9759869394323469
# OOF AUC and Meta with TTA: 0.9759061581187719
# Best average Meta weighting: 0.028000000000000004
# Mean CV Loss: 0.19467427730560302
# Total Epochs: 50
# Early Stop: 0
# Best AUC Epoch: 34.8
# Best Loss Epoch: 40.4
# Kaggle LB AUC: 0.0
# Kaggle LB AUC w Meta: 0.0
#     Image Size     Model  2018 Data  Batch Size  Replicas  Total Batch Size  \
# 0          128     EFNB0          1         256         1               256
# 1          128     EFNB0          1         128         1               128
# 2          128     EFNB0          1         128         1               128
# 3          128     EFNB0          1         128         1               128
# 4          128     EFNB0          0         256         1               256
# 5          128     EFNB0          0         256         1               256
# 6          128     EFNB0          1         128         1               128
# 7          128     EFNB0          1         128         1               128
# 8          128     EFNB0          1          64         1                64
# 9          128     EFNB0          0         256         1               256
# 10         128     EFNB0          0         128         1               128
# 11         128     EFNB0          1         128         1               128
# 12         128     EFNB0          0         256         1               256
# 13         192     EFNB0          0         128         1               128
# 14         192     EFNB0          1          64         2               128
# 15         256     EFNB0          1         128         1               128
# 16         256     EFNB0          1         128         1               128
# 17         256     EFNB0          0         128         1               128
# 18         128  EFNB0EXP          1         128         1               128
# 19         192  EFNB0EXP          1          64         2               128
# 20         128     EFNB1          0         128         1               128
# 21         192     EFNB1          1         128         1               128
# 22         192     EFNB1          0         128         1               128
# 23         256     EFNB1          1          64         1                64
# 24         256     EFNB1          0          64         1                64
# 0          256     EFNB1          1          32         2                64
# 25         256  EFNB1EXP          1          32         2                64
# 26         256     EFNB2          1          64         1                64
# 27         256     EFNB2          1          64         1                64
# 28         256     EFNB2          1          64         1                64
# 29         256     EFNB2          1          64         1                64
# 30         256     EFNB2          0          64         1                64
# 31         256     EFNB2          1          64         8               512
# 32         384     EFNB2          0         128         1               128
# 33         512     EFNB2          0          64         8               512
# 34         256  EFNB2EXP          1          64         1                64
# 35         256  EFNB2EXP          1          64         1                64
# 36         192     EFNB3          0          32         1                32
# 37         256     EFNB3          0          16         1                16
# 38         384     EFNB3          0           8         1                 8
# 39         384     EFNB3          0         128         8              1024
# 40         384     EFNB3          1          16         1                16
# 41         384  EFNB3EXP          1           8         2                16
# 42         256     EFNB4          0          32         1                32
# 43         384     EFNB4          0          16         1                16
# 44         384     EFNB4          1         128         8              1024
# 45         384     EFNB4          0         128         8              1024
# 46         512     EFNB4          0          64         8               512
# 47         512     EFNB5          0          32         8               256
# 48         512     EFNB6          0           8         8                64
#
#     TTA Loops  CV Folds  Mean CV AUC  Std CV AUC  OOF AUC with TTA  \
# 0          25         5     0.862810    0.015301          0.899221
# 1          25         5     0.893108    0.009577          0.896964
# 2          25         5     0.894638    0.016115          0.899087
# 3          25         5     0.891281    0.012457          0.897615
# 4          25         5     0.858138    0.017181          0.892846
# 5          25         5     0.862265    0.021282          0.891697
# 6          25         3     0.868520    0.007854          0.891658
# 7          25         5     0.860609    0.011030          0.888065
# 8          25         5     0.892140    0.012269          0.881596
# 9          25         5     0.862378    0.000000          0.892097
# 10         50         5     0.869673    0.020289          0.893746
# 11         25         5     0.870027    0.019537          0.893820
# 12         25         5     0.862576    0.017381          0.895973
# 13         25         5     0.869117    0.000000          0.899562
# 14         25         5     0.902529    0.008819          0.906529
# 15         25         5     0.905725    0.013085          0.913515
# 16         25         5     0.880362    0.021434          0.911405
# 17         25         5     0.881442    0.000000          0.905685
# 18         25         5     0.912633    0.002593          0.912759
# 19         25         5     0.902832    0.004064          0.910726
# 20         25         5     0.857287    0.015800          0.890922
# 21         25         5     0.885721    0.022526          0.902849
# 22         25         5     0.872257    0.024584          0.898725
# 23         25         5     0.894408    0.012953          0.912732
# 24         25         5     0.886249    0.010748          0.907220
# 0          25         5     0.972321    0.003898          0.975987
# 25         25         5     0.955029    0.018500          0.962169
# 26         25         5     0.956336    0.007296          0.961748
# 27         25         5     0.903819    0.017790          0.913861
# 28         25         5     0.888146    0.020124          0.909704
# 29         25         5     0.889753    0.014140          0.915927
# 30         25         5     0.884384    0.009332          0.909386
# 31         25         5     0.910257    0.010415          0.921064
# 32         25         5     0.828881    0.038663          0.842111
# 33         25         5     0.886565    0.012560          0.879694
# 34         25         5     0.938519    0.000000          0.946079
# 35         25         5     0.925376    0.021439          0.945415
# 36         25         5     0.867541    0.012185          0.898843
# 37         25         5     0.871538    0.011266          0.904422
# 38         25         5     0.876217    0.016871          0.898717
# 39         25         5     0.874759    0.019894          0.883070
# 40         25         5     0.898124    0.013586          0.910307
# 41         25         5     0.905761    0.005587          0.912990
# 42         25         5     0.889665    0.013592          0.914790
# 43         25         5     0.893494    0.025733          0.909297
# 44         25         5     0.896319    0.008178          0.902081
# 45         25         5     0.890323    0.009456          0.905070
# 46         25         5     0.885838    0.021590          0.876753
# 47         25         5     0.903188    0.015500          0.887710
# 48         25         3     0.889957    0.010651          0.890717
#
#     OOF AUC and Meta with TTA  Best average Meta weighting  Mean CV Loss  \
# 0                    0.899624                     0.028000      0.164090
# 1                    0.899278                     0.186000      0.471082
# 2                    0.899203                     0.074000      0.234308
# 3                    0.898825                     0.260000      0.430066
# 4                    0.893437                     0.058000      0.165035
# 5                    0.893361                     0.050000      0.164463
# 6                    0.891997                     0.013333      0.164465
# 7                    0.889803                     0.030000      0.164579
# 8                    0.883801                     0.106000      0.251114
# 9                    0.000000                     0.000000      0.164595
# 10                   0.000000                     0.000000      0.164480
# 11                   0.000000                     0.000000      0.163722
# 12                   0.000000                     0.000000      0.164683
# 13                   0.000000                     0.000000      0.163387
# 14                   0.914878                     0.156000      0.212644
# 15                   0.914208                     0.172000      0.365035
# 16                   0.000000                     0.000000      0.161010
# 17                   0.000000                     0.000000      0.162524
# 18                   0.918679                     0.290000      0.472791
# 19                   0.911090                     0.000000      0.245847
# 20                   0.000000                     0.000000      0.164851
# 21                   0.000000                     0.000000      0.162546
# 22                   0.000000                     0.000000      0.163616
# 23                   0.000000                     0.000000      0.160833
# 24                   0.000000                     0.000000      0.162028
# 0                    0.975906                     0.028000      0.194674
# 25                   0.962298                     0.164000      0.208217
# 26                   0.962125                     0.038000      0.200851
# 27                   0.914280                     0.078000      0.207408
# 28                   0.910367                     0.050000      0.161091
# 29                   0.000000                     0.000000      0.161170
# 30                   0.000000                     0.000000      0.161911
# 31                   0.924116                     0.062000      0.179513
# 32                   0.000000                     0.000000      0.165045
# 33                   0.000000                     0.000000      0.161943
# 34                   0.946689                     0.180000      0.219144
# 35                   0.945607                     0.110000      0.213297
# 36                   0.000000                     0.000000      0.163563
# 37                   0.000000                     0.000000      0.162711
# 38                   0.000000                     0.000000      0.163969
# 39                   0.000000                     0.000000      0.161846
# 40                   0.000000                     0.000000      0.161235
# 41                   0.913461                     0.000000      0.237265
# 42                   0.000000                     0.000000      0.161829
# 43                   0.000000                     0.000000      0.161644
# 44                   0.000000                     0.000000      0.159346
# 45                   0.000000                     0.000000      0.161675
# 46                   0.000000                     0.000000      0.162841
# 47                   0.000000                     0.000000      0.161710
# 48                   0.000000                     0.000000      0.162821
#
#     Total Epochs  Early Stop  Best AUC Epoch  Best Loss Epoch  Kaggle LB AUC  \
# 0             12           0        8.800000         9.400000         0.0000
# 1             12           0       10.400000        10.400000         0.0000
# 2             12           0        9.200000         8.000000         0.0000
# 3             12           0       10.000000         9.000000         0.0000
# 4             12           0        7.400000         9.400000         0.0000
# 5             12           0        9.200000         9.400000         0.0000
# 6             20           0       10.000000        15.000000         0.0000
# 7             12           0        8.200000         9.800000         0.0000
# 8             15           0       12.000000         6.140000            NaN
# 9             15           1        9.400000        10.200000         0.0000
# 10            30           0       12.600000        11.400000         0.0000
# 11            15           0        8.800000        10.000000         0.0000
# 12            20           0        9.400000        12.000000         0.0000
# 13            15           1        9.800000        10.200000         0.0000
# 14            50           0       11.800000        31.800000         0.0000
# 15            12           0        8.600000         9.400000         0.0000
# 16            15           0        7.800000        12.000000         0.0000
# 17            15           1        9.400000        11.200000         0.0000
# 18            12           0        9.000000         9.666667         0.0000
# 19            20           0       10.666667        15.166667         0.0000
# 20            15           1       12.200000        11.200000         0.0000
# 21            15           0       10.200000         9.800000         0.0000
# 22            15           1       10.600000        10.800000         0.0000
# 23            15           0        8.800000        13.400000         0.0000
# 24            15           1        9.600000        10.200000         0.0000
# 0             50           0       34.800000        40.400000         0.0000
# 25            60           0       43.600000        41.800000         0.0000
# 26            17           0       15.600000        10.400000         0.0000
# 27            12           0        7.200000         7.800000         0.0000
# 28            20           0       10.600000        10.600000         0.0000
# 29            15           0        9.200000        11.000000         0.9377
# 30            15           1        9.600000         9.400000         0.9296
# 31            20           0       14.000000         5.800000         0.9413
# 32            15           1       11.200000        11.400000         0.0000
# 33            15           1        8.200000         8.600000         0.0000
# 34            20           0       14.000000        17.000000         0.0000
# 35            15           0       11.800000        13.800000         0.0000
# 36            20           1        8.800000        10.400000         0.0000
# 37            15           1       11.600000        11.600000         0.0000
# 38            15           1        8.800000        10.200000         0.9235
# 39            20           0       13.000000        13.800000         0.9181
# 40            15           0       10.000000        11.600000         0.9467
# 41            20           0       14.666667        14.500000         0.0000
# 42            15           1       12.400000        12.800000         0.9262
# 43            15           1        9.800000        12.000000         0.0000
# 44            20           0       14.400000        11.200000         0.9350
# 45            20           0       17.000000        16.200000         0.9357
# 46            15           1        7.400000         7.600000         0.0000
# 47            15           1        5.800000         5.600000         0.9383
# 48            15           1       11.666667        10.666667         0.9358
#
#     Kaggle LB AUC w Meta
# 0                 0.0000
# 1                 0.0000
# 2                 0.0000
# 3                 0.0000
# 4                 0.0000
# 5                 0.0000
# 6                 0.0000
# 7                 0.0000
# 8                    NaN
# 9                 0.0000
# 10                0.0000
# 11                0.0000
# 12                0.0000
# 13                0.0000
# 14                0.0000
# 15                0.0000
# 16                0.0000
# 17                0.0000
# 18                0.0000
# 19                0.0000
# 20                0.0000
# 21                0.0000
# 22                0.0000
# 23                0.0000
# 24                0.0000
# 0                 0.0000
# 25                0.0000
# 26                0.9428
# 27                0.9361
# 28                0.9407
# 29                0.0000
# 30                0.0000
# 31                0.9438
# 32                0.0000
# 33                0.0000
# 34                0.0000
# 35                0.0000
# 36                0.0000
# 37                0.0000
# 38                0.0000
# 39                0.0000
# 40                0.0000
# 41                0.0000
# 42                0.0000
# 43                0.0000
# 44                0.0000
# 45                0.0000
# 46                0.0000
# 47                0.0000
# 48                0.0000

# %% [markdown]
# ### Prepare Kaggle File

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}FCV-submission.csv', index=False)
submission.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.032354
# 723   ISIC_0052349  0.019547
# 1560  ISIC_0058510  0.015933
# 2438  ISIC_0073313  0.021307
# 2750  ISIC_0073502  0.017692

# %%
submission_meta = pd.DataFrame(dict(image_name=image_names, target=preds_meta_ls[:,0]))
submission_meta = submission_meta.sort_values('image_name') 
submission_meta.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}FCV-META-submission.csv', index=False)
submission_meta.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.038699
# 723   ISIC_0052349  0.019712
# 1560  ISIC_0058510  0.017384
# 2438  ISIC_0073313  0.022721
# 2750  ISIC_0073502  0.019565

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
plt.hist(submission_meta.target,bins=100)
plt.show()
