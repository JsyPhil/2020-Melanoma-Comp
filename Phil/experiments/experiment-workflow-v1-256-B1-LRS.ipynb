# %% [markdown]
# ## Experiment Workflow Notebook v1

# %% [markdown]
# #### Sources of information, code and discussions

# %% [markdown]
# 1. This notebook follows the 5 step process presented in the Chris Deotte "How to compete with GPUs Workshop" [here][1].
# 2. Triple stratified KFold TFRecords used for image data is explained [here][2].
# 3. Some code sections have been reused from AgentAuers' notebook [here][3]
# 4. The advantage of using different input sizes is discussed [here][4]
# 5. Use external data by changing the variables `INC2019` and `INC2018`.These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][5]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [4]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147
# [5]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %% [markdown]
# #### Train Experiments
# In this notebook we run 6 experiments.
# * Experiment 1 - baseline - no upsample or dropout but with class balance and 2018 data
# * Experiment 2 - upsample 2020 and 2018 malignant
# * Experiment 3 - upsample all
# * Experiment 4 - add minor dropout
# * Experiment 5 - add major dropout
#
# This note book will repeatedly run experiments on the same KFold fold. Each experiment will be trained for the number of EPOCHS you chose in the configuration above. Each experiment the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %% [markdown]
# ####  Initiatialise environment and import necessary libraries

# %%
# Use if running in Kaggle environment
#!pip install -q efficientnet >> /dev/null

# %%
# import KaggleDatasets if running in Kaggle environment
#from kaggle_datasets import KaggleDatasets

import os, re, math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K

import efficientnet.tfkeras as efn

from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score 
from sklearn.utils import class_weight

# %% [markdown]
# ## Configuration
#
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 for conistent number of train and validation samples across folds
# * IMG_SIZES - These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter. Consider early stopping in Callbacks.
# * EFF_NETS - These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.
#
# ### New Variables
# * EXPERIMENTS - number of experiments to perform
# * FNUMBER - which of the KFolds to repeatedly perform experiments on.
# * M1 - is a list of length EXPERIMENTS. For each experiment, choose 0, 1, 2, 3, etc. Determines how many additional copies of malignant images from this years comp data to add
# * M2 - is a list. Adds copies of malignant images from ISIC archive that are not in 2020, 2019, 2018, 2017 comp data
# * M3 - is a list. Adds copies of malignant images from 2019 comp data. They have been filtered to include the ones that look like 2020 data
# * M4 - is a list. Adds copies of malignant images from 2018 2017 data.
# * DROP_FREQ - a list of floats between 0 and 1. Determines proportion of train images to apply coarse dropout to
# * DROP_CT - a list of ints. How many squares to remove from train images when applying dropout. (Note that if you use CT>16 with FREQ=1, it may slow down training when using small image resolutions like 128x128 if your CPU is slow).
# * DROP_SIZE - a list of floats between 0 and 1. The size of square side equals `IMG_SIZE * DROP_SIZE`
# * INFER_TEST - whether to predict test images each experiment

# %% [markdown]
# Image sizes used in the Efficientnet model:
#
# - efficientnet-b0-224 -cv train with 192
# - efficientnet-b1-240 -cv train with 256
# - efficientnet-b2-260 -cv train with 256
# - efficientnet-b3-300 -cv train with 384
# - efficientnet-b4-380 -cv train with 384
# - efficientnet-b5-456 -cv train with 512
# - efficientnet-b6-528 -cv train with 512
# - efficientnet-b7-600 -cv train with 768
#
# Better to train with a larger size and let the model scale down rather than up.

# %%
ENV = "LOCAL" #or "KAGGLE"

# DEFAULT TO TPU TO ENSURE KAGGLE TPU COMPATIABILITY
# https://www.kaggle.com/docs/tpu
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 45

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH FOLD SET TO PERFORM EXPERIMENTS ON
FNUMBER = 5; EXPERIMENTS = 5

# UPSAMPLE MALIGNANT COUNT TIMES
M1 = [0,1,1,1,1] #2020 malig
M2 = [0,0,1,1,1] #ISIC malig
M3 = [0,0,1,1,1] #2019 good malig
M4 = [0,1,1,1,1] #2018 2017 malig

# COARSE DROPOUT
DROP_FREQ = [0,0,0,0.5,0.75] # between 0 and 1
DROP_CT = [0,0,0,4,8] # may slow training if CT>16
DROP_SIZE = [0,0,0,0.1,0.2] # between 0 and 1

print("Check:", (len(M1)+len(M2)+len(M3)+len(M4)+len(DROP_FREQ)+len(DROP_CT)+len(DROP_SIZE))/7/EXPERIMENTS)

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 
IMG_SIZES = [256]*EXPERIMENTS

# META DATA? YES=1 NO=0
META = 1

# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0]*EXPERIMENTS
INC2018 = [1]*EXPERIMENTS

# BATCH SIZE AND EPOCHS
# TRY 8, 16, 32, 64, 128, 256. REDUCE IF OOM ERROR, HIGHER FOR TPUS
BATCH_SIZES = [32]*EXPERIMENTS
EPOCHS = [60]*EXPERIMENTS
EARLY_STOPPING = 0 # Yes:1, No:0

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [1]*EXPERIMENTS

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/EXPERIMENTS]*EXPERIMENTS

# TEST TIME AUGMENTATION STEPS
TTA = 25
# Out:
# Check: 1.0

# %% [markdown]
# #### Configure environment to use TPUs, Multiple GPUs, Single GPU or just CPU

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and GPU")
    

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    if len(tf.config.experimental.list_physical_devices('GPU')) > 1:
        strategy = tf.distribute.MirroredStrategy()
    else:
        strategy = tf.distribute.get_strategy()
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync

print(f'REPLICAS: {REPLICAS}')
# Out:
# connecting to TPU...
# Could not connect to TPU
# Using default strategy for CPU and GPU
# Num GPUs Available:  2
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# REPLICAS: 2

# %% [markdown]
# ### Step 1: Preprocess and file handling
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section.

# %%
# Load file locations
if ENV == 'KAGGLE':
    #Use GCS if running in Kaggle environment
    PATH = [None]*EXPERIMENTS; PATH2 = [None]*EXPERIMENTS; PATH3 = [None]*EXPERIMENTS
    for i,k in enumerate(IMG_SIZES[:EXPERIMENTS]):
        PATH[i] = KaggleDatasets().get_gcs_path('melanoma-%ix%i'%(k,k))
        PATH2[i] = KaggleDatasets().get_gcs_path('isic2019-%ix%i'%(k,k))
        PATH3[i] = KaggleDatasets().get_gcs_path('malignant-v2-%ix%i'%(k,k))
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))
       
if ENV == 'LOCAL':  
    # Use LDS if running in local environment
    PATH = [None]*EXPERIMENTS; PATH2 = [None]*EXPERIMENTS; PATH3 = [None]*EXPERIMENTS
    for i,k in enumerate(IMG_SIZES[:EXPERIMENTS]):
        PATH[i] = f"./siim-isic-melanoma-classification/tfrecords{k}"
        PATH2[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Ext"
        PATH3[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Mal"
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))

# %%
# Save file locations
if ENV == 'KAGGLE':
    LOG_PATH = ''
    CV_OOF_PREDS_PATH = ''
    CV_TEST_PREDS_PATH = ''
    CV_FOLDS_PATH = ''

if ENV == 'LOCAL':
    LOG_PATH = './logs/'
    CV_OOF_PREDS_PATH = './cv_oof_preds/'
    CV_TEST_PREDS_PATH = './cv_test_preds/'
    CV_FOLDS_PATH = './cv_folds/'

# %%
# File handling functions
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']

def read_meta_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge'], example['target']

def read_meta_tfrecord_test(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge']

def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
# Function to stream datasets into model when training, validating and predicting
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256,
                droprate=0, dropct=0, dropsize=0):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO)      
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim,
                                               droprate=droprate, dropct=dropct, dropsize=dropsize),
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %%
# Function to stream datasets into model when training, validating and predicting
column_names = ['image_name', 'sex', 'age_approx', 'anatom', 'target']
column_names_test = ['image_name', 'sex', 'age_approx', 'anatom']

def get_meta(files, batch_size=16, test=0):
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    if test:
        ds = ds.map(lambda example: read_meta_tfrecord_test(example), num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_meta_tfrecord(example), num_parallel_calls=AUTO)      
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
        
    return ds

def meta_unbatch(files, test=0):
    if test:
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy()]
                for img_name, sex, age, anatomy in iter(files.unbatch())])
        meta_df = pd.DataFrame(data = meta_np, columns=column_names_test)

    else:        
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy(),
                  target.numpy()] 
                for img_name, sex, age, anatomy, target in iter(files.unbatch())])
        
        meta_df = pd.DataFrame(data = meta_np, columns=column_names)
        meta_df = meta_df.astype({"target": int})
    return meta_df

# %% [markdown]
# ### Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation. This notebook also uses horizontal flip, saturation, contrast, brightness augmentation similar to last years winner.

# %%
# Assign variables
ROT_ = 180.0
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def dropout(image, DIM=256, PROBABILITY = 0.75, CT = 8, SZ = 0.2):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image with CT squares of side size SZ*DIM removed
    
    # DO DROPOUT WITH PROBABILITY DEFINED ABOVE
    P = tf.cast( tf.random.uniform([],0,1)<PROBABILITY, tf.int32)
    if (P==0)|(CT==0)|(SZ==0): return image
    
    for k in range(CT):
        # CHOOSE RANDOM LOCATION
        x = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        y = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        # COMPUTE SQUARE 
        WIDTH = tf.cast( SZ*DIM,tf.int32) * P
        ya = tf.math.maximum(0,y-WIDTH//2)
        yb = tf.math.minimum(DIM,y+WIDTH//2)
        xa = tf.math.maximum(0,x-WIDTH//2)
        xb = tf.math.minimum(DIM,x+WIDTH//2)
        # DROPOUT IMAGE
        one = image[ya:yb,0:xa,:]
        two = tf.zeros([yb-ya,xb-xa,3]) 
        three = image[ya:yb,xb:DIM,:]
        middle = tf.concat([one,two,three],axis=1)
        image = tf.concat([image[0:ya,:,:],middle,image[yb:DIM,:,:]],axis=0)
            
    # RESHAPE HACK SO TPU COMPILER KNOWS SHAPE OF OUTPUT TENSOR 
    image = tf.reshape(image,[DIM,DIM,3])
    return image

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

def prepare_image(img, augment=True, dim=256, droprate=0, dropct=0, dropsize=0):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        if (droprate!=0)&(dropct!=0)&(dropsize!=0): 
            img = dropout(img, DIM=dim, PROBABILITY=droprate, CT=dropct, SZ=dropsize)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

# %% [markdown]
# ### Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN. Also consider different models to provide diversity of predictions which may benefit the final ensemble.

# %%
EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7]

def build_model(dim=128, ef=0, v=0):
    inputs = tf.keras.layers.Input(shape=(dim,dim,3))
    
    base = EFNS[ef](input_shape=(dim,dim,3),weights='noisy-student',include_top=False)
    
    x = base(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=inputs,outputs=x)
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    
    if v:
        model.summary()
    
    return model

# Visualise model in use
build_model(dim=IMG_SIZES[0],ef=EFF_NETS[0],v=1)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnet-b1 (Functional) (None, 8, 8, 1280)        6575232
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1281
# =================================================================
# Total params: 6,576,513
# Trainable params: 6,514,465
# Non-trainable params: 62,048
# _________________________________________________________________

# %%
# META DATA FUNCTION

# Function to get meta data
def meta_model(meta_train, meta_val):
    L = 15
    feat = ['sex','age_approx','anatom']
    M = meta_train.target.mean()
    te = meta_train.groupby(feat)['target'].agg(['mean','count']).reset_index()
    te['ll'] = ((te['mean']*te['count'])+(M*L))/(te['count']+L)
    del te['mean'], te['count']
    meta_val = meta_val.merge( te, on=feat, how='left' )
    meta_val['ll'] = meta_val['ll'].fillna(M)
    return meta_val

# %% [markdown]
# ### Step 4: Training and Cross Validation

# %% [markdown]
# #### Training Schedule
# Thism is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
TS_CFG = dict(
    lr_start   = 0.000006, 
    lr_max     = 0.00000145 * REPLICAS * BATCH_SIZES[0],
    lr_min     = 0.000001,
    lr_ramp_ep = 5,
    lr_sus_ep  = 0,
    lr_decay   = 0.85
    )

# %%
def get_lr_callback(ts_cfg, batch_size=8):
    lr_start   = ts_cfg['lr_start']
    lr_max     = ts_cfg['lr_max']
    lr_min     = ts_cfg['lr_min']
    lr_ramp_ep = ts_cfg['lr_ramp_ep']
    lr_sus_ep  = ts_cfg['lr_sus_ep']
    lr_decay   = ts_cfg['lr_decay']
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    
    return lr_callback

# %% [markdown]
# #### Visualise Training Schedule

# %%
# Quick test and visualisation of learning rate schedule
# Important not to have a high learning rate which would destroy the pre-trained parameters
lr_start   = TS_CFG['lr_start']
lr_max     = TS_CFG['lr_max']
lr_min     = TS_CFG['lr_min']
lr_ramp_ep = TS_CFG['lr_ramp_ep']
lr_sus_ep  = TS_CFG['lr_sus_ep']
lr_decay   = TS_CFG['lr_decay']

def lrfn_sched(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

# Visualise learning rate schedule
rng = [i for i in range(40)]
y = [lrfn_sched(x) for x in rng]
plt.plot(rng, y)
plt.xlabel('epoch', size=14); plt.ylabel('learning rate', size=14)
plt.title('Training Schedule', size=16); plt.show()

# %% [markdown]
# #### Class Imbalance Analysis

# %%
# Analyze class imbalance in the targets
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / (33126-470))*(33126)/2.0 
weight_for_1 = (1 / 470)*(33126)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.51
# Weight for class 1: 35.24

# %% [markdown]
# #### Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    if fold==(FNUMBER-1):
        idxTT = idxT; idxVV = idxV
        print('### Using fold',fold,'for experiments')
    print('Fold',fold,'has TRAIN:',idxT,'VALID:',idxV)
# Out:
# Fold 0 has TRAIN: [ 0  1  2  3  4  5  7 10 11 12 13 14] VALID: [6 8 9]
# Fold 1 has TRAIN: [ 0  1  3  4  5  6  8  9 11 12 13 14] VALID: [ 2  7 10]
# Fold 2 has TRAIN: [ 0  2  3  5  6  7  8  9 10 11 12 13] VALID: [ 1  4 14]
# Fold 3 has TRAIN: [ 1  2  3  4  6  7  8  9 10 11 12 14] VALID: [ 0  5 13]
# ### Using fold 4 for experiments
# Fold 4 has TRAIN: [ 0  1  2  4  5  6  7  8  9 10 13 14] VALID: [ 3 11 12]

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

oof_pred = []
oof_tar = []
oof_val = []
oof_names = []
oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_meta_ls = np.zeros((count_data_items(files_test),1))

best_val_auc_ls = []
best_epoch_val_auc_ls = []

best_val_loss_ls = []
best_epoch_val_loss_ls = []

best_meta_wgts = []

#TESTING ONLY
loops = 0
max_loops = EXPERIMENTS #Use EXPERIMENTS or a number less than FOLDS if testing

for fold in range(EXPERIMENTS):
    # REPEAT SAME FOLD OVER AND OVER
    idxT = idxTT
    idxV = idxVV
    
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25)
    print('#### EXPERIMENT',fold+1)
    print('#'*25)
    print('#### Using the following TFRecords:')
    print(idxT,idxV)
    print(f'#### Image Size {IMG_SIZES[fold]} with EfficientNet B{EFF_NETS[fold]} and batch_size {BATCH_SIZES[fold]*REPLICAS}')
    print(f'#### DropoutFreq {DROP_FREQ[fold]} Count{DROP_CT[fold]} Size {DROP_SIZE[fold]}')
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    for k in range(M1[fold]):
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT])
        print('#### Upsample MALIG-1 data (2020 comp)')
    for k in range(M2[fold]):
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT+15])
        print('#### Upsample MALIG-2 data (ISIC website)')
    for k in range(M3[fold]):
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1+30])
        print('#### Upsample MALIG-3 data (2019 comp)')
    for k in range(M4[fold]):
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+30])
        print('#### Upsample MALIG-4 data (2018 2017 comp)')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(PATH[fold] + '/test*.tfrec')))
    
    # DETERMINE CLASS WEIGHTS FROM TRAINING DATASET
    # Analyze class imbalance in the targets
    # Scaling by total/2 helps keep the loss to a similar magnitude.
    # The sum of the weights of all examples stays the same.
    ft = get_dataset(files_train, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    ott = np.array([target.numpy() for img, target in iter(ft.unbatch())])
    tot = len(ott)
    counts = np.bincount(ott[:])
    
    weight_for_0 = (1 / counts[0])*(tot)/2.0 
    weight_for_1 = (1 / counts[1])*(tot)/2.0
    class_weight = {0: weight_for_0, 1: weight_for_1}
    print('Weight for class 0: {:.2f}'.format(weight_for_0))
    print('Weight for class 1: {:.2f}'.format(weight_for_1))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold],v=0)
        
    # CALLBACKS - SAVE BEST MODEL EACH FOLD ALSO UTILISE EARLY STOPPING TO ALLOW MORE EPOCHS
    svl = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-EXP-loss.h5', monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
    sva = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-EXP-auc.h5', monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    if EARLY_STOPPING:
        es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, verbose=VERBOSE, mode='auto')
        callback_list = [svl, sva, es, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
    else:
        callback_list = [svl, sva, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
   
    # TRAIN
    print('Training and Validation, No Dropout on Validation...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                    dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold],
                    droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]), 
        epochs=EPOCHS[fold],
        callbacks = callback_list, 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=True,shuffle=False,
                                    repeat=False,dim=IMG_SIZES[fold],
                                    droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]),
        class_weight = class_weight,
        verbose=VERBOSE
    )
    
    # DETERMINE BEST SCORES AND EPOCHS
    val_auc_ls = history.history['val_auc']
    val_loss_ls = history.history['val_loss']
    
    best_val_auc = max(val_auc_ls)
    best_val_loss = min(val_loss_ls)
    best_val_auc_ls.append(best_val_auc)
    best_val_loss_ls.append(best_val_loss)
    
    opt_epoch_auc = val_auc_ls.index(best_val_auc)
    opt_epoch_loss = val_loss_ls.index(best_val_loss)
    best_epoch_val_auc_ls.append(opt_epoch_auc)
    best_epoch_val_loss_ls.append(opt_epoch_loss)
    
    #RELOAD BEST WEIGHTS AT BEST EPOCH
    print('Loading best model...')
    model.load_weights(f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-EXP-auc.h5')
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA No Dropout...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
                          repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*2,
                          droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/2/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))

    # INCLUDING ENSEMBLE OF META DATA
    meta_wgt_auc = []

    dsp_ft = get_meta(files_train)
    dsp_fv = get_meta(files_valid)
    meta_train = meta_unbatch(dsp_ft)
    meta_val = meta_unbatch(dsp_fv)
    meta_pred = meta_model(meta_train, meta_val)
    meta_pred['oof'] = oof_pred[-1]
    meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])    

    for wgt in range(0, 31, 1):
        wgt = wgt/100
        meta_pred['ens'] = ((1-wgt)*meta_pred.oof + wgt*meta_pred.ll)
        meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])
        meta_ens_auc = roc_auc_score(meta_pred['target'],meta_pred['ens'])    
        meta_wgt_auc.append([wgt, meta_ens_auc])
        #print(f"With Meta Weight {wgt}, Meta and OOF AUC with TTA:", meta_ens_auc)
    best_meta_wgts.append(max(meta_wgt_auc, key=lambda item: item[1]))    
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA, No Dropout...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
                         repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*4,
                         droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/4/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,]
    pred = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += pred * WGTS[fold]
    
    dsp_test = get_meta(files_test, BATCH_SIZES[0], test=1)
    meta_test = meta_unbatch(dsp_test, test=1)
    meta_test = meta_model(meta_train, meta_test)
    meta_test['preds'] = pred
    meta_test['preds_meta'] = best_meta_wgts[-1][0]*meta_test.ll + (1-best_meta_wgts[-1][0])*meta_test.preds
    preds_meta = np.array([meta_test.preds_meta]).T
    preds_meta_ls += preds_meta * WGTS[fold]

    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print(f'#### FOLD {fold+1} OOF AUC without TTA = {oof_val[-1]:.3f}, with TTA = {auc:.3f}')
    print("Meta only AUC:", meta_auc) 
    print(f"The best weight is {best_meta_wgts[-1][0]}, Meta and OOF AUC with TTA: {best_meta_wgts[-1][1]:.3f}")
    
    COMPLETED_EPOCHS = len(history.history['loss'])
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] )
        y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4')
        plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] )
        y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728')
        plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('EXPERIMENT %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i, M1=%i, M2=%i, M3=%i, M4=%i\n\
        batch_size %i, dropout_freq=%.2f count=%i size=%.3f'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold],M1[fold],M2[fold],M3[fold],
                 M4[fold],BATCH_SIZES[fold]*REPLICAS,DROP_FREQ[fold],DROP_CT[fold],DROP_SIZE[fold]),size=18)
        plt.legend(loc=3)
        plt.show()  
        
        # TESTING ONLY
        loops+=1
        if loops == max_loops:
            break
        else:
            continue
        
        del model; z = gc.collect()
# Out:
# #########################
# #### EXPERIMENT 1
# #########################
# #### Using the following TFRecords:
# [ 0  1  2  4  5  6  7  8  9 10 13 14] [ 3 11 12]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #########################
# Weight for class 0: 0.53
# Weight for class 1: 9.98
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Training and Validation, No Dropout on Validation...
# Epoch 1/60
# WARNING:tensorflow:From /home/phil/anaconda3/envs/tf37/lib/python3.7/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 549/549 [==============================] - ETA: 0s - loss: 0.6252 - auc: 0.7438
# Epoch 00001: val_loss improved from inf to 0.53749, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.79689, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 198s 361ms/step - loss: 0.6252 - auc: 0.7438 - val_loss: 0.5375 - val_auc: 0.7969
# Epoch 2/60
# 549/549 [==============================] - ETA: 0s - loss: 0.5109 - auc: 0.8499
# Epoch 00002: val_loss improved from 0.53749 to 0.37999, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00002: val_auc improved from 0.79689 to 0.82459, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 198s 360ms/step - loss: 0.5109 - auc: 0.8499 - val_loss: 0.3800 - val_auc: 0.8246
# Epoch 3/60
# 549/549 [==============================] - ETA: 0s - loss: 0.4679 - auc: 0.8801
# Epoch 00003: val_loss improved from 0.37999 to 0.36585, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00003: val_auc improved from 0.82459 to 0.85105, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 199s 363ms/step - loss: 0.4679 - auc: 0.8801 - val_loss: 0.3659 - val_auc: 0.8511
# Epoch 4/60
# 549/549 [==============================] - ETA: 0s - loss: 0.4327 - auc: 0.8957
# Epoch 00004: val_loss improved from 0.36585 to 0.31587, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00004: val_auc improved from 0.85105 to 0.85671, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 201s 366ms/step - loss: 0.4327 - auc: 0.8957 - val_loss: 0.3159 - val_auc: 0.8567
# Epoch 5/60
# 549/549 [==============================] - ETA: 0s - loss: 0.4229 - auc: 0.9085
# Epoch 00005: val_loss improved from 0.31587 to 0.30142, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00005: val_auc improved from 0.85671 to 0.86314, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 202s 367ms/step - loss: 0.4229 - auc: 0.9085 - val_loss: 0.3014 - val_auc: 0.8631
# Epoch 6/60
# 549/549 [==============================] - ETA: 0s - loss: 0.4116 - auc: 0.9146
# Epoch 00006: val_loss did not improve from 0.30142
#
# Epoch 00006: val_auc improved from 0.86314 to 0.87635, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 198s 361ms/step - loss: 0.4116 - auc: 0.9146 - val_loss: 0.3173 - val_auc: 0.8764
# Epoch 7/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3886 - auc: 0.9257
# Epoch 00007: val_loss improved from 0.30142 to 0.27249, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00007: val_auc improved from 0.87635 to 0.87695, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 197s 359ms/step - loss: 0.3886 - auc: 0.9257 - val_loss: 0.2725 - val_auc: 0.8769
# Epoch 8/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3751 - auc: 0.9337
# Epoch 00008: val_loss improved from 0.27249 to 0.23786, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00008: val_auc did not improve from 0.87695
# 549/549 [==============================] - 197s 358ms/step - loss: 0.3751 - auc: 0.9337 - val_loss: 0.2379 - val_auc: 0.8742
# Epoch 9/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3731 - auc: 0.9353
# Epoch 00009: val_loss did not improve from 0.23786
#
# Epoch 00009: val_auc improved from 0.87695 to 0.89749, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 197s 359ms/step - loss: 0.3731 - auc: 0.9353 - val_loss: 0.3229 - val_auc: 0.8975
# Epoch 10/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3484 - auc: 0.9453
# Epoch 00010: val_loss did not improve from 0.23786
#
# Epoch 00010: val_auc did not improve from 0.89749
# 549/549 [==============================] - 196s 357ms/step - loss: 0.3484 - auc: 0.9453 - val_loss: 0.2871 - val_auc: 0.8957
# Epoch 11/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3437 - auc: 0.9481
# Epoch 00011: val_loss did not improve from 0.23786
#
# Epoch 00011: val_auc improved from 0.89749 to 0.90530, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 195s 354ms/step - loss: 0.3437 - auc: 0.9481 - val_loss: 0.3188 - val_auc: 0.9053
# Epoch 12/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3378 - auc: 0.9504
# Epoch 00012: val_loss did not improve from 0.23786
#
# Epoch 00012: val_auc improved from 0.90530 to 0.90639, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 196s 357ms/step - loss: 0.3378 - auc: 0.9504 - val_loss: 0.2736 - val_auc: 0.9064
# Epoch 13/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3331 - auc: 0.9530
# Epoch 00013: val_loss did not improve from 0.23786
#
# Epoch 00013: val_auc improved from 0.90639 to 0.92003, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 195s 356ms/step - loss: 0.3331 - auc: 0.9530 - val_loss: 0.2599 - val_auc: 0.9200
# Epoch 14/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3157 - auc: 0.9589
# Epoch 00014: val_loss did not improve from 0.23786
#
# Epoch 00014: val_auc did not improve from 0.92003
# 549/549 [==============================] - 195s 355ms/step - loss: 0.3157 - auc: 0.9589 - val_loss: 0.2476 - val_auc: 0.8894
# Epoch 15/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3164 - auc: 0.9599
# Epoch 00015: val_loss did not improve from 0.23786
#
# Epoch 00015: val_auc did not improve from 0.92003
# 549/549 [==============================] - 195s 356ms/step - loss: 0.3164 - auc: 0.9599 - val_loss: 0.2658 - val_auc: 0.9134
# Epoch 16/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3134 - auc: 0.9610
# Epoch 00016: val_loss did not improve from 0.23786
#
# Epoch 00016: val_auc did not improve from 0.92003
# 549/549 [==============================] - 195s 355ms/step - loss: 0.3134 - auc: 0.9610 - val_loss: 0.2489 - val_auc: 0.9071
# Epoch 17/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3089 - auc: 0.9610
# Epoch 00017: val_loss did not improve from 0.23786
#
# Epoch 00017: val_auc did not improve from 0.92003
# 549/549 [==============================] - 195s 356ms/step - loss: 0.3089 - auc: 0.9610 - val_loss: 0.2656 - val_auc: 0.9090
# Epoch 18/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3054 - auc: 0.9636
# Epoch 00018: val_loss did not improve from 0.23786
#
# Epoch 00018: val_auc did not improve from 0.92003
# 549/549 [==============================] - 195s 355ms/step - loss: 0.3054 - auc: 0.9636 - val_loss: 0.2408 - val_auc: 0.9105
# Epoch 19/60
# 549/549 [==============================] - ETA: 0s - loss: 0.3020 - auc: 0.9643
# Epoch 00019: val_loss did not improve from 0.23786
#
# Epoch 00019: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.3020 - auc: 0.9643 - val_loss: 0.2808 - val_auc: 0.8832
# Epoch 20/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2982 - auc: 0.9662
# Epoch 00020: val_loss did not improve from 0.23786
#
# Epoch 00020: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 356ms/step - loss: 0.2982 - auc: 0.9662 - val_loss: 0.2489 - val_auc: 0.9047
# Epoch 21/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2998 - auc: 0.9650
# Epoch 00021: val_loss did not improve from 0.23786
#
# Epoch 00021: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2998 - auc: 0.9650 - val_loss: 0.2421 - val_auc: 0.8895
# Epoch 22/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2911 - auc: 0.9674
# Epoch 00022: val_loss did not improve from 0.23786
#
# Epoch 00022: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2911 - auc: 0.9674 - val_loss: 0.2436 - val_auc: 0.9012
# Epoch 23/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2958 - auc: 0.9676
# Epoch 00023: val_loss did not improve from 0.23786
#
# Epoch 00023: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2958 - auc: 0.9676 - val_loss: 0.2423 - val_auc: 0.9111
# Epoch 24/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2949 - auc: 0.9666
# Epoch 00024: val_loss improved from 0.23786 to 0.23761, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00024: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2949 - auc: 0.9666 - val_loss: 0.2376 - val_auc: 0.9122
# Epoch 25/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2924 - auc: 0.9688
# Epoch 00025: val_loss did not improve from 0.23761
#
# Epoch 00025: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2924 - auc: 0.9688 - val_loss: 0.3441 - val_auc: 0.8898
# Epoch 26/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2915 - auc: 0.9675
# Epoch 00026: val_loss did not improve from 0.23761
#
# Epoch 00026: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2915 - auc: 0.9675 - val_loss: 0.2445 - val_auc: 0.8939
# Epoch 27/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2874 - auc: 0.9697
# Epoch 00027: val_loss improved from 0.23761 to 0.23233, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00027: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2874 - auc: 0.9697 - val_loss: 0.2323 - val_auc: 0.9128
# Epoch 28/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2849 - auc: 0.9706
# Epoch 00028: val_loss improved from 0.23233 to 0.23058, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00028: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2849 - auc: 0.9706 - val_loss: 0.2306 - val_auc: 0.9087
# Epoch 29/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2912 - auc: 0.9687
# Epoch 00029: val_loss did not improve from 0.23058
#
# Epoch 00029: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2912 - auc: 0.9687 - val_loss: 0.2388 - val_auc: 0.9143
# Epoch 30/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2880 - auc: 0.9689
# Epoch 00030: val_loss improved from 0.23058 to 0.22825, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00030: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2880 - auc: 0.9689 - val_loss: 0.2283 - val_auc: 0.9143
# Epoch 31/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2856 - auc: 0.9696
# Epoch 00031: val_loss did not improve from 0.22825
#
# Epoch 00031: val_auc did not improve from 0.92003
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2856 - auc: 0.9696 - val_loss: 0.2420 - val_auc: 0.9055
# Epoch 32/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2815 - auc: 0.9717
# Epoch 00032: val_loss improved from 0.22825 to 0.22556, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00032: val_auc did not improve from 0.92003
# 549/549 [==============================] - 197s 358ms/step - loss: 0.2815 - auc: 0.9717 - val_loss: 0.2256 - val_auc: 0.9129
# Epoch 33/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2871 - auc: 0.9695
# Epoch 00033: val_loss did not improve from 0.22556
#
# Epoch 00033: val_auc improved from 0.92003 to 0.92050, saving model to ./cv_folds/EB1-256-fold-0-EXP-auc.h5
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2871 - auc: 0.9695 - val_loss: 0.2328 - val_auc: 0.9205
# Epoch 34/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2851 - auc: 0.9705
# Epoch 00034: val_loss did not improve from 0.22556
#
# Epoch 00034: val_auc did not improve from 0.92050
# 549/549 [==============================] - 195s 356ms/step - loss: 0.2851 - auc: 0.9705 - val_loss: 0.2375 - val_auc: 0.9054
# Epoch 35/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2849 - auc: 0.9702
# Epoch 00035: val_loss did not improve from 0.22556
#
# Epoch 00035: val_auc did not improve from 0.92050
# 549/549 [==============================] - 197s 358ms/step - loss: 0.2849 - auc: 0.9702 - val_loss: 0.2288 - val_auc: 0.9104
# Epoch 36/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2798 - auc: 0.9705
# Epoch 00036: val_loss did not improve from 0.22556
#
# Epoch 00036: val_auc did not improve from 0.92050
# 549/549 [==============================] - 197s 358ms/step - loss: 0.2798 - auc: 0.9705 - val_loss: 0.2327 - val_auc: 0.8977
# Epoch 37/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2834 - auc: 0.9720
# Epoch 00037: val_loss did not improve from 0.22556
#
# Epoch 00037: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2834 - auc: 0.9720 - val_loss: 0.2293 - val_auc: 0.9129
# Epoch 38/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2857 - auc: 0.9696
# Epoch 00038: val_loss did not improve from 0.22556
#
# Epoch 00038: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2857 - auc: 0.9696 - val_loss: 0.2306 - val_auc: 0.9033
# Epoch 39/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2795 - auc: 0.9719
# Epoch 00039: val_loss did not improve from 0.22556
#
# Epoch 00039: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2795 - auc: 0.9719 - val_loss: 0.2421 - val_auc: 0.9033
# Epoch 40/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2893 - auc: 0.9691
# Epoch 00040: val_loss did not improve from 0.22556
#
# Epoch 00040: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2893 - auc: 0.9691 - val_loss: 0.2402 - val_auc: 0.9103
# Epoch 41/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2805 - auc: 0.9712
# Epoch 00041: val_loss did not improve from 0.22556
#
# Epoch 00041: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2805 - auc: 0.9712 - val_loss: 0.2308 - val_auc: 0.9112
# Epoch 42/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2855 - auc: 0.9708
# Epoch 00042: val_loss did not improve from 0.22556
#
# Epoch 00042: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2855 - auc: 0.9708 - val_loss: 0.2315 - val_auc: 0.9027
# Epoch 43/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2804 - auc: 0.9710
# Epoch 00043: val_loss did not improve from 0.22556
#
# Epoch 00043: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 356ms/step - loss: 0.2804 - auc: 0.9710 - val_loss: 0.2428 - val_auc: 0.9026
# Epoch 44/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2805 - auc: 0.9720
# Epoch 00044: val_loss did not improve from 0.22556
#
# Epoch 00044: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2805 - auc: 0.9720 - val_loss: 0.2623 - val_auc: 0.8920
# Epoch 45/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2887 - auc: 0.9690
# Epoch 00045: val_loss did not improve from 0.22556
#
# Epoch 00045: val_auc did not improve from 0.92050
# 549/549 [==============================] - 195s 356ms/step - loss: 0.2887 - auc: 0.9690 - val_loss: 0.2392 - val_auc: 0.9066
# Epoch 46/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2836 - auc: 0.9703
# Epoch 00046: val_loss improved from 0.22556 to 0.22443, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00046: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2836 - auc: 0.9703 - val_loss: 0.2244 - val_auc: 0.9002
# Epoch 47/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2886 - auc: 0.9691
# Epoch 00047: val_loss did not improve from 0.22443
#
# Epoch 00047: val_auc did not improve from 0.92050
# 549/549 [==============================] - 195s 355ms/step - loss: 0.2886 - auc: 0.9691 - val_loss: 0.2287 - val_auc: 0.9101
# Epoch 48/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2805 - auc: 0.9722
# Epoch 00048: val_loss did not improve from 0.22443
#
# Epoch 00048: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2805 - auc: 0.9722 - val_loss: 0.2275 - val_auc: 0.9009
# Epoch 49/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2878 - auc: 0.9695
# Epoch 00049: val_loss did not improve from 0.22443
#
# Epoch 00049: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 358ms/step - loss: 0.2878 - auc: 0.9695 - val_loss: 0.2296 - val_auc: 0.9077
# Epoch 50/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2881 - auc: 0.9693
# Epoch 00050: val_loss did not improve from 0.22443
#
# Epoch 00050: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 356ms/step - loss: 0.2881 - auc: 0.9693 - val_loss: 0.2354 - val_auc: 0.9057
# Epoch 51/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2787 - auc: 0.9721
# Epoch 00051: val_loss did not improve from 0.22443
#
# Epoch 00051: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2787 - auc: 0.9721 - val_loss: 0.2367 - val_auc: 0.9069
# Epoch 52/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2837 - auc: 0.9714
# Epoch 00052: val_loss did not improve from 0.22443
#
# Epoch 00052: val_auc did not improve from 0.92050
# 549/549 [==============================] - 195s 356ms/step - loss: 0.2837 - auc: 0.9714 - val_loss: 0.2312 - val_auc: 0.9074
# Epoch 53/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2775 - auc: 0.9726
# Epoch 00053: val_loss did not improve from 0.22443
#
# Epoch 00053: val_auc did not improve from 0.92050
# 549/549 [==============================] - 195s 356ms/step - loss: 0.2775 - auc: 0.9726 - val_loss: 0.2355 - val_auc: 0.9073
# Epoch 54/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2815 - auc: 0.9713
# Epoch 00054: val_loss did not improve from 0.22443
#
# Epoch 00054: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2815 - auc: 0.9713 - val_loss: 0.2300 - val_auc: 0.8995
# Epoch 55/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2782 - auc: 0.9726
# Epoch 00055: val_loss did not improve from 0.22443
#
# Epoch 00055: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2782 - auc: 0.9726 - val_loss: 0.2297 - val_auc: 0.8853
# Epoch 56/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2771 - auc: 0.9723
# Epoch 00056: val_loss did not improve from 0.22443
#
# Epoch 00056: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2771 - auc: 0.9723 - val_loss: 0.2304 - val_auc: 0.8998
# Epoch 57/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2801 - auc: 0.9720
# Epoch 00057: val_loss did not improve from 0.22443
#
# Epoch 00057: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2801 - auc: 0.9720 - val_loss: 0.2268 - val_auc: 0.9029
# Epoch 58/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2833 - auc: 0.9708
# Epoch 00058: val_loss improved from 0.22443 to 0.22428, saving model to ./cv_folds/EB1-256-fold-0-EXP-loss.h5
#
# Epoch 00058: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2833 - auc: 0.9708 - val_loss: 0.2243 - val_auc: 0.9184
# Epoch 59/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2826 - auc: 0.9713
# Epoch 00059: val_loss did not improve from 0.22428
#
# Epoch 00059: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2826 - auc: 0.9713 - val_loss: 0.2304 - val_auc: 0.9011
# Epoch 60/60
# 549/549 [==============================] - ETA: 0s - loss: 0.2795 - auc: 0.9719
# Epoch 00060: val_loss did not improve from 0.22428
#
# Epoch 00060: val_auc did not improve from 0.92050
# 549/549 [==============================] - 196s 357ms/step - loss: 0.2795 - auc: 0.9719 - val_loss: 0.3006 - val_auc: 0.9112
# Loading best model...
# Predicting OOF with TTA No Dropout...
# 1214/1213 [==============================] - 108s 89ms/step
# Predicting Test with TTA, No Dropout...
# 1073/1072 [==============================] - 178s 166ms/step
# #### FOLD 1 OOF AUC without TTA = 0.921, with TTA = 0.929
# Meta only AUC: 0.6871985621985621
# The best weight is 0.3, Meta and OOF AUC with TTA: 0.932
# #########################
# #### EXPERIMENT 2
# #########################
# #### Using the following TFRecords:
# [ 0  1  2  4  5  6  7  8  9 10 13 14] [ 3 11 12]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.55
# Weight for class 1: 5.24
# Training and Validation, No Dropout on Validation...
# Epoch 1/60
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 576/576 [==============================] - ETA: 0s - loss: 0.6341 - auc: 0.7579
# Epoch 00001: val_loss improved from inf to 0.52600, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.78181, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 208s 362ms/step - loss: 0.6341 - auc: 0.7579 - val_loss: 0.5260 - val_auc: 0.7818
# Epoch 2/60
# 576/576 [==============================] - ETA: 0s - loss: 0.4872 - auc: 0.8667
# Epoch 00002: val_loss improved from 0.52600 to 0.32393, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00002: val_auc improved from 0.78181 to 0.82291, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 204s 354ms/step - loss: 0.4872 - auc: 0.8667 - val_loss: 0.3239 - val_auc: 0.8229
# Epoch 3/60
# 576/576 [==============================] - ETA: 0s - loss: 0.4495 - auc: 0.8885
# Epoch 00003: val_loss did not improve from 0.32393
#
# Epoch 00003: val_auc improved from 0.82291 to 0.86757, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 353ms/step - loss: 0.4495 - auc: 0.8885 - val_loss: 0.3289 - val_auc: 0.8676
# Epoch 4/60
# 576/576 [==============================] - ETA: 0s - loss: 0.4250 - auc: 0.9054
# Epoch 00004: val_loss improved from 0.32393 to 0.28914, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00004: val_auc improved from 0.86757 to 0.89479, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.4250 - auc: 0.9054 - val_loss: 0.2891 - val_auc: 0.8948
# Epoch 5/60
# 576/576 [==============================] - ETA: 0s - loss: 0.4013 - auc: 0.9199
# Epoch 00005: val_loss did not improve from 0.28914
#
# Epoch 00005: val_auc improved from 0.89479 to 0.90473, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.4013 - auc: 0.9199 - val_loss: 0.2949 - val_auc: 0.9047
# Epoch 6/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3820 - auc: 0.9295
# Epoch 00006: val_loss improved from 0.28914 to 0.28086, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00006: val_auc improved from 0.90473 to 0.91880, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.3820 - auc: 0.9295 - val_loss: 0.2809 - val_auc: 0.9188
# Epoch 7/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3717 - auc: 0.9365
# Epoch 00007: val_loss improved from 0.28086 to 0.27751, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00007: val_auc improved from 0.91880 to 0.92688, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 202s 351ms/step - loss: 0.3717 - auc: 0.9365 - val_loss: 0.2775 - val_auc: 0.9269
# Epoch 8/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3482 - auc: 0.9453
# Epoch 00008: val_loss improved from 0.27751 to 0.24101, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00008: val_auc did not improve from 0.92688
# 576/576 [==============================] - 202s 351ms/step - loss: 0.3482 - auc: 0.9453 - val_loss: 0.2410 - val_auc: 0.9266
# Epoch 9/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3354 - auc: 0.9517
# Epoch 00009: val_loss improved from 0.24101 to 0.22935, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00009: val_auc improved from 0.92688 to 0.93741, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.3354 - auc: 0.9517 - val_loss: 0.2293 - val_auc: 0.9374
# Epoch 10/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3277 - auc: 0.9554
# Epoch 00010: val_loss did not improve from 0.22935
#
# Epoch 00010: val_auc improved from 0.93741 to 0.94026, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.3277 - auc: 0.9554 - val_loss: 0.2450 - val_auc: 0.9403
# Epoch 11/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3110 - auc: 0.9613
# Epoch 00011: val_loss improved from 0.22935 to 0.21839, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00011: val_auc improved from 0.94026 to 0.94220, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.3110 - auc: 0.9613 - val_loss: 0.2184 - val_auc: 0.9422
# Epoch 12/60
# 576/576 [==============================] - ETA: 0s - loss: 0.3033 - auc: 0.9636
# Epoch 00012: val_loss did not improve from 0.21839
#
# Epoch 00012: val_auc improved from 0.94220 to 0.94546, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 202s 351ms/step - loss: 0.3033 - auc: 0.9636 - val_loss: 0.2273 - val_auc: 0.9455
# Epoch 13/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2951 - auc: 0.9671
# Epoch 00013: val_loss improved from 0.21839 to 0.21469, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00013: val_auc improved from 0.94546 to 0.95152, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2951 - auc: 0.9671 - val_loss: 0.2147 - val_auc: 0.9515
# Epoch 14/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2910 - auc: 0.9683
# Epoch 00014: val_loss did not improve from 0.21469
#
# Epoch 00014: val_auc did not improve from 0.95152
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2910 - auc: 0.9683 - val_loss: 0.2198 - val_auc: 0.9514
# Epoch 15/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2858 - auc: 0.9704
# Epoch 00015: val_loss did not improve from 0.21469
#
# Epoch 00015: val_auc did not improve from 0.95152
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2858 - auc: 0.9704 - val_loss: 0.2206 - val_auc: 0.9490
# Epoch 16/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2840 - auc: 0.9708
# Epoch 00016: val_loss did not improve from 0.21469
#
# Epoch 00016: val_auc improved from 0.95152 to 0.95424, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2840 - auc: 0.9708 - val_loss: 0.2153 - val_auc: 0.9542
# Epoch 17/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2744 - auc: 0.9736
# Epoch 00017: val_loss improved from 0.21469 to 0.21274, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00017: val_auc did not improve from 0.95424
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2744 - auc: 0.9736 - val_loss: 0.2127 - val_auc: 0.9448
# Epoch 18/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2720 - auc: 0.9742
# Epoch 00018: val_loss did not improve from 0.21274
#
# Epoch 00018: val_auc did not improve from 0.95424
# 576/576 [==============================] - 202s 352ms/step - loss: 0.2720 - auc: 0.9742 - val_loss: 0.2171 - val_auc: 0.9489
# Epoch 19/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2718 - auc: 0.9750
# Epoch 00019: val_loss did not improve from 0.21274
#
# Epoch 00019: val_auc did not improve from 0.95424
# 576/576 [==============================] - 202s 352ms/step - loss: 0.2718 - auc: 0.9750 - val_loss: 0.2139 - val_auc: 0.9521
# Epoch 20/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2667 - auc: 0.9758
# Epoch 00020: val_loss improved from 0.21274 to 0.21011, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
# Epoch 00020: val_auc improved from 0.95424 to 0.96006, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2667 - auc: 0.9758 - val_loss: 0.2101 - val_auc: 0.9601
# Epoch 21/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2677 - auc: 0.9754
# Epoch 00021: val_loss improved from 0.21011 to 0.20945, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00021: val_auc improved from 0.96006 to 0.96043, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2677 - auc: 0.9754 - val_loss: 0.2094 - val_auc: 0.9604
# Epoch 22/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2616 - auc: 0.9774
# Epoch 00022: val_loss improved from 0.20945 to 0.20290, saving model to ./cv_folds/EB1-256-fold-1-EXP-loss.h5
#
# Epoch 00022: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2616 - auc: 0.9774 - val_loss: 0.2029 - val_auc: 0.9604
# Epoch 23/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2651 - auc: 0.9769
# Epoch 00023: val_loss did not improve from 0.20290
#
# Epoch 00023: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2651 - auc: 0.9769 - val_loss: 0.2101 - val_auc: 0.9569
# Epoch 24/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2634 - auc: 0.9770
# Epoch 00024: val_loss did not improve from 0.20290
#
# Epoch 00024: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2634 - auc: 0.9770 - val_loss: 0.2114 - val_auc: 0.9527
# Epoch 25/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2587 - auc: 0.9783
# Epoch 00025: val_loss did not improve from 0.20290
#
# Epoch 00025: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2587 - auc: 0.9783 - val_loss: 0.2108 - val_auc: 0.9565
# Epoch 26/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2595 - auc: 0.9783
# Epoch 00026: val_loss did not improve from 0.20290
#
# Epoch 00026: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2595 - auc: 0.9783 - val_loss: 0.2093 - val_auc: 0.9486
# Epoch 27/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2604 - auc: 0.9775
# Epoch 00027: val_loss did not improve from 0.20290
#
# Epoch 00027: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2604 - auc: 0.9775 - val_loss: 0.2111 - val_auc: 0.9541
# Epoch 28/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2575 - auc: 0.9789
# Epoch 00028: val_loss did not improve from 0.20290
#
# Epoch 00028: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 350ms/step - loss: 0.2575 - auc: 0.9789 - val_loss: 0.2095 - val_auc: 0.9586
# Epoch 29/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2573 - auc: 0.9790
# Epoch 00029: val_loss did not improve from 0.20290
#
# Epoch 00029: val_auc did not improve from 0.96043
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2573 - auc: 0.9790 - val_loss: 0.2091 - val_auc: 0.9442
# Epoch 30/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2564 - auc: 0.9791
# Epoch 00030: val_loss did not improve from 0.20290
#
# Epoch 00030: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2564 - auc: 0.9791 - val_loss: 0.2091 - val_auc: 0.9494
# Epoch 31/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2559 - auc: 0.9792
# Epoch 00031: val_loss did not improve from 0.20290
#
# Epoch 00031: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2559 - auc: 0.9792 - val_loss: 0.2127 - val_auc: 0.9543
# Epoch 32/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2562 - auc: 0.9792
# Epoch 00032: val_loss did not improve from 0.20290
#
# Epoch 00032: val_auc did not improve from 0.96043
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2562 - auc: 0.9792 - val_loss: 0.2105 - val_auc: 0.9599
# Epoch 33/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2603 - auc: 0.9775
# Epoch 00033: val_loss did not improve from 0.20290
#
# Epoch 00033: val_auc did not improve from 0.96043
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2603 - auc: 0.9775 - val_loss: 0.2126 - val_auc: 0.9529
# Epoch 34/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2527 - auc: 0.9800
# Epoch 00034: val_loss did not improve from 0.20290
#
# Epoch 00034: val_auc did not improve from 0.96043
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2527 - auc: 0.9800 - val_loss: 0.2152 - val_auc: 0.9439
# Epoch 35/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2590 - auc: 0.9784
# Epoch 00035: val_loss did not improve from 0.20290
#
# Epoch 00035: val_auc improved from 0.96043 to 0.96902, saving model to ./cv_folds/EB1-256-fold-1-EXP-auc.h5
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2590 - auc: 0.9784 - val_loss: 0.2075 - val_auc: 0.9690
# Epoch 36/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2550 - auc: 0.9795
# Epoch 00036: val_loss did not improve from 0.20290
#
# Epoch 00036: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2550 - auc: 0.9795 - val_loss: 0.2118 - val_auc: 0.9528
# Epoch 37/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2569 - auc: 0.9788
# Epoch 00037: val_loss did not improve from 0.20290
#
# Epoch 00037: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2569 - auc: 0.9788 - val_loss: 0.2137 - val_auc: 0.9607
# Epoch 38/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2567 - auc: 0.9793
# Epoch 00038: val_loss did not improve from 0.20290
#
# Epoch 00038: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2567 - auc: 0.9793 - val_loss: 0.2083 - val_auc: 0.9614
# Epoch 39/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2557 - auc: 0.9789
# Epoch 00039: val_loss did not improve from 0.20290
#
# Epoch 00039: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 350ms/step - loss: 0.2557 - auc: 0.9789 - val_loss: 0.2169 - val_auc: 0.9421
# Epoch 40/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2568 - auc: 0.9792
# Epoch 00040: val_loss did not improve from 0.20290
#
# Epoch 00040: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2568 - auc: 0.9792 - val_loss: 0.2144 - val_auc: 0.9562
# Epoch 41/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2540 - auc: 0.9793
# Epoch 00041: val_loss did not improve from 0.20290
#
# Epoch 00041: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2540 - auc: 0.9793 - val_loss: 0.2280 - val_auc: 0.9541
# Epoch 42/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2539 - auc: 0.9797
# Epoch 00042: val_loss did not improve from 0.20290
#
# Epoch 00042: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2539 - auc: 0.9797 - val_loss: 0.2102 - val_auc: 0.9515
# Epoch 43/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2495 - auc: 0.9808
# Epoch 00043: val_loss did not improve from 0.20290
#
# Epoch 00043: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2495 - auc: 0.9808 - val_loss: 0.2097 - val_auc: 0.9621
# Epoch 44/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2554 - auc: 0.9794
# Epoch 00044: val_loss did not improve from 0.20290
#
# Epoch 00044: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2554 - auc: 0.9794 - val_loss: 0.2196 - val_auc: 0.9518
# Epoch 45/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2538 - auc: 0.9798
# Epoch 00045: val_loss did not improve from 0.20290
#
# Epoch 00045: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 350ms/step - loss: 0.2538 - auc: 0.9798 - val_loss: 0.2094 - val_auc: 0.9570
# Epoch 46/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2504 - auc: 0.9806
# Epoch 00046: val_loss did not improve from 0.20290
#
# Epoch 00046: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2504 - auc: 0.9806 - val_loss: 0.2169 - val_auc: 0.9482
# Epoch 47/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2524 - auc: 0.9803
# Epoch 00047: val_loss did not improve from 0.20290
#
# Epoch 00047: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2524 - auc: 0.9803 - val_loss: 0.2075 - val_auc: 0.9467
# Epoch 48/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2470 - auc: 0.9819
# Epoch 00048: val_loss did not improve from 0.20290
#
# Epoch 00048: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 352ms/step - loss: 0.2470 - auc: 0.9819 - val_loss: 0.2119 - val_auc: 0.9647
# Epoch 49/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2510 - auc: 0.9801
# Epoch 00049: val_loss did not improve from 0.20290
#
# Epoch 00049: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2510 - auc: 0.9801 - val_loss: 0.2106 - val_auc: 0.9520
# Epoch 50/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2513 - auc: 0.9806
# Epoch 00050: val_loss did not improve from 0.20290
#
# Epoch 00050: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2513 - auc: 0.9806 - val_loss: 0.2052 - val_auc: 0.9625
# Epoch 51/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2522 - auc: 0.9803
# Epoch 00051: val_loss did not improve from 0.20290
#
# Epoch 00051: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2522 - auc: 0.9803 - val_loss: 0.2096 - val_auc: 0.9606
# Epoch 52/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2525 - auc: 0.9797
# Epoch 00052: val_loss did not improve from 0.20290
#
# Epoch 00052: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2525 - auc: 0.9797 - val_loss: 0.2098 - val_auc: 0.9596
# Epoch 53/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2483 - auc: 0.9811
# Epoch 00053: val_loss did not improve from 0.20290
#
# Epoch 00053: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2483 - auc: 0.9811 - val_loss: 0.2063 - val_auc: 0.9577
# Epoch 54/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2531 - auc: 0.9798
# Epoch 00054: val_loss did not improve from 0.20290
#
# Epoch 00054: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2531 - auc: 0.9798 - val_loss: 0.2102 - val_auc: 0.9643
# Epoch 55/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2490 - auc: 0.9813
# Epoch 00055: val_loss did not improve from 0.20290
#
# Epoch 00055: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2490 - auc: 0.9813 - val_loss: 0.2096 - val_auc: 0.9545
# Epoch 56/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2505 - auc: 0.9800
# Epoch 00056: val_loss did not improve from 0.20290
#
# Epoch 00056: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 350ms/step - loss: 0.2505 - auc: 0.9800 - val_loss: 0.2068 - val_auc: 0.9603
# Epoch 57/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2545 - auc: 0.9797
# Epoch 00057: val_loss did not improve from 0.20290
#
# Epoch 00057: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2545 - auc: 0.9797 - val_loss: 0.2106 - val_auc: 0.9520
# Epoch 58/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2504 - auc: 0.9807
# Epoch 00058: val_loss did not improve from 0.20290
#
# Epoch 00058: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2504 - auc: 0.9807 - val_loss: 0.2073 - val_auc: 0.9615
# Epoch 59/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2512 - auc: 0.9805
# Epoch 00059: val_loss did not improve from 0.20290
#
# Epoch 00059: val_auc did not improve from 0.96902
# 576/576 [==============================] - 202s 351ms/step - loss: 0.2512 - auc: 0.9805 - val_loss: 0.2072 - val_auc: 0.9497
# Epoch 60/60
# 576/576 [==============================] - ETA: 0s - loss: 0.2508 - auc: 0.9805
# Epoch 00060: val_loss did not improve from 0.20290
#
# Epoch 00060: val_auc did not improve from 0.96902
# 576/576 [==============================] - 203s 352ms/step - loss: 0.2508 - auc: 0.9805 - val_loss: 0.2086 - val_auc: 0.9586
# Loading best model...
# Predicting OOF with TTA No Dropout...
# 1214/1213 [==============================] - 109s 89ms/step
# Predicting Test with TTA, No Dropout...
# 1073/1072 [==============================] - 180s 168ms/step
# #### FOLD 2 OOF AUC without TTA = 0.969, with TTA = 0.971
# Meta only AUC: 0.6953415536748869
# The best weight is 0.27, Meta and OOF AUC with TTA: 0.972
# #########################
# #### EXPERIMENT 3
# #########################
# #### Using the following TFRecords:
# [ 0  1  2  4  5  6  7  8  9 10 13 14] [ 3 11 12]
# #### Image Size 256 with EfficientNet B1 and batch_size 64
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-2 data (ISIC website)
# #### Upsample MALIG-3 data (2019 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.57
# Weight for class 1: 3.89
# Training and Validation, No Dropout on Validation...
# Epoch 1/60
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 301 all-reduces with algorithm = nccl, num_packs = 1
# 598/598 [==============================] - ETA: 0s - loss: 0.6378 - auc: 0.7594
# Epoch 00001: val_loss improved from inf to 0.50393, saving model to ./cv_folds/EB1-256-fold-2-EXP-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.81905, saving model to ./cv_folds/EB1-256-fold-2-EXP-auc.h5
# 598/598 [==============================] - 215s 360ms/step - loss: 0.6378 - auc: 0.7594 - val_loss: 0.5039 - val_auc: 0.8191
# Epoch 2/60
# 598/598 [==============================] - ETA: 0s - loss: 0.4648 - auc: 0.8794
# Epoch 00002: val_loss improved from 0.50393 to 0.35781, saving model to ./cv_folds/EB1-256-fold-2-EXP-loss.h5
#
# Epoch 00002: val_auc improved from 0.81905 to 0.84226, saving model to ./cv_folds/EB1-256-fold-2-EXP-auc.h5
# 598/598 [==============================] - 212s 354ms/step - loss: 0.4648 - auc: 0.8794 - val_loss: 0.3578 - val_auc: 0.8423
# Epoch 3/60
# 598/598 [==============================] - ETA: 0s - loss: 0.4254 - auc: 0.9067
# Epoch 00003: val_loss improved from 0.35781 to 0.34591, saving model to ./cv_folds/EB1-256-fold-2-EXP-loss.h5
#
# Epoch 00003: val_auc improved from 0.84226 to 0.84916, saving model to ./cv_folds/EB1-256-fold-2-EXP-auc.h5
# 598/598 [==============================] - 211s 353ms/step - loss: 0.4254 - auc: 0.9067 - val_loss: 0.3459 - val_auc: 0.8492
# Epoch 4/60
# 598/598 [==============================] - ETA: 0s - loss: 0.4031 - auc: 0.9189
# Epoch 00004: val_loss improved from 0.34591 to 0.31541, saving model to ./cv_folds/EB1-256-fold-2-EXP-loss.h5
#
# Epoch 00004: val_auc improved from 0.84916 to 0.87464, saving model to ./cv_folds/EB1-256-fold-2-EXP-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.4031 - auc: 0.9189 - val_loss: 0.3154 - val_auc: 0.8746
# Epoch 5/60
# 598/598 [==============================] - ETA: 0s - loss: 0.3791 - auc: 0.9315
# Epoch 00005: val_loss improved from 0.31541 to 0.24285, saving model to ./cv_folds/EB1-256-fold-2-EXP-loss.h5
#
# Epoch 00005: val_auc improved from 0.87464 to 0.89403, saving model to ./cv_folds/EB1-256-fold-2-EXP-auc.h5
# ...
# 598/598 [==============================] - ETA: 0s - loss: 0.3070 - auc: 0.9641
# Epoch 00014: val_loss did not improve from 0.23708
#
# Epoch 00014: val_auc improved from 0.93504 to 0.93768, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 209s 350ms/step - loss: 0.3070 - auc: 0.9641 - val_loss: 0.2495 - val_auc: 0.9377
# Epoch 15/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2997 - auc: 0.9663
# Epoch 00015: val_loss did not improve from 0.23708
#
# Epoch 00015: val_auc did not improve from 0.93768
# 598/598 [==============================] - 209s 349ms/step - loss: 0.2997 - auc: 0.9663 - val_loss: 0.2498 - val_auc: 0.9376
# Epoch 16/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2945 - auc: 0.9681
# Epoch 00016: val_loss did not improve from 0.23708
#
# Epoch 00016: val_auc improved from 0.93768 to 0.93780, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2945 - auc: 0.9681 - val_loss: 0.2405 - val_auc: 0.9378
# Epoch 17/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2866 - auc: 0.9710
# Epoch 00017: val_loss did not improve from 0.23708
#
# Epoch 00017: val_auc improved from 0.93780 to 0.94487, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2866 - auc: 0.9710 - val_loss: 0.2410 - val_auc: 0.9449
# Epoch 18/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2862 - auc: 0.9706
# Epoch 00018: val_loss improved from 0.23708 to 0.23056, saving model to ./cv_folds/EB1-256-fold-4-EXP-loss.h5
#
# Epoch 00018: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2862 - auc: 0.9706 - val_loss: 0.2306 - val_auc: 0.9378
# Epoch 19/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2897 - auc: 0.9691
# Epoch 00019: val_loss did not improve from 0.23056
#
# Epoch 00019: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2897 - auc: 0.9691 - val_loss: 0.2821 - val_auc: 0.9219
# Epoch 20/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.9716
# Epoch 00020: val_loss did not improve from 0.23056
#
# Epoch 00020: val_auc did not improve from 0.94487
# 598/598 [==============================] - 209s 349ms/step - loss: 0.2850 - auc: 0.9716 - val_loss: 0.2416 - val_auc: 0.9269
# Epoch 21/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2827 - auc: 0.9719
# Epoch 00021: val_loss improved from 0.23056 to 0.22497, saving model to ./cv_folds/EB1-256-fold-4-EXP-loss.h5
#
# Epoch 00021: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2827 - auc: 0.9719 - val_loss: 0.2250 - val_auc: 0.9371
# Epoch 22/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2798 - auc: 0.9724
# Epoch 00022: val_loss did not improve from 0.22497
#
# Epoch 00022: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 350ms/step - loss: 0.2798 - auc: 0.9724 - val_loss: 0.2251 - val_auc: 0.9406
# Epoch 23/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2789 - auc: 0.9733
# Epoch 00023: val_loss did not improve from 0.22497
#
# Epoch 00023: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 350ms/step - loss: 0.2789 - auc: 0.9733 - val_loss: 0.2364 - val_auc: 0.9364
# Epoch 24/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2828 - auc: 0.9719
# Epoch 00024: val_loss did not improve from 0.22497
#
# Epoch 00024: val_auc did not improve from 0.94487
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2828 - auc: 0.9719 - val_loss: 0.2278 - val_auc: 0.9410
# Epoch 25/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2762 - auc: 0.9741
# Epoch 00025: val_loss did not improve from 0.22497
#
# Epoch 00025: val_auc did not improve from 0.94487
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2762 - auc: 0.9741 - val_loss: 0.2401 - val_auc: 0.9403
# Epoch 26/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2772 - auc: 0.9737
# Epoch 00026: val_loss improved from 0.22497 to 0.22401, saving model to ./cv_folds/EB1-256-fold-4-EXP-loss.h5
#
# Epoch 00026: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2772 - auc: 0.9737 - val_loss: 0.2240 - val_auc: 0.9439
# Epoch 27/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2755 - auc: 0.9742
# Epoch 00027: val_loss improved from 0.22401 to 0.22336, saving model to ./cv_folds/EB1-256-fold-4-EXP-loss.h5
#
# Epoch 00027: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2755 - auc: 0.9742 - val_loss: 0.2234 - val_auc: 0.9446
# Epoch 28/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2751 - auc: 0.9738
# Epoch 00028: val_loss did not improve from 0.22336
#
# Epoch 00028: val_auc did not improve from 0.94487
# 598/598 [==============================] - 209s 349ms/step - loss: 0.2751 - auc: 0.9738 - val_loss: 0.2283 - val_auc: 0.9439
# Epoch 29/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2739 - auc: 0.9748
# Epoch 00029: val_loss did not improve from 0.22336
#
# Epoch 00029: val_auc did not improve from 0.94487
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2739 - auc: 0.9748 - val_loss: 0.2266 - val_auc: 0.9431
# Epoch 30/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2747 - auc: 0.9749
# Epoch 00030: val_loss did not improve from 0.22336
#
# Epoch 00030: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2747 - auc: 0.9749 - val_loss: 0.2275 - val_auc: 0.9366
# Epoch 31/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2750 - auc: 0.9745
# Epoch 00031: val_loss did not improve from 0.22336
#
# Epoch 00031: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2750 - auc: 0.9745 - val_loss: 0.2246 - val_auc: 0.9429
# Epoch 32/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2762 - auc: 0.9739
# Epoch 00032: val_loss did not improve from 0.22336
#
# Epoch 00032: val_auc did not improve from 0.94487
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2762 - auc: 0.9739 - val_loss: 0.2261 - val_auc: 0.9434
# Epoch 33/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2712 - auc: 0.9758
# Epoch 00033: val_loss did not improve from 0.22336
#
# Epoch 00033: val_auc improved from 0.94487 to 0.94514, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 210s 352ms/step - loss: 0.2712 - auc: 0.9758 - val_loss: 0.2272 - val_auc: 0.9451
# Epoch 34/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2733 - auc: 0.9750
# Epoch 00034: val_loss did not improve from 0.22336
#
# Epoch 00034: val_auc did not improve from 0.94514
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2733 - auc: 0.9750 - val_loss: 0.2416 - val_auc: 0.9392
# Epoch 35/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2722 - auc: 0.9752
# Epoch 00035: val_loss did not improve from 0.22336
#
# Epoch 00035: val_auc improved from 0.94514 to 0.95106, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2722 - auc: 0.9752 - val_loss: 0.2639 - val_auc: 0.9511
# Epoch 36/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2710 - auc: 0.9760
# Epoch 00036: val_loss did not improve from 0.22336
#
# Epoch 00036: val_auc did not improve from 0.95106
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2710 - auc: 0.9760 - val_loss: 0.2319 - val_auc: 0.9330
# Epoch 37/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2740 - auc: 0.9746
# Epoch 00037: val_loss did not improve from 0.22336
#
# Epoch 00037: val_auc did not improve from 0.95106
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2740 - auc: 0.9746 - val_loss: 0.2479 - val_auc: 0.9398
# Epoch 38/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2714 - auc: 0.9755
# Epoch 00038: val_loss did not improve from 0.22336
#
# Epoch 00038: val_auc did not improve from 0.95106
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2714 - auc: 0.9755 - val_loss: 0.2245 - val_auc: 0.9415
# Epoch 39/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2722 - auc: 0.9754
# Epoch 00039: val_loss did not improve from 0.22336
#
# Epoch 00039: val_auc did not improve from 0.95106
# 598/598 [==============================] - 210s 350ms/step - loss: 0.2722 - auc: 0.9754 - val_loss: 0.2314 - val_auc: 0.9403
# Epoch 40/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2697 - auc: 0.9758
# Epoch 00040: val_loss improved from 0.22336 to 0.21949, saving model to ./cv_folds/EB1-256-fold-4-EXP-loss.h5
#
# Epoch 00040: val_auc improved from 0.95106 to 0.95109, saving model to ./cv_folds/EB1-256-fold-4-EXP-auc.h5
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2697 - auc: 0.9758 - val_loss: 0.2195 - val_auc: 0.9511
# Epoch 41/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2689 - auc: 0.9760
# Epoch 00041: val_loss did not improve from 0.21949
#
# Epoch 00041: val_auc did not improve from 0.95109
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2689 - auc: 0.9760 - val_loss: 0.2260 - val_auc: 0.9236
# Epoch 42/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2697 - auc: 0.9766
# Epoch 00042: val_loss did not improve from 0.21949
#
# Epoch 00042: val_auc did not improve from 0.95109
# 598/598 [==============================] - 209s 350ms/step - loss: 0.2697 - auc: 0.9766 - val_loss: 0.2302 - val_auc: 0.9404
# Epoch 43/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2684 - auc: 0.9762
# Epoch 00043: val_loss did not improve from 0.21949
#
# Epoch 00043: val_auc did not improve from 0.95109
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2684 - auc: 0.9762 - val_loss: 0.2446 - val_auc: 0.9436
# Epoch 44/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2734 - auc: 0.9750
# Epoch 00044: val_loss did not improve from 0.21949
#
# Epoch 00044: val_auc did not improve from 0.95109
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2734 - auc: 0.9750 - val_loss: 0.2418 - val_auc: 0.9349
# Epoch 45/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2682 - auc: 0.9764
# Epoch 00045: val_loss did not improve from 0.21949
#
# Epoch 00045: val_auc did not improve from 0.95109
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2682 - auc: 0.9764 - val_loss: 0.2408 - val_auc: 0.9448
# Epoch 46/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2715 - auc: 0.9753
# Epoch 00046: val_loss did not improve from 0.21949
#
# Epoch 00046: val_auc did not improve from 0.95109
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2715 - auc: 0.9753 - val_loss: 0.2251 - val_auc: 0.9391
# Epoch 47/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2697 - auc: 0.9761
# Epoch 00047: val_loss did not improve from 0.21949
#
# Epoch 00047: val_auc did not improve from 0.95109
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2697 - auc: 0.9761 - val_loss: 0.2408 - val_auc: 0.9290
# Epoch 48/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2701 - auc: 0.9757
# Epoch 00048: val_loss did not improve from 0.21949
#
# Epoch 00048: val_auc did not improve from 0.95109
# 598/598 [==============================] - 210s 351ms/step - loss: 0.2701 - auc: 0.9757 - val_loss: 0.2381 - val_auc: 0.9253
# Epoch 49/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2688 - auc: 0.9765
# Epoch 00049: val_loss did not improve from 0.21949
#
# Epoch 00049: val_auc did not improve from 0.95109
# 598/598 [==============================] - 211s 352ms/step - loss: 0.2688 - auc: 0.9765 - val_loss: 0.2680 - val_auc: 0.9313
# Epoch 50/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2703 - auc: 0.9758
# Epoch 00050: val_loss did not improve from 0.21949
#
# Epoch 00050: val_auc did not improve from 0.95109
# 598/598 [==============================] - 211s 353ms/step - loss: 0.2703 - auc: 0.9758 - val_loss: 0.4653 - val_auc: 0.9309
# Epoch 51/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2725 - auc: 0.9754
# Epoch 00051: val_loss did not improve from 0.21949
#
# Epoch 00051: val_auc did not improve from 0.95109
# 598/598 [==============================] - 217s 363ms/step - loss: 0.2725 - auc: 0.9754 - val_loss: 0.2361 - val_auc: 0.9424
# Epoch 52/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2694 - auc: 0.9760
# Epoch 00052: val_loss did not improve from 0.21949
#
# Epoch 00052: val_auc did not improve from 0.95109
# 598/598 [==============================] - 216s 361ms/step - loss: 0.2694 - auc: 0.9760 - val_loss: 0.2298 - val_auc: 0.9478
# Epoch 53/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2691 - auc: 0.9765
# Epoch 00053: val_loss did not improve from 0.21949
#
# Epoch 00053: val_auc did not improve from 0.95109
# 598/598 [==============================] - 220s 367ms/step - loss: 0.2691 - auc: 0.9765 - val_loss: 0.2328 - val_auc: 0.9495
# Epoch 54/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2712 - auc: 0.9754
# Epoch 00054: val_loss did not improve from 0.21949
#
# Epoch 00054: val_auc did not improve from 0.95109
# 598/598 [==============================] - 219s 366ms/step - loss: 0.2712 - auc: 0.9754 - val_loss: 0.2303 - val_auc: 0.9460
# Epoch 55/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2692 - auc: 0.9763
# Epoch 00055: val_loss did not improve from 0.21949
#
# Epoch 00055: val_auc did not improve from 0.95109
# 598/598 [==============================] - 215s 360ms/step - loss: 0.2692 - auc: 0.9763 - val_loss: 0.2279 - val_auc: 0.9417
# Epoch 56/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2653 - auc: 0.9775
# Epoch 00056: val_loss did not improve from 0.21949
#
# Epoch 00056: val_auc did not improve from 0.95109
# 598/598 [==============================] - 215s 360ms/step - loss: 0.2653 - auc: 0.9775 - val_loss: 0.2277 - val_auc: 0.9378
# Epoch 57/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2678 - auc: 0.9765
# Epoch 00057: val_loss did not improve from 0.21949
#
# Epoch 00057: val_auc did not improve from 0.95109
# 598/598 [==============================] - 213s 357ms/step - loss: 0.2678 - auc: 0.9765 - val_loss: 0.2355 - val_auc: 0.9474
# Epoch 58/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2688 - auc: 0.9763
# Epoch 00058: val_loss did not improve from 0.21949
#
# Epoch 00058: val_auc did not improve from 0.95109
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2688 - auc: 0.9763 - val_loss: 0.2801 - val_auc: 0.9390
# Epoch 59/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2716 - auc: 0.9752
# Epoch 00059: val_loss did not improve from 0.21949
#
# Epoch 00059: val_auc did not improve from 0.95109
# 598/598 [==============================] - 213s 356ms/step - loss: 0.2716 - auc: 0.9752 - val_loss: 0.2620 - val_auc: 0.9422
# Epoch 60/60
# 598/598 [==============================] - ETA: 0s - loss: 0.2694 - auc: 0.9760
# Epoch 00060: val_loss did not improve from 0.21949
#
# Epoch 00060: val_auc did not improve from 0.95109
# 598/598 [==============================] - 212s 355ms/step - loss: 0.2694 - auc: 0.9760 - val_loss: 0.2772 - val_auc: 0.9444
# Loading best model...
# Predicting OOF with TTA No Dropout...
# 1214/1213 [==============================] - 110s 90ms/step
# Predicting Test with TTA, No Dropout...
# 1073/1072 [==============================] - 185s 173ms/step
# #### FOLD 5 OOF AUC without TTA = 0.951, with TTA = 0.957
# Meta only AUC: 0.6921550338217004
# The best weight is 0.17, Meta and OOF AUC with TTA: 0.959

# %% [markdown]
# #### Show the optimal characteristics from CV

# %%
best_epoch_val_auc_mean = np.mean(np.array(best_epoch_val_auc_ls), axis=0)
best_epoch_val_loss_mean = np.mean(np.array(best_epoch_val_loss_ls), axis=0)

print("The best epoch value for AUC over the cv is: ",best_epoch_val_auc_mean)
print("The best epoch value for loss over the cv is: ",best_epoch_val_loss_mean)
# Out:
# The best epoch value for AUC over the cv is:  43.6
# The best epoch value for loss over the cv is:  41.8

# %%
cv_val_auc_mean = np.mean(np.array(best_val_auc_ls), axis=0)
cv_val_auc_std = np.std(np.array(best_val_auc_ls), axis=0)
cv_val_loss_mean = np.mean(np.array(best_val_loss_ls), axis=0)

print(f"The mean AUC score across CV folds is {cv_val_auc_mean:.2f} and the standard deviation is {cv_val_auc_std:.2%}")
# Out:
# The mean AUC score across CV folds is 0.96 and the standard deviation is 1.85%

# %% [markdown]
# #### Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred)
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names)
folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{CV_OOF_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-oof-EXP.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.962
#      image_name  target      pred  fold
# 0  ISIC_7149353       0  0.009995     0
# 1  ISIC_2234161       0  0.016199     0
# 2  ISIC_5628615       0  0.022653     0
# 3  ISIC_9855719       0  0.053233     0
# 4  ISIC_7558912       0  0.060589     0

# %% [markdown]
# #### Calculate OOF AUC with Tabular Data
# Utilising a simple prediction model on the tabular data should add additional information when blending. This can be tested with the OOF data.

# %%
best_wgt = []
best_auc = []
for best in best_meta_wgts:
    best_wgt.append(best[0])
    best_auc.append(best[1])
avg_wgt = sum(best_wgt)/len(best_wgt)
avg_auc = sum(best_auc)/len(best_auc)
print(f"Average of best meta weights = {avg_wgt:.2f}")
print(f"Overall OOF and Meta AUC with TTA = {avg_auc:.3f}")
# Out:
# Average of best meta weights = 0.16
# Overall OOF and Meta AUC with TTA = 0.962

# %% [markdown]
# ### Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.

# %% [markdown]
# ### Log values from the cross validation process

# %%
if ENV == 'LOCAL':
    log_df = pd.read_csv('./logs/experiment_log.csv')
    headers = list(log_df.columns.values)
    
if ENV == 'KAGGLE':
    headers = ['Image Size',
             'Model',
             '2018 Data',
             'Batch Size',
             'Replicas',
             'Total Batch Size',
             'TTA Loops',
             'CV Folds',
             'Mean CV AUC',
             'Std CV AUC',
             'OOF AUC with TTA',
             'OOF AUC and Meta with TTA'
             'Best average Meta weighting'  
             'Mean CV Loss',
             'Total Epochs',
             'Early Stop',
             'Best AUC Epoch',
             'Best Loss Epoch',
             'Kaggle LB AUC',
             'Kaggle LB AUC w Meta']
    log_df = pd.DataFrame(columns = headers)

# %%
log_items = [IMG_SIZES[0],
            str(f"EFNB{EFF_NETS[0]}EXP"),
            INC2018[0],
            BATCH_SIZES[0],
            REPLICAS,
            BATCH_SIZES[0] * REPLICAS,
            TTA,
            FOLDS,
            cv_val_auc_mean,
            cv_val_auc_std, 
            auc,
            avg_auc,
            avg_wgt,
            cv_val_loss_mean,
            EPOCHS[0],
            EARLY_STOPPING,
            best_epoch_val_auc_mean,
            best_epoch_val_loss_mean,
            0.00,
            0.00]

# %%
for n in range(len(headers)):
    print(headers[n]+":", log_items[n])
    
log_data = pd.DataFrame([log_items], columns=headers)
log_df = log_df.append(log_data)
log_df.sort_values(by=['Model','Image Size'], inplace=True)
log_df.to_csv(f'{LOG_PATH}experiment_log.csv', index=False)
log_df.head(30)
# Out:
# Image Size: 256
# Model: EFNB1EXP
# 2018 Data: 1
# Batch Size: 32
# Replicas: 2
# Total Batch Size: 64
# TTA Loops: 25
# CV Folds: 5
# Mean CV AUC: 0.955028522014618
# Std CV AUC: 0.018499758124038874
# OOF AUC with TTA: 0.9621690175023507
# OOF AUC and Meta with TTA: 0.9622980556313891
# Best average Meta weighting: 0.164
# Mean CV Loss: 0.20821706652641297
# Total Epochs: 60
# Early Stop: 0
# Best AUC Epoch: 43.6
# Best Loss Epoch: 41.8
# Kaggle LB AUC: 0.0
# Kaggle LB AUC w Meta: 0.0
#     Image Size     Model  2018 Data  Batch Size  Replicas  Total Batch Size  \
# 0          128     EFNB0          1         256         1               256
# 1          128     EFNB0          1         128         1               128
# 2          128     EFNB0          1         128         1               128
# 3          128     EFNB0          1         128         1               128
# 4          128     EFNB0          0         256         1               256
# 5          128     EFNB0          0         256         1               256
# 6          128     EFNB0          1         128         1               128
# 7          128     EFNB0          1         128         1               128
# 8          128     EFNB0          1          64         1                64
# 9          128     EFNB0          0         256         1               256
# 10         128     EFNB0          0         128         1               128
# 11         128     EFNB0          1         128         1               128
# 12         128     EFNB0          0         256         1               256
# 13         192     EFNB0          0         128         1               128
# 14         256     EFNB0          1         128         1               128
# 15         256     EFNB0          1         128         1               128
# 16         256     EFNB0          0         128         1               128
# 17         128  EFNB0EXP          1         128         1               128
# 18         192  EFNB0EXP          1          64         2               128
# 19         128     EFNB1          0         128         1               128
# 20         192     EFNB1          1         128         1               128
# 21         192     EFNB1          0         128         1               128
# 22         256     EFNB1          1          64         1                64
# 23         256     EFNB1          0          64         1                64
# 0          256  EFNB1EXP          1          32         2                64
# 24         256     EFNB2          1          64         1                64
# 25         256     EFNB2          1          64         1                64
# 26         256     EFNB2          1          64         1                64
# 27         256     EFNB2          1          64         1                64
# 28         256     EFNB2          0          64         1                64
#
#     TTA Loops  CV Folds  Mean CV AUC  Std CV AUC  OOF AUC with TTA  \
# 0          25         5     0.862810    0.015301          0.899221
# 1          25         5     0.893108    0.009577          0.896964
# 2          25         5     0.894638    0.016115          0.899087
# 3          25         5     0.891281    0.012457          0.897615
# 4          25         5     0.858138    0.017181          0.892846
# 5          25         5     0.862265    0.021282          0.891697
# 6          25         3     0.868520    0.007854          0.891658
# 7          25         5     0.860609    0.011030          0.888065
# 8          25         5     0.892140    0.012269          0.881596
# 9          25         5     0.862378    0.000000          0.892097
# 10         50         5     0.869673    0.020289          0.893746
# 11         25         5     0.870027    0.019537          0.893820
# 12         25         5     0.862576    0.017381          0.895973
# 13         25         5     0.869117    0.000000          0.899562
# 14         25         5     0.905725    0.013085          0.913515
# 15         25         5     0.880362    0.021434          0.911405
# 16         25         5     0.881442    0.000000          0.905685
# 17         25         5     0.912633    0.002593          0.912759
# 18         25         5     0.902832    0.004064          0.910726
# 19         25         5     0.857287    0.015800          0.890922
# 20         25         5     0.885721    0.022526          0.902849
# 21         25         5     0.872257    0.024584          0.898725
# 22         25         5     0.894408    0.012953          0.912732
# 23         25         5     0.886249    0.010748          0.907220
# 0          25         5     0.955029    0.018500          0.962169
# 24         25         5     0.956336    0.007296          0.961748
# 25         25         5     0.903819    0.017790          0.913861
# 26         25         5     0.888146    0.020124          0.909704
# 27         25         5     0.889753    0.014140          0.915927
# 28         25         5     0.884384    0.009332          0.909386
#
#     OOF AUC and Meta with TTA  Best average Meta weighting  Mean CV Loss  \
# 0                    0.899624                     0.028000      0.164090
# 1                    0.899278                     0.186000      0.471082
# 2                    0.899203                     0.074000      0.234308
# 3                    0.898825                     0.260000      0.430066
# 4                    0.893437                     0.058000      0.165035
# 5                    0.893361                     0.050000      0.164463
# 6                    0.891997                     0.013333      0.164465
# 7                    0.889803                     0.030000      0.164579
# 8                    0.883801                     0.106000      0.251114
# 9                    0.000000                     0.000000      0.164595
# 10                   0.000000                     0.000000      0.164480
# 11                   0.000000                     0.000000      0.163722
# 12                   0.000000                     0.000000      0.164683
# 13                   0.000000                     0.000000      0.163387
# 14                   0.914208                     0.172000      0.365035
# 15                   0.000000                     0.000000      0.161010
# 16                   0.000000                     0.000000      0.162524
# 17                   0.918679                     0.290000      0.472791
# 18                   0.911090                     0.000000      0.245847
# 19                   0.000000                     0.000000      0.164851
# 20                   0.000000                     0.000000      0.162546
# 21                   0.000000                     0.000000      0.163616
# 22                   0.000000                     0.000000      0.160833
# 23                   0.000000                     0.000000      0.162028
# 0                    0.962298                     0.164000      0.208217
# 24                   0.962125                     0.038000      0.200851
# 25                   0.914280                     0.078000      0.207408
# 26                   0.910367                     0.050000      0.161091
# 27                   0.000000                     0.000000      0.161170
# 28                   0.000000                     0.000000      0.161911
#
#     Total Epochs  Early Stop  Best AUC Epoch  Best Loss Epoch  Kaggle LB AUC  \
# 0             12           0        8.800000         9.400000         0.0000
# 1             12           0       10.400000        10.400000         0.0000
# 2             12           0        9.200000         8.000000         0.0000
# 3             12           0       10.000000         9.000000         0.0000
# 4             12           0        7.400000         9.400000         0.0000
# 5             12           0        9.200000         9.400000         0.0000
# 6             20           0       10.000000        15.000000         0.0000
# 7             12           0        8.200000         9.800000         0.0000
# 8             15           0       12.000000         6.140000            NaN
# 9             15           1        9.400000        10.200000         0.0000
# 10            30           0       12.600000        11.400000         0.0000
# 11            15           0        8.800000        10.000000         0.0000
# 12            20           0        9.400000        12.000000         0.0000
# 13            15           1        9.800000        10.200000         0.0000
# 14            12           0        8.600000         9.400000         0.0000
# 15            15           0        7.800000        12.000000         0.0000
# 16            15           1        9.400000        11.200000         0.0000
# 17            12           0        9.000000         9.666667         0.0000
# 18            20           0       10.666667        15.166667         0.0000
# 19            15           1       12.200000        11.200000         0.0000
# 20            15           0       10.200000         9.800000         0.0000
# 21            15           1       10.600000        10.800000         0.0000
# 22            15           0        8.800000        13.400000         0.0000
# 23            15           1        9.600000        10.200000         0.0000
# 0             60           0       43.600000        41.800000         0.0000
# 24            17           0       15.600000        10.400000         0.0000
# 25            12           0        7.200000         7.800000         0.0000
# 26            20           0       10.600000        10.600000         0.0000
# 27            15           0        9.200000        11.000000         0.9377
# 28            15           1        9.600000         9.400000         0.9296
#
#     Kaggle LB AUC w Meta
# 0                 0.0000
# 1                 0.0000
# 2                 0.0000
# 3                 0.0000
# 4                 0.0000
# 5                 0.0000
# 6                 0.0000
# 7                 0.0000
# 8                    NaN
# 9                 0.0000
# 10                0.0000
# 11                0.0000
# 12                0.0000
# 13                0.0000
# 14                0.0000
# 15                0.0000
# 16                0.0000
# 17                0.0000
# 18                0.0000
# 19                0.0000
# 20                0.0000
# 21                0.0000
# 22                0.0000
# 23                0.0000
# 0                 0.0000
# 24                0.9428
# 25                0.9361
# 26                0.9407
# 27                0.0000
# 28                0.0000

# %% [markdown]
# ### Prepare Kaggle File

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}F-EXP-submission.csv', index=False)
submission.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.032579
# 723   ISIC_0052349  0.025305
# 1560  ISIC_0058510  0.020482
# 2438  ISIC_0073313  0.026705
# 2750  ISIC_0073502  0.018688

# %%
submission_meta = pd.DataFrame(dict(image_name=image_names, target=preds_meta_ls[:,0]))
submission_meta = submission_meta.sort_values('image_name') 
submission_meta.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}F-EXP-META-submission.csv', index=False)
submission_meta.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.057132
# 723   ISIC_0052349  0.024722
# 1560  ISIC_0058510  0.025029
# 2438  ISIC_0073313  0.030143
# 2750  ISIC_0073502  0.023224

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
plt.hist(submission_meta.target,bins=100)
plt.show()
