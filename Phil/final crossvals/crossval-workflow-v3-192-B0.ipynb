# %% [markdown]
# ## Cross Validation Workflow Notebook v3

# %% [markdown]
# #### Sources of information, code and discussions

# %% [markdown]
# 1. This notebook follows the 5 step process presented in the Chris Deotte "How to compete with GPUs Workshop" [here][1].
# 2. Triple stratified KFold TFRecords used for image data is explained [here][2].
# 3. Some code sections have been reused from AgentAuers' notebook [here][3]
# 4. The advantage of using different input sizes is discussed [here][4]
# 5. Use external data by changing the variables `INC2019` and `INC2018`.These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][5]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [4]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147
# [5]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %% [markdown]
# ####  Initiatialise environment and import necessary libraries

# %% [markdown]
# # Initialize Environment

# %%
# Use if running in Kaggle environment
#!pip install -q efficientnet >> /dev/null

# %%
# import KaggleDatasets if running in Kaggle environment
#from kaggle_datasets import KaggleDatasets

import os, re, math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K

import efficientnet.tfkeras as efn

from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score 
from sklearn.utils import class_weight

# %% [markdown]
# ## Configuration
#
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 for conistent number of train and validation samples across folds
# * IMG_SIZES - These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter. Consider early stopping in Callbacks.
# * EFF_NETS - These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %% [markdown]
# Image sizes used in the Efficientnet model:
#
# - efficientnet-b0-224 -cv train with 192
# - efficientnet-b1-240 -cv train with 256
# - efficientnet-b2-260 -cv train with 256
# - efficientnet-b3-300 -cv train with 384
# - efficientnet-b4-380 -cv train with 384
# - efficientnet-b5-456 -cv train with 512
# - efficientnet-b6-528 -cv train with 512
# - efficientnet-b7-600 -cv train with 768
#
# Better to train with a larger size and let the model scale down rather than up.

# %%
ENV = "LOCAL" #or "KAGGLE"

# DEFAULT TO TPU TO ENSURE KAGGLE TPU COMPATIABILITY
# https://www.kaggle.com/docs/tpu
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 45

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 
IMG_SIZES = [192]*FOLDS

# META DATA? YES=1 NO=0
META = 1

# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0]*FOLDS
INC2018 = [1]*FOLDS

# UPSAMPLE MALIGNANT
M1 = [1]*FOLDS #2020 malig
M2 = [0]*FOLDS #ISIC malig
M3 = [0]*FOLDS #2019 good malig
M4 = [1]*FOLDS #2018 2017 malig - Malignant only images from HAM10000

# COARSE DROPOUT
DROP_FREQ = [0]*FOLDS # between 0 and 1
DROP_CT = [0]*FOLDS # may slow training if CT>16
DROP_SIZE = [0]*FOLDS # between 0 and 1

# BATCH SIZE AND EPOCHS
# TRY 8, 16, 32, 64, 128, 256. REDUCE IF OOM ERROR, HIGHER FOR TPUS
BATCH_SIZES = [64]*FOLDS
EPOCHS = [50]*FOLDS

#EARLY TOPPING
EARLY_STOPPING = 0 # Yes:1, No:0
PATIENCE = 10 

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [0]*FOLDS

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 25

# %% [markdown]
# #### Configure environment to use TPUs, Multiple GPUs, Single GPU or just CPU

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and GPU")
    

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    if len(tf.config.experimental.list_physical_devices('GPU')) > 1:
        strategy = tf.distribute.MirroredStrategy()
    else:
        strategy = tf.distribute.get_strategy()
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync

print(f'REPLICAS: {REPLICAS}')
# Out:
# connecting to TPU...
# Could not connect to TPU
# Using default strategy for CPU and GPU
# Num GPUs Available:  2
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# REPLICAS: 2

# %% [markdown]
# ### Step 1: Preprocess and file handling
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section.

# %%
# Load file locations
if ENV == 'KAGGLE':
    #Use GCS if running in Kaggle environment
    PATH = [None]*FOLDS; PATH2 = [None]*FOLDS; PATH3 = [None]*FOLDS
    for i,k in enumerate(IMG_SIZES):
        PATH[i] = KaggleDatasets().get_gcs_path('melanoma-%ix%i'%(k,k))
        PATH2[i] = KaggleDatasets().get_gcs_path('isic2019-%ix%i'%(k,k))
        PATH3[i] = KaggleDatasets().get_gcs_path('malignant-v2-%ix%i'%(k,k))
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))
       
if ENV == 'LOCAL':  
    # Use LDS if running in local environment
    PATH = [None]*FOLDS; PATH2 = [None]*FOLDS; PATH3 = [None]*FOLDS
    for i,k in enumerate(IMG_SIZES):
        PATH[i] = f"./siim-isic-melanoma-classification/tfrecords{k}"
        PATH2[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Ext"
        PATH3[i] = f"./siim-isic-melanoma-classification/tfrecords{k}Mal"
    files_train = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/train*.tfrec')))
    files_test  = np.sort(np.array(tf.io.gfile.glob(PATH[0] + '/test*.tfrec')))

# %%
# Save file locations
if ENV == 'KAGGLE':
    LOG_PATH = ''
    CV_OOF_PREDS_PATH = ''
    CV_TEST_PREDS_PATH = ''
    CV_FOLDS_PATH = ''

if ENV == 'LOCAL':
    LOG_PATH = './logs/'
    CV_OOF_PREDS_PATH = './cv_oof_preds/'
    CV_TEST_PREDS_PATH = './cv_test_preds/'
    CV_FOLDS_PATH = './cv_folds/'

# %%
# File handling functions
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']

def read_meta_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge'], example['target']

def read_meta_tfrecord_test(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image_name'], example['sex'], example['age_approx'], example['anatom_site_general_challenge']

def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
# Function to stream datasets into model when training, validating and predicting
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256,
                droprate=0, dropct=0, dropsize=0):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO)      
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim,
                                               droprate=droprate, dropct=dropct, dropsize=dropsize),
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %%
# Function to stream datasets into model when training, validating and predicting
column_names = ['image_name', 'sex', 'age_approx', 'anatom', 'target']
column_names_test = ['image_name', 'sex', 'age_approx', 'anatom']

def get_meta(files, batch_size=16, test=0):
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    if test:
        ds = ds.map(lambda example: read_meta_tfrecord_test(example), num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_meta_tfrecord(example), num_parallel_calls=AUTO)      
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
        
    return ds

def meta_unbatch(files, test=0):
    if test:
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy()]
                for img_name, sex, age, anatomy in iter(files.unbatch())])
        meta_df = pd.DataFrame(data = meta_np, columns=column_names_test)

    else:        
        meta_np = np.array([[img_name.numpy().decode("utf-8"),
                  sex.numpy(),
                  age.numpy(),
                  anatomy.numpy(),
                  target.numpy()] 
                for img_name, sex, age, anatomy, target in iter(files.unbatch())])
        
        meta_df = pd.DataFrame(data = meta_np, columns=column_names)
        meta_df = meta_df.astype({"target": int})
    return meta_df

# %% [markdown]
# ### Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation. This notebook also uses horizontal flip, saturation, contrast, brightness augmentation similar to last years winner.

# %%
# Assign variables
ROT_ = 180.0
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def dropout(image, DIM=256, PROBABILITY = 0.75, CT = 8, SZ = 0.2):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image with CT squares of side size SZ*DIM removed
    
    # DO DROPOUT WITH PROBABILITY DEFINED ABOVE
    P = tf.cast( tf.random.uniform([],0,1)<PROBABILITY, tf.int32)
    if (P==0)|(CT==0)|(SZ==0): return image
    
    for k in range(CT):
        # CHOOSE RANDOM LOCATION
        x = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        y = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        # COMPUTE SQUARE 
        WIDTH = tf.cast( SZ*DIM,tf.int32) * P
        ya = tf.math.maximum(0,y-WIDTH//2)
        yb = tf.math.minimum(DIM,y+WIDTH//2)
        xa = tf.math.maximum(0,x-WIDTH//2)
        xb = tf.math.minimum(DIM,x+WIDTH//2)
        # DROPOUT IMAGE
        one = image[ya:yb,0:xa,:]
        two = tf.zeros([yb-ya,xb-xa,3]) 
        three = image[ya:yb,xb:DIM,:]
        middle = tf.concat([one,two,three],axis=1)
        image = tf.concat([image[0:ya,:,:],middle,image[yb:DIM,:,:]],axis=0)
            
    # RESHAPE HACK SO TPU COMPILER KNOWS SHAPE OF OUTPUT TENSOR 
    image = tf.reshape(image,[DIM,DIM,3])
    return image

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

def prepare_image(img, augment=True, dim=256, droprate=0, dropct=0, dropsize=0):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        if (droprate!=0)&(dropct!=0)&(dropsize!=0): 
            img = dropout(img, DIM=dim, PROBABILITY=droprate, CT=dropct, SZ=dropsize)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

# %% [markdown]
# ### Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN. Also consider different models to provide diversity of predictions which may benefit the final ensemble.

# %%
EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7]

def build_model(dim=128, ef=0, v=0):
    inputs = tf.keras.layers.Input(shape=(dim,dim,3))
    
    base = EFNS[ef](input_shape=(dim,dim,3),weights='noisy-student',include_top=False)
    
    x = base(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=inputs,outputs=x)
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    
    if v:
        model.summary()
    
    return model

# Visualise model in use
build_model(dim=IMG_SIZES[0],ef=EFF_NETS[0],v=1)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# efficientnet-b0 (Functional) (None, 6, 6, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 4,008,829
# Non-trainable params: 42,016
# _________________________________________________________________

# %%
# META DATA FUNCTION

# Function to get meta data
def meta_model(meta_train, meta_val):
    L = 15
    feat = ['sex','age_approx','anatom']
    M = meta_train.target.mean()
    te = meta_train.groupby(feat)['target'].agg(['mean','count']).reset_index()
    te['ll'] = ((te['mean']*te['count'])+(M*L))/(te['count']+L)
    del te['mean'], te['count']
    meta_val = meta_val.merge( te, on=feat, how='left' )
    meta_val['ll'] = meta_val['ll'].fillna(M)
    return meta_val

# %% [markdown]
# ### Step 4: Training and Cross Validation

# %% [markdown]
# #### Training Schedule
# Thism is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
TS_CFG = dict(
    lr_start   = 0.000006, 
    lr_max     = 0.00000145 * REPLICAS * BATCH_SIZES[0],
    lr_min     = 0.000001,
    lr_ramp_ep = 5,
    lr_sus_ep  = 0,
    lr_decay   = 0.85
    )

# %%
def get_lr_callback(ts_cfg, batch_size=8):
    lr_start   = ts_cfg['lr_start']
    lr_max     = ts_cfg['lr_max']
    lr_min     = ts_cfg['lr_min']
    lr_ramp_ep = ts_cfg['lr_ramp_ep']
    lr_sus_ep  = ts_cfg['lr_sus_ep']
    lr_decay   = ts_cfg['lr_decay']
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    
    return lr_callback

# %% [markdown]
# #### Visualise Training Schedule

# %%
# Quick test and visualisation of learning rate schedule
# Important not to have a high learning rate which would destroy the pre-trained parameters
lr_start   = TS_CFG['lr_start']
lr_max     = TS_CFG['lr_max']
lr_min     = TS_CFG['lr_min']
lr_ramp_ep = TS_CFG['lr_ramp_ep']
lr_sus_ep  = TS_CFG['lr_sus_ep']
lr_decay   = TS_CFG['lr_decay']

def lrfn_sched(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

# Visualise learning rate schedule
rng = [i for i in range(20)]
y = [lrfn_sched(x) for x in rng]
plt.plot(rng, y)
plt.xlabel('epoch', size=14); plt.ylabel('learning rate', size=14)
plt.title('Training Schedule', size=16); plt.show()

# %% [markdown]
# #### Class Imbalance Analysis

# %%
# Analyze class imbalance in the targets
# Number of positive samples in training data: 470 (1.77% of total 33126)
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / (33126-470))*(33126)/2.0 
weight_for_1 = (1 / 470)*(33126)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.51
# Weight for class 1: 35.24

# %% [markdown]
# #### Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []
oof_tar = []
oof_val = []
oof_names = []
oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_meta_ls = np.zeros((count_data_items(files_test),1))

best_val_auc_ls = []
best_epoch_val_auc_ls = []

best_val_loss_ls = []
best_epoch_val_loss_ls = []

best_meta_wgts = []

#TESTING ONLY
loops = 0
max_loops = FOLDS #Use FOLDS or a number less than FOLDS if testing

#FITTING LOOP    
for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25)
    print('#### FOLD',fold+1)
    print('#'*25)
    print('#### Using the following TFRecords:')
    print(idxT,idxV)
    print(f'#### Image Size {IMG_SIZES[fold]} with EfficientNet B{EFF_NETS[fold]} and batch_size {BATCH_SIZES[fold]*REPLICAS}')
    print(f'#### DropoutFreq {DROP_FREQ[fold]} Count{DROP_CT[fold]} Size {DROP_SIZE[fold]}')
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    if M1[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT])
        print('#### Upsample MALIG-1 data (2020 comp)')
    if M2[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT+15])
        print('#### Upsample MALIG-2 data (ISIC website)')
    if M3[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1+30])
        print('#### Upsample MALIG-3 data (2019 comp)')
    if M4[fold]:
        files_train += tf.io.gfile.glob([PATH3[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+30])
        print('#### Upsample MALIG-4 data (2018 2017 comp)')        
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(PATH[fold] + '/test*.tfrec')))
    
    # DETERMINE CLASS WEIGHTS FROM TRAINING DATASET
    # Analyze class imbalance in the targets
    # Scaling by total/2 helps keep the loss to a similar magnitude.
    # The sum of the weights of all examples stays the same.
    ft = get_dataset(files_train, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    ott = np.array([target.numpy() for img, target in iter(ft.unbatch())])
    tot = len(ott)
    counts = np.bincount(ott[:])
    
    weight_for_0 = (1 / counts[0])*(tot)/2.0 
    weight_for_1 = (1 / counts[1])*(tot)/2.0
    class_weight = {0: weight_for_0, 1: weight_for_1}
    print('Weight for class 0: {:.2f}'.format(weight_for_0))
    print('Weight for class 1: {:.2f}'.format(weight_for_1))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold],v=0)
        
    # CALLBACKS - SAVE BEST MODEL EACH FOLD ALSO UTILISE EARLY STOPPING TO ALLOW MORE EPOCHS
    svl = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-loss.h5', monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
    sva = tf.keras.callbacks.ModelCheckpoint(
        f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-auc.h5', monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    if EARLY_STOPPING:
        es = tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=PATIENCE, verbose=VERBOSE, mode='auto')
        callback_list = [svl, sva, es, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
    else:
        callback_list = [svl, sva, get_lr_callback(TS_CFG, BATCH_SIZES[fold])]
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                    dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold],
                    droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]),
        epochs=EPOCHS[fold],
        callbacks = callback_list, 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid, augment=True, shuffle=False, repeat=False, dim=IMG_SIZES[fold],
                                   droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]),
        class_weight=class_weight,
        verbose=VERBOSE
    )
    
    # DETERMINE BEST SCORES AND EPOCHS
    val_auc_ls = history.history['val_auc']
    val_loss_ls = history.history['val_loss']
    
    best_val_auc = max(val_auc_ls)
    best_val_loss = min(val_loss_ls)
    best_val_auc_ls.append(best_val_auc)
    best_val_loss_ls.append(best_val_loss)
    
    opt_epoch_auc = val_auc_ls.index(best_val_auc)
    opt_epoch_loss = val_loss_ls.index(best_val_loss)
    best_epoch_val_auc_ls.append(opt_epoch_auc)
    best_epoch_val_loss_ls.append(opt_epoch_loss)
    
    #RELOAD BEST WEIGHTS AT BEST EPOCH
    print('Loading best model...')
    model.load_weights(f'{CV_FOLDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-fold-{fold}-auc.h5')
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
                          repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*2,
                          droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/2/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))

    # INCLUDING ENSEMBLE OF META DATA
    meta_wgt_auc = []

    dsp_ft = get_meta(files_train)
    dsp_fv = get_meta(files_valid)
    meta_train = meta_unbatch(dsp_ft)
    meta_val = meta_unbatch(dsp_fv)
    meta_pred = meta_model(meta_train, meta_val)
    meta_pred['oof'] = oof_pred[-1]
    meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])    

    for wgt in range(0, 31, 1):
        wgt = wgt/100
        meta_pred['ens'] = ((1-wgt)*meta_pred.oof + wgt*meta_pred.ll)
        meta_auc = roc_auc_score(meta_pred['target'],meta_pred['ll'])
        meta_ens_auc = roc_auc_score(meta_pred['target'],meta_pred['ens'])    
        meta_wgt_auc.append([wgt, meta_ens_auc])
        #print(f"With Meta Weight {wgt}, Meta and OOF AUC with TTA:", meta_ens_auc)
    best_meta_wgts.append(max(meta_wgt_auc, key=lambda item: item[1]))    
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
                         repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold]*4,
                         droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/4/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,]
    pred = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += pred * WGTS[fold]
    
    dsp_test = get_meta(files_test, BATCH_SIZES[0], test=1)
    meta_test = meta_unbatch(dsp_test, test=1)
    meta_test = meta_model(meta_train, meta_test)
    meta_test['preds'] = pred
    meta_test['preds_meta'] = best_meta_wgts[-1][0]*meta_test.ll + (1-best_meta_wgts[-1][0])*meta_test.preds
    preds_meta = np.array([meta_test.preds_meta]).T
    preds_meta_ls += preds_meta * WGTS[fold]

    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print(f'#### FOLD {fold+1} OOF AUC without TTA = {oof_val[-1]:.3f}, with TTA = {auc:.3f}')
    print("Meta only AUC:", meta_auc) 
    print(f"The best weight is {best_meta_wgts[-1][0]}, Meta and OOF AUC with TTA: {best_meta_wgts[-1][1]:.3f}")
    
    COMPLETED_EPOCHS = len(history.history['loss'])
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] )
        y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4')
        plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] )
        y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728')
        plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i, M1=%i, M2=%i, M3=%i, M4=%i\n\
        batch_size %i, dropout_freq=%.2f count=%i size=%.3f'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold],M1[fold],M2[fold],M3[fold],
                 M4[fold],BATCH_SIZES[fold]*REPLICAS,DROP_FREQ[fold],DROP_CT[fold],DROP_SIZE[fold]),size=18)
        plt.legend(loc=3)
        plt.show()  
        
        # TESTING ONLY
        loops+=1
        if loops == max_loops:
            break
        else:
            continue
        
        del model; z = gc.collect()
# Out:
# #########################
# #### FOLD 1
# #########################
# #### Using the following TFRecords:
# [ 0  1  2  3  4  5  7 10 11 12 13 14] [6 8 9]
# #### Image Size 192 with EfficientNet B0 and batch_size 128
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.55
# Weight for class 1: 5.40
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Training...
# Epoch 1/50
# WARNING:tensorflow:From /home/phil/anaconda3/envs/tf37/lib/python3.7/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# 298/298 [==============================] - ETA: 0s - loss: 0.6757 - auc: 0.6933
# Epoch 00001: val_loss improved from inf to 0.57765, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.69331, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 84s 282ms/step - loss: 0.6757 - auc: 0.6933 - val_loss: 0.5777 - val_auc: 0.6933
# Epoch 2/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4970 - auc: 0.8606
# Epoch 00002: val_loss improved from 0.57765 to 0.43442, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00002: val_auc improved from 0.69331 to 0.83207, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 82s 275ms/step - loss: 0.4970 - auc: 0.8606 - val_loss: 0.4344 - val_auc: 0.8321
# Epoch 3/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4384 - auc: 0.8972
# Epoch 00003: val_loss improved from 0.43442 to 0.34892, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00003: val_auc improved from 0.83207 to 0.86483, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 83s 280ms/step - loss: 0.4384 - auc: 0.8972 - val_loss: 0.3489 - val_auc: 0.8648
# Epoch 4/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4096 - auc: 0.9137
# Epoch 00004: val_loss improved from 0.34892 to 0.28848, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00004: val_auc improved from 0.86483 to 0.87073, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 84s 283ms/step - loss: 0.4096 - auc: 0.9137 - val_loss: 0.2885 - val_auc: 0.8707
# Epoch 5/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3954 - auc: 0.9227
# Epoch 00005: val_loss did not improve from 0.28848
#
# Epoch 00005: val_auc improved from 0.87073 to 0.88431, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 85s 284ms/step - loss: 0.3954 - auc: 0.9227 - val_loss: 0.3947 - val_auc: 0.8843
# Epoch 6/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3701 - auc: 0.9354
# Epoch 00006: val_loss improved from 0.28848 to 0.25719, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00006: val_auc improved from 0.88431 to 0.88732, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 85s 284ms/step - loss: 0.3701 - auc: 0.9354 - val_loss: 0.2572 - val_auc: 0.8873
# Epoch 7/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3454 - auc: 0.9465
# Epoch 00007: val_loss did not improve from 0.25719
#
# Epoch 00007: val_auc did not improve from 0.88732
# 298/298 [==============================] - 83s 278ms/step - loss: 0.3454 - auc: 0.9465 - val_loss: 0.2720 - val_auc: 0.8805
# Epoch 8/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3276 - auc: 0.9550
# Epoch 00008: val_loss did not improve from 0.25719
#
# Epoch 00008: val_auc did not improve from 0.88732
# 298/298 [==============================] - 82s 277ms/step - loss: 0.3276 - auc: 0.9550 - val_loss: 0.2698 - val_auc: 0.8805
# Epoch 9/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3089 - auc: 0.9610
# Epoch 00009: val_loss improved from 0.25719 to 0.21588, saving model to ./cv_folds/EB0-192-fold-0-loss.h5
#
# Epoch 00009: val_auc did not improve from 0.88732
# 298/298 [==============================] - 86s 290ms/step - loss: 0.3089 - auc: 0.9610 - val_loss: 0.2159 - val_auc: 0.8869
# Epoch 10/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2922 - auc: 0.9675
# Epoch 00010: val_loss did not improve from 0.21588
#
# Epoch 00010: val_auc did not improve from 0.88732
# 298/298 [==============================] - 85s 285ms/step - loss: 0.2922 - auc: 0.9675 - val_loss: 0.2502 - val_auc: 0.8860
# Epoch 11/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2778 - auc: 0.9721
# Epoch 00011: val_loss did not improve from 0.21588
#
# Epoch 00011: val_auc did not improve from 0.88732
# 298/298 [==============================] - 84s 280ms/step - loss: 0.2778 - auc: 0.9721 - val_loss: 0.2999 - val_auc: 0.8663
# Epoch 12/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2711 - auc: 0.9745
# Epoch 00012: val_loss did not improve from 0.21588
#
# Epoch 00012: val_auc did not improve from 0.88732
# 298/298 [==============================] - 84s 283ms/step - loss: 0.2711 - auc: 0.9745 - val_loss: 0.2625 - val_auc: 0.8794
# Epoch 13/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2627 - auc: 0.9766
# Epoch 00013: val_loss did not improve from 0.21588
#
# Epoch 00013: val_auc did not improve from 0.88732
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2627 - auc: 0.9766 - val_loss: 0.2472 - val_auc: 0.8834
# Epoch 14/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2527 - auc: 0.9793
# Epoch 00014: val_loss did not improve from 0.21588
#
# Epoch 00014: val_auc did not improve from 0.88732
# 298/298 [==============================] - 84s 283ms/step - loss: 0.2527 - auc: 0.9793 - val_loss: 0.2505 - val_auc: 0.8595
# Epoch 15/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2476 - auc: 0.9811
# Epoch 00015: val_loss did not improve from 0.21588
#
# Epoch 00015: val_auc improved from 0.88732 to 0.90175, saving model to ./cv_folds/EB0-192-fold-0-auc.h5
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2476 - auc: 0.9811 - val_loss: 0.2469 - val_auc: 0.9018
# Epoch 16/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2400 - auc: 0.9832
# Epoch 00016: val_loss did not improve from 0.21588
#
# Epoch 00016: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 280ms/step - loss: 0.2400 - auc: 0.9832 - val_loss: 0.2598 - val_auc: 0.8713
# Epoch 17/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2387 - auc: 0.9835
# Epoch 00017: val_loss did not improve from 0.21588
#
# Epoch 00017: val_auc did not improve from 0.90175
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2387 - auc: 0.9835 - val_loss: 0.2608 - val_auc: 0.8610
# Epoch 18/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2302 - auc: 0.9849
# Epoch 00018: val_loss did not improve from 0.21588
#
# Epoch 00018: val_auc did not improve from 0.90175
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2302 - auc: 0.9849 - val_loss: 0.2523 - val_auc: 0.8597
# Epoch 19/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2299 - auc: 0.9857
# Epoch 00019: val_loss did not improve from 0.21588
#
# Epoch 00019: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2299 - auc: 0.9857 - val_loss: 0.2573 - val_auc: 0.8688
# Epoch 20/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2281 - auc: 0.9861
# Epoch 00020: val_loss did not improve from 0.21588
#
# Epoch 00020: val_auc did not improve from 0.90175
# 298/298 [==============================] - 85s 285ms/step - loss: 0.2281 - auc: 0.9861 - val_loss: 0.2602 - val_auc: 0.8852
# Epoch 21/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2235 - auc: 0.9865
# Epoch 00021: val_loss did not improve from 0.21588
#
# Epoch 00021: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2235 - auc: 0.9865 - val_loss: 0.2568 - val_auc: 0.8759
# Epoch 22/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2275 - auc: 0.9864
# Epoch 00022: val_loss did not improve from 0.21588
#
# Epoch 00022: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 280ms/step - loss: 0.2275 - auc: 0.9864 - val_loss: 0.2637 - val_auc: 0.8564
# Epoch 23/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2203 - auc: 0.9875
# Epoch 00023: val_loss did not improve from 0.21588
#
# Epoch 00023: val_auc did not improve from 0.90175
# 298/298 [==============================] - 86s 287ms/step - loss: 0.2203 - auc: 0.9875 - val_loss: 0.2424 - val_auc: 0.8791
# Epoch 24/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2210 - auc: 0.9875
# Epoch 00024: val_loss did not improve from 0.21588
#
# Epoch 00024: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2210 - auc: 0.9875 - val_loss: 0.2433 - val_auc: 0.8565
# Epoch 25/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2188 - auc: 0.9879
# Epoch 00025: val_loss did not improve from 0.21588
#
# Epoch 00025: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2188 - auc: 0.9879 - val_loss: 0.2427 - val_auc: 0.8643
# Epoch 26/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2194 - auc: 0.9879
# Epoch 00026: val_loss did not improve from 0.21588
#
# Epoch 00026: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2194 - auc: 0.9879 - val_loss: 0.2335 - val_auc: 0.8685
# Epoch 27/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2173 - auc: 0.9884
# Epoch 00027: val_loss did not improve from 0.21588
#
# Epoch 00027: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2173 - auc: 0.9884 - val_loss: 0.2377 - val_auc: 0.8478
# Epoch 28/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2162 - auc: 0.9883
# Epoch 00028: val_loss did not improve from 0.21588
#
# Epoch 00028: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 279ms/step - loss: 0.2162 - auc: 0.9883 - val_loss: 0.2320 - val_auc: 0.8646
# Epoch 29/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2150 - auc: 0.9889
# Epoch 00029: val_loss did not improve from 0.21588
#
# Epoch 00029: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2150 - auc: 0.9889 - val_loss: 0.2308 - val_auc: 0.8442
# Epoch 30/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2186 - auc: 0.9880
# Epoch 00030: val_loss did not improve from 0.21588
#
# Epoch 00030: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2186 - auc: 0.9880 - val_loss: 0.2280 - val_auc: 0.8641
# Epoch 31/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2143 - auc: 0.9891
# Epoch 00031: val_loss did not improve from 0.21588
#
# Epoch 00031: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 280ms/step - loss: 0.2143 - auc: 0.9891 - val_loss: 0.2253 - val_auc: 0.8502
# Epoch 32/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2153 - auc: 0.9887
# Epoch 00032: val_loss did not improve from 0.21588
#
# Epoch 00032: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2153 - auc: 0.9887 - val_loss: 0.2201 - val_auc: 0.8739
# Epoch 33/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2140 - auc: 0.9894
# Epoch 00033: val_loss did not improve from 0.21588
#
# Epoch 00033: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2140 - auc: 0.9894 - val_loss: 0.2248 - val_auc: 0.8639
# Epoch 34/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2163 - auc: 0.9887
# Epoch 00034: val_loss did not improve from 0.21588
#
# Epoch 00034: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2163 - auc: 0.9887 - val_loss: 0.2218 - val_auc: 0.8289
# Epoch 35/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2138 - auc: 0.9893
# Epoch 00035: val_loss did not improve from 0.21588
#
# Epoch 00035: val_auc did not improve from 0.90175
# 298/298 [==============================] - 86s 287ms/step - loss: 0.2138 - auc: 0.9893 - val_loss: 0.2201 - val_auc: 0.8567
# Epoch 36/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2128 - auc: 0.9895
# Epoch 00036: val_loss did not improve from 0.21588
#
# Epoch 00036: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 280ms/step - loss: 0.2128 - auc: 0.9895 - val_loss: 0.2222 - val_auc: 0.8671
# Epoch 37/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2140 - auc: 0.9889
# Epoch 00037: val_loss did not improve from 0.21588
#
# Epoch 00037: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2140 - auc: 0.9889 - val_loss: 0.2187 - val_auc: 0.8629
# Epoch 38/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2140 - auc: 0.9891
# Epoch 00038: val_loss did not improve from 0.21588
#
# Epoch 00038: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2140 - auc: 0.9891 - val_loss: 0.2240 - val_auc: 0.8466
# Epoch 39/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2132 - auc: 0.9892
# Epoch 00039: val_loss did not improve from 0.21588
#
# Epoch 00039: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2132 - auc: 0.9892 - val_loss: 0.2234 - val_auc: 0.8454
# Epoch 40/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2133 - auc: 0.9891
# Epoch 00040: val_loss did not improve from 0.21588
#
# Epoch 00040: val_auc did not improve from 0.90175
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2133 - auc: 0.9891 - val_loss: 0.2171 - val_auc: 0.8736
# Epoch 41/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2116 - auc: 0.9898
# Epoch 00041: val_loss did not improve from 0.21588
#
# Epoch 00041: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 281ms/step - loss: 0.2116 - auc: 0.9898 - val_loss: 0.2185 - val_auc: 0.8577
# Epoch 42/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2121 - auc: 0.9897
# Epoch 00042: val_loss did not improve from 0.21588
#
# Epoch 00042: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 277ms/step - loss: 0.2121 - auc: 0.9897 - val_loss: 0.2176 - val_auc: 0.8624
# Epoch 43/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2112 - auc: 0.9899
# Epoch 00043: val_loss did not improve from 0.21588
#
# Epoch 00043: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 279ms/step - loss: 0.2112 - auc: 0.9899 - val_loss: 0.2222 - val_auc: 0.8555
# Epoch 44/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2132 - auc: 0.9892
# Epoch 00044: val_loss did not improve from 0.21588
#
# Epoch 00044: val_auc did not improve from 0.90175
# 298/298 [==============================] - 82s 277ms/step - loss: 0.2132 - auc: 0.9892 - val_loss: 0.2235 - val_auc: 0.8424
# Epoch 45/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2102 - auc: 0.9902
# Epoch 00045: val_loss did not improve from 0.21588
#
# Epoch 00045: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2102 - auc: 0.9902 - val_loss: 0.2234 - val_auc: 0.8554
# Epoch 46/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2120 - auc: 0.9898
# Epoch 00046: val_loss did not improve from 0.21588
#
# Epoch 00046: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 279ms/step - loss: 0.2120 - auc: 0.9898 - val_loss: 0.2213 - val_auc: 0.8271
# Epoch 47/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2122 - auc: 0.9894
# Epoch 00047: val_loss did not improve from 0.21588
#
# Epoch 00047: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2122 - auc: 0.9894 - val_loss: 0.2182 - val_auc: 0.8563
# Epoch 48/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2065 - auc: 0.9906
# Epoch 00048: val_loss did not improve from 0.21588
#
# Epoch 00048: val_auc did not improve from 0.90175
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2065 - auc: 0.9906 - val_loss: 0.2199 - val_auc: 0.8473
# Epoch 49/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2106 - auc: 0.9899
# Epoch 00049: val_loss did not improve from 0.21588
#
# Epoch 00049: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 280ms/step - loss: 0.2106 - auc: 0.9899 - val_loss: 0.2177 - val_auc: 0.8509
# Epoch 50/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2100 - auc: 0.9901
# Epoch 00050: val_loss did not improve from 0.21588
#
# Epoch 00050: val_auc did not improve from 0.90175
# 298/298 [==============================] - 84s 282ms/step - loss: 0.2100 - auc: 0.9901 - val_loss: 0.2183 - val_auc: 0.8606
# Loading best model...
# Predicting OOF with TTA...
# 638/637 [==============================] - 48s 75ms/step
# Predicting Test with TTA...
# 537/536 [==============================] - 76s 141ms/step
# #### FOLD 1 OOF AUC without TTA = 0.902, with TTA = 0.902
# Meta only AUC: 0.6701450490844382
# The best weight is 0.3, Meta and OOF AUC with TTA: 0.912
# #########################
# #### FOLD 2
# #########################
# #### Using the following TFRecords:
# [ 0  1  3  4  5  6  8  9 11 12 13 14] [ 2  7 10]
# #### Image Size 192 with EfficientNet B0 and batch_size 128
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.55
# Weight for class 1: 5.40
# Training...
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# 298/298 [==============================] - ETA: 0s - loss: 0.6864 - auc: 0.6842
# Epoch 00001: val_loss improved from inf to 0.56545, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.73604, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 88s 295ms/step - loss: 0.6864 - auc: 0.6842 - val_loss: 0.5655 - val_auc: 0.7360
# Epoch 2/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4994 - auc: 0.8582
# Epoch 00002: val_loss improved from 0.56545 to 0.39133, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00002: val_auc improved from 0.73604 to 0.86214, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 85s 285ms/step - loss: 0.4994 - auc: 0.8582 - val_loss: 0.3913 - val_auc: 0.8621
# Epoch 3/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4443 - auc: 0.8923
# Epoch 00003: val_loss improved from 0.39133 to 0.34935, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00003: val_auc improved from 0.86214 to 0.89730, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 84s 283ms/step - loss: 0.4443 - auc: 0.8923 - val_loss: 0.3493 - val_auc: 0.8973
# Epoch 4/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4144 - auc: 0.9135
# Epoch 00004: val_loss improved from 0.34935 to 0.31966, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00004: val_auc did not improve from 0.89730
# 298/298 [==============================] - 82s 276ms/step - loss: 0.4144 - auc: 0.9135 - val_loss: 0.3197 - val_auc: 0.8949
# Epoch 5/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3942 - auc: 0.9238
# Epoch 00005: val_loss did not improve from 0.31966
#
# Epoch 00005: val_auc did not improve from 0.89730
# 298/298 [==============================] - 82s 274ms/step - loss: 0.3942 - auc: 0.9238 - val_loss: 0.3837 - val_auc: 0.8908
# Epoch 6/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3732 - auc: 0.9350
# Epoch 00006: val_loss did not improve from 0.31966
#
# Epoch 00006: val_auc improved from 0.89730 to 0.90136, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 83s 278ms/step - loss: 0.3732 - auc: 0.9350 - val_loss: 0.3480 - val_auc: 0.9014
# Epoch 7/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3467 - auc: 0.9454
# Epoch 00007: val_loss improved from 0.31966 to 0.26961, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00007: val_auc improved from 0.90136 to 0.91456, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 83s 278ms/step - loss: 0.3467 - auc: 0.9454 - val_loss: 0.2696 - val_auc: 0.9146
# Epoch 8/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3299 - auc: 0.9536
# Epoch 00008: val_loss did not improve from 0.26961
#
# Epoch 00008: val_auc did not improve from 0.91456
# 298/298 [==============================] - 82s 276ms/step - loss: 0.3299 - auc: 0.9536 - val_loss: 0.4178 - val_auc: 0.8977
# Epoch 9/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3147 - auc: 0.9594
# Epoch 00009: val_loss did not improve from 0.26961
#
# Epoch 00009: val_auc improved from 0.91456 to 0.91576, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 83s 278ms/step - loss: 0.3147 - auc: 0.9594 - val_loss: 0.2980 - val_auc: 0.9158
# Epoch 10/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2963 - auc: 0.9659
# Epoch 00010: val_loss improved from 0.26961 to 0.26619, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00010: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2963 - auc: 0.9659 - val_loss: 0.2662 - val_auc: 0.8907
# Epoch 11/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2871 - auc: 0.9695
# Epoch 00011: val_loss improved from 0.26619 to 0.25495, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00011: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2871 - auc: 0.9695 - val_loss: 0.2549 - val_auc: 0.8912
# Epoch 12/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2754 - auc: 0.9729
# Epoch 00012: val_loss improved from 0.25495 to 0.24011, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00012: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2754 - auc: 0.9729 - val_loss: 0.2401 - val_auc: 0.9007
# Epoch 13/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2683 - auc: 0.9753
# Epoch 00013: val_loss did not improve from 0.24011
#
# Epoch 00013: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 279ms/step - loss: 0.2683 - auc: 0.9753 - val_loss: 0.2581 - val_auc: 0.8853
# Epoch 14/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2561 - auc: 0.9787
# Epoch 00014: val_loss improved from 0.24011 to 0.23864, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00014: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2561 - auc: 0.9787 - val_loss: 0.2386 - val_auc: 0.9018
# Epoch 15/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2559 - auc: 0.9784
# Epoch 00015: val_loss did not improve from 0.23864
#
# Epoch 00015: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2559 - auc: 0.9784 - val_loss: 0.2655 - val_auc: 0.8879
# Epoch 16/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2474 - auc: 0.9813
# Epoch 00016: val_loss did not improve from 0.23864
#
# Epoch 00016: val_auc did not improve from 0.91576
# 298/298 [==============================] - 82s 277ms/step - loss: 0.2474 - auc: 0.9813 - val_loss: 0.2523 - val_auc: 0.9022
# Epoch 17/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2451 - auc: 0.9825
# Epoch 00017: val_loss did not improve from 0.23864
#
# Epoch 00017: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2451 - auc: 0.9825 - val_loss: 0.2587 - val_auc: 0.9053
# Epoch 18/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2384 - auc: 0.9833
# Epoch 00018: val_loss did not improve from 0.23864
#
# Epoch 00018: val_auc did not improve from 0.91576
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2384 - auc: 0.9833 - val_loss: 0.2543 - val_auc: 0.8988
# Epoch 19/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2393 - auc: 0.9832
# Epoch 00019: val_loss improved from 0.23864 to 0.23691, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00019: val_auc improved from 0.91576 to 0.91588, saving model to ./cv_folds/EB0-192-fold-1-auc.h5
# 298/298 [==============================] - 83s 280ms/step - loss: 0.2393 - auc: 0.9832 - val_loss: 0.2369 - val_auc: 0.9159
# Epoch 20/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2318 - auc: 0.9855
# Epoch 00020: val_loss did not improve from 0.23691
#
# Epoch 00020: val_auc did not improve from 0.91588
# 298/298 [==============================] - 83s 279ms/step - loss: 0.2318 - auc: 0.9855 - val_loss: 0.2618 - val_auc: 0.8856
# Epoch 21/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2290 - auc: 0.9856
# Epoch 00021: val_loss did not improve from 0.23691
#
# Epoch 00021: val_auc did not improve from 0.91588
# 298/298 [==============================] - 83s 278ms/step - loss: 0.2290 - auc: 0.9856 - val_loss: 0.2424 - val_auc: 0.8905
# Epoch 22/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2277 - auc: 0.9860
# Epoch 00022: val_loss improved from 0.23691 to 0.23678, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00022: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2277 - auc: 0.9860 - val_loss: 0.2368 - val_auc: 0.8815
# Epoch 23/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2310 - auc: 0.9856
# Epoch 00023: val_loss improved from 0.23678 to 0.23220, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00023: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2310 - auc: 0.9856 - val_loss: 0.2322 - val_auc: 0.8926
# Epoch 24/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2261 - auc: 0.9863
# Epoch 00024: val_loss improved from 0.23220 to 0.23006, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00024: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2261 - auc: 0.9863 - val_loss: 0.2301 - val_auc: 0.8971
# Epoch 25/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2294 - auc: 0.9855
# Epoch 00025: val_loss did not improve from 0.23006
#
# Epoch 00025: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2294 - auc: 0.9855 - val_loss: 0.2355 - val_auc: 0.8883
# Epoch 26/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2207 - auc: 0.9881
# Epoch 00026: val_loss improved from 0.23006 to 0.22832, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00026: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2207 - auc: 0.9881 - val_loss: 0.2283 - val_auc: 0.8954
# Epoch 27/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2209 - auc: 0.9874
# Epoch 00027: val_loss improved from 0.22832 to 0.22782, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00027: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2209 - auc: 0.9874 - val_loss: 0.2278 - val_auc: 0.8791
# Epoch 28/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2252 - auc: 0.9869
# Epoch 00028: val_loss improved from 0.22782 to 0.22588, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00028: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2252 - auc: 0.9869 - val_loss: 0.2259 - val_auc: 0.8834
# Epoch 29/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2232 - auc: 0.9869
# Epoch 00029: val_loss did not improve from 0.22588
#
# Epoch 00029: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2232 - auc: 0.9869 - val_loss: 0.2287 - val_auc: 0.8894
# Epoch 30/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2201 - auc: 0.9882
# Epoch 00030: val_loss improved from 0.22588 to 0.22100, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00030: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2201 - auc: 0.9882 - val_loss: 0.2210 - val_auc: 0.8952
# Epoch 31/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2211 - auc: 0.9878
# Epoch 00031: val_loss did not improve from 0.22100
#
# Epoch 00031: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2211 - auc: 0.9878 - val_loss: 0.2232 - val_auc: 0.8759
# Epoch 32/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2209 - auc: 0.9877
# Epoch 00032: val_loss improved from 0.22100 to 0.22058, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00032: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2209 - auc: 0.9877 - val_loss: 0.2206 - val_auc: 0.8848
# Epoch 33/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2203 - auc: 0.9881
# Epoch 00033: val_loss improved from 0.22058 to 0.22013, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00033: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2203 - auc: 0.9881 - val_loss: 0.2201 - val_auc: 0.8879
# Epoch 34/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2166 - auc: 0.9889
# Epoch 00034: val_loss improved from 0.22013 to 0.21965, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00034: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2166 - auc: 0.9889 - val_loss: 0.2196 - val_auc: 0.9030
# Epoch 35/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2245 - auc: 0.9872
# Epoch 00035: val_loss did not improve from 0.21965
#
# Epoch 00035: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2245 - auc: 0.9872 - val_loss: 0.2256 - val_auc: 0.8749
# Epoch 36/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2203 - auc: 0.9878
# Epoch 00036: val_loss did not improve from 0.21965
#
# Epoch 00036: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2203 - auc: 0.9878 - val_loss: 0.2214 - val_auc: 0.8902
# Epoch 37/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2168 - auc: 0.9885
# Epoch 00037: val_loss improved from 0.21965 to 0.21409, saving model to ./cv_folds/EB0-192-fold-1-loss.h5
#
# Epoch 00037: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2168 - auc: 0.9885 - val_loss: 0.2141 - val_auc: 0.9026
# Epoch 38/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2172 - auc: 0.9886
# Epoch 00038: val_loss did not improve from 0.21409
#
# Epoch 00038: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2172 - auc: 0.9886 - val_loss: 0.2162 - val_auc: 0.8818
# Epoch 39/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2234 - auc: 0.9874
# Epoch 00039: val_loss did not improve from 0.21409
#
# Epoch 00039: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2234 - auc: 0.9874 - val_loss: 0.2166 - val_auc: 0.8736
# Epoch 40/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2196 - auc: 0.9882
# Epoch 00040: val_loss did not improve from 0.21409
#
# Epoch 00040: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2196 - auc: 0.9882 - val_loss: 0.2186 - val_auc: 0.8836
# Epoch 41/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2173 - auc: 0.9886
# Epoch 00041: val_loss did not improve from 0.21409
#
# Epoch 00041: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2173 - auc: 0.9886 - val_loss: 0.2175 - val_auc: 0.8887
# Epoch 42/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2165 - auc: 0.9886
# Epoch 00042: val_loss did not improve from 0.21409
#
# Epoch 00042: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2165 - auc: 0.9886 - val_loss: 0.2161 - val_auc: 0.8966
# Epoch 43/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2201 - auc: 0.9879
# Epoch 00043: val_loss did not improve from 0.21409
#
# Epoch 00043: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2201 - auc: 0.9879 - val_loss: 0.2174 - val_auc: 0.8825
# Epoch 44/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2177 - auc: 0.9885
# Epoch 00044: val_loss did not improve from 0.21409
#
# Epoch 00044: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2177 - auc: 0.9885 - val_loss: 0.2194 - val_auc: 0.8989
# Epoch 45/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2170 - auc: 0.9889
# Epoch 00045: val_loss did not improve from 0.21409
#
# Epoch 00045: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2170 - auc: 0.9889 - val_loss: 0.2164 - val_auc: 0.9032
# Epoch 46/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2145 - auc: 0.9891
# Epoch 00046: val_loss did not improve from 0.21409
#
# Epoch 00046: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2145 - auc: 0.9891 - val_loss: 0.2173 - val_auc: 0.9031
# Epoch 47/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2167 - auc: 0.9886
# Epoch 00047: val_loss did not improve from 0.21409
#
# Epoch 00047: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2167 - auc: 0.9886 - val_loss: 0.2186 - val_auc: 0.8952
# Epoch 48/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2168 - auc: 0.9886
# Epoch 00048: val_loss did not improve from 0.21409
#
# Epoch 00048: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2168 - auc: 0.9886 - val_loss: 0.2206 - val_auc: 0.8790
# Epoch 49/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2202 - auc: 0.9877
# Epoch 00049: val_loss did not improve from 0.21409
#
# Epoch 00049: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2202 - auc: 0.9877 - val_loss: 0.2219 - val_auc: 0.8582
# Epoch 50/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2154 - auc: 0.9890
# Epoch 00050: val_loss did not improve from 0.21409
#
# Epoch 00050: val_auc did not improve from 0.91588
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2154 - auc: 0.9890 - val_loss: 0.2192 - val_auc: 0.8743
# Loading best model...
# Predicting OOF with TTA...
# 639/638 [==============================] - 47s 73ms/step
# Predicting Test with TTA...
# 537/536 [==============================] - 74s 138ms/step
# #### FOLD 2 OOF AUC without TTA = 0.916, with TTA = 0.920
# Meta only AUC: 0.6512224457429937
# The best weight is 0.14, Meta and OOF AUC with TTA: 0.921
# #########################
# #### FOLD 3
# #########################
# #### Using the following TFRecords:
# [ 0  2  3  5  6  7  8  9 10 11 12 13] [ 1  4 14]
# #### Image Size 192 with EfficientNet B0 and batch_size 128
# #### DropoutFreq 0 Count0 Size 0
# #### Using 2018+2017 external data
# #### Upsample MALIG-1 data (2020 comp)
# #### Upsample MALIG-4 data (2018 2017 comp)
# #########################
# Weight for class 0: 0.55
# Weight for class 1: 5.39
# Training...
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = nccl, num_packs = 1
# 298/298 [==============================] - ETA: 0s - loss: 0.6848 - auc: 0.6753
# Epoch 00001: val_loss improved from inf to 0.63535, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00001: val_auc improved from -inf to 0.74177, saving model to ./cv_folds/EB0-192-fold-2-auc.h5
# 298/298 [==============================] - 85s 287ms/step - loss: 0.6848 - auc: 0.6753 - val_loss: 0.6353 - val_auc: 0.7418
# Epoch 2/50
# 298/298 [==============================] - ETA: 0s - loss: 0.5007 - auc: 0.8628
# Epoch 00002: val_loss improved from 0.63535 to 0.40157, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00002: val_auc improved from 0.74177 to 0.86854, saving model to ./cv_folds/EB0-192-fold-2-auc.h5
# 298/298 [==============================] - 83s 279ms/step - loss: 0.5007 - auc: 0.8628 - val_loss: 0.4016 - val_auc: 0.8685
# Epoch 3/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4369 - auc: 0.8967
# Epoch 00003: val_loss improved from 0.40157 to 0.33085, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00003: val_auc improved from 0.86854 to 0.88708, saving model to ./cv_folds/EB0-192-fold-2-auc.h5
# 298/298 [==============================] - 83s 278ms/step - loss: 0.4369 - auc: 0.8967 - val_loss: 0.3309 - val_auc: 0.8871
# Epoch 4/50
# 298/298 [==============================] - ETA: 0s - loss: 0.4127 - auc: 0.9130
# Epoch 00004: val_loss improved from 0.33085 to 0.28722, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00004: val_auc improved from 0.88708 to 0.90207, saving model to ./cv_folds/EB0-192-fold-2-auc.h5
# 298/298 [==============================] - 83s 277ms/step - loss: 0.4127 - auc: 0.9130 - val_loss: 0.2872 - val_auc: 0.9021
# Epoch 5/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3914 - auc: 0.9244
# Epoch 00005: val_loss improved from 0.28722 to 0.25749, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00005: val_auc did not improve from 0.90207
# 298/298 [==============================] - 82s 275ms/step - loss: 0.3914 - auc: 0.9244 - val_loss: 0.2575 - val_auc: 0.8937
# Epoch 6/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3724 - auc: 0.9350
# Epoch 00006: val_loss did not improve from 0.25749
#
# Epoch 00006: val_auc did not improve from 0.90207
# 298/298 [==============================] - 81s 273ms/step - loss: 0.3724 - auc: 0.9350 - val_loss: 0.3036 - val_auc: 0.8947
# Epoch 7/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3486 - auc: 0.9458
# Epoch 00007: val_loss did not improve from 0.25749
#
# Epoch 00007: val_auc did not improve from 0.90207
# 298/298 [==============================] - 82s 274ms/step - loss: 0.3486 - auc: 0.9458 - val_loss: 0.2922 - val_auc: 0.8977
# Epoch 8/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3263 - auc: 0.9547
# Epoch 00008: val_loss did not improve from 0.25749
#
# Epoch 00008: val_auc improved from 0.90207 to 0.90539, saving model to ./cv_folds/EB0-192-fold-2-auc.h5
# 298/298 [==============================] - 82s 276ms/step - loss: 0.3263 - auc: 0.9547 - val_loss: 0.3087 - val_auc: 0.9054
# Epoch 9/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3160 - auc: 0.9589
# Epoch 00009: val_loss did not improve from 0.25749
#
# Epoch 00009: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.3160 - auc: 0.9589 - val_loss: 0.2701 - val_auc: 0.8998
# Epoch 10/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2954 - auc: 0.9663
# Epoch 00010: val_loss did not improve from 0.25749
#
# Epoch 00010: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2954 - auc: 0.9663 - val_loss: 0.2768 - val_auc: 0.8674
# Epoch 11/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2833 - auc: 0.9696
# Epoch 00011: val_loss did not improve from 0.25749
#
# Epoch 00011: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2833 - auc: 0.9696 - val_loss: 0.2734 - val_auc: 0.8795
# Epoch 12/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2741 - auc: 0.9739
# Epoch 00012: val_loss improved from 0.25749 to 0.24725, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00012: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2741 - auc: 0.9739 - val_loss: 0.2472 - val_auc: 0.8847
# Epoch 13/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2623 - auc: 0.9764
# Epoch 00013: val_loss improved from 0.24725 to 0.22948, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00013: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2623 - auc: 0.9764 - val_loss: 0.2295 - val_auc: 0.8902
# Epoch 14/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2572 - auc: 0.9780
# Epoch 00014: val_loss did not improve from 0.22948
#
# Epoch 00014: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 272ms/step - loss: 0.2572 - auc: 0.9780 - val_loss: 0.2589 - val_auc: 0.8971
# Epoch 15/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2496 - auc: 0.9802
# Epoch 00015: val_loss improved from 0.22948 to 0.21281, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00015: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2496 - auc: 0.9802 - val_loss: 0.2128 - val_auc: 0.8587
# Epoch 16/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2415 - auc: 0.9823
# Epoch 00016: val_loss did not improve from 0.21281
#
# Epoch 00016: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2415 - auc: 0.9823 - val_loss: 0.2243 - val_auc: 0.8737
# Epoch 17/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2406 - auc: 0.9830
# Epoch 00017: val_loss did not improve from 0.21281
#
# Epoch 00017: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2406 - auc: 0.9830 - val_loss: 0.2225 - val_auc: 0.8841
# Epoch 18/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2373 - auc: 0.9834
# Epoch 00018: val_loss did not improve from 0.21281
#
# Epoch 00018: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2373 - auc: 0.9834 - val_loss: 0.2235 - val_auc: 0.8579
# Epoch 19/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2365 - auc: 0.9843
# Epoch 00019: val_loss did not improve from 0.21281
#
# Epoch 00019: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2365 - auc: 0.9843 - val_loss: 0.2324 - val_auc: 0.8664
# Epoch 20/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2304 - auc: 0.9851
# Epoch 00020: val_loss did not improve from 0.21281
#
# Epoch 00020: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2304 - auc: 0.9851 - val_loss: 0.2227 - val_auc: 0.8875
# Epoch 21/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2264 - auc: 0.9859
# Epoch 00021: val_loss did not improve from 0.21281
#
# Epoch 00021: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2264 - auc: 0.9859 - val_loss: 0.2179 - val_auc: 0.8669
# Epoch 22/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2247 - auc: 0.9865
# Epoch 00022: val_loss did not improve from 0.21281
#
# Epoch 00022: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2247 - auc: 0.9865 - val_loss: 0.2170 - val_auc: 0.8746
# Epoch 23/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2238 - auc: 0.9869
# Epoch 00023: val_loss did not improve from 0.21281
#
# Epoch 00023: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2238 - auc: 0.9869 - val_loss: 0.2146 - val_auc: 0.8705
# Epoch 24/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2248 - auc: 0.9869
# Epoch 00024: val_loss improved from 0.21281 to 0.20786, saving model to ./cv_folds/EB0-192-fold-2-loss.h5
#
# Epoch 00024: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2248 - auc: 0.9869 - val_loss: 0.2079 - val_auc: 0.8594
# Epoch 25/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2220 - auc: 0.9875
# Epoch 00025: val_loss did not improve from 0.20786
#
# Epoch 00025: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2220 - auc: 0.9875 - val_loss: 0.2087 - val_auc: 0.8657
# Epoch 26/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2201 - auc: 0.9877
# Epoch 00026: val_loss did not improve from 0.20786
#
# Epoch 00026: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 272ms/step - loss: 0.2201 - auc: 0.9877 - val_loss: 0.2180 - val_auc: 0.8411
# Epoch 27/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2210 - auc: 0.9874
# Epoch 00027: val_loss did not improve from 0.20786
#
# Epoch 00027: val_auc did not improve from 0.90539
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2210 - auc: 0.9874 - val_loss: 0.2104 - val_auc: 0.8475
# Epoch 28/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2183 - auc: 0.9882
# Epoch 00028: val_loss did not improve from 0.20786
#
# Epoch 00028: val_auc did not improve from 0.90539
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2183 - auc: 0.9882 - val_loss: 0.2125 - val_auc: 0.8745
# Epoch 29/50
# ...
# 298/298 [==============================] - 83s 278ms/step - loss: 0.4079 - auc: 0.9142 - val_loss: 0.2895 - val_auc: 0.8843
# Epoch 5/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3836 - auc: 0.9286
# Epoch 00005: val_loss did not improve from 0.28955
#
# Epoch 00005: val_auc improved from 0.88428 to 0.89429, saving model to ./cv_folds/EB0-192-fold-4-auc.h5
# 298/298 [==============================] - 83s 277ms/step - loss: 0.3836 - auc: 0.9286 - val_loss: 0.3279 - val_auc: 0.8943
# Epoch 6/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3722 - auc: 0.9351
# Epoch 00006: val_loss did not improve from 0.28955
#
# Epoch 00006: val_auc did not improve from 0.89429
# 298/298 [==============================] - 82s 276ms/step - loss: 0.3722 - auc: 0.9351 - val_loss: 0.3068 - val_auc: 0.8921
# Epoch 7/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3415 - auc: 0.9478
# Epoch 00007: val_loss did not improve from 0.28955
#
# Epoch 00007: val_auc improved from 0.89429 to 0.90125, saving model to ./cv_folds/EB0-192-fold-4-auc.h5
# 298/298 [==============================] - 83s 277ms/step - loss: 0.3415 - auc: 0.9478 - val_loss: 0.3265 - val_auc: 0.9013
# Epoch 8/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3286 - auc: 0.9542
# Epoch 00008: val_loss improved from 0.28955 to 0.28323, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00008: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 277ms/step - loss: 0.3286 - auc: 0.9542 - val_loss: 0.2832 - val_auc: 0.8816
# Epoch 9/50
# 298/298 [==============================] - ETA: 0s - loss: 0.3110 - auc: 0.9606
# Epoch 00009: val_loss improved from 0.28323 to 0.23880, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00009: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.3110 - auc: 0.9606 - val_loss: 0.2388 - val_auc: 0.8662
# Epoch 10/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2888 - auc: 0.9680
# Epoch 00010: val_loss improved from 0.23880 to 0.23087, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00010: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2888 - auc: 0.9680 - val_loss: 0.2309 - val_auc: 0.8816
# Epoch 11/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2804 - auc: 0.9713
# Epoch 00011: val_loss did not improve from 0.23087
#
# Epoch 00011: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2804 - auc: 0.9713 - val_loss: 0.2424 - val_auc: 0.8800
# Epoch 12/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2693 - auc: 0.9743
# Epoch 00012: val_loss did not improve from 0.23087
#
# Epoch 00012: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2693 - auc: 0.9743 - val_loss: 0.2361 - val_auc: 0.8711
# Epoch 13/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2615 - auc: 0.9770
# Epoch 00013: val_loss did not improve from 0.23087
#
# Epoch 00013: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2615 - auc: 0.9770 - val_loss: 0.2579 - val_auc: 0.8927
# Epoch 14/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2518 - auc: 0.9793
# Epoch 00014: val_loss did not improve from 0.23087
#
# Epoch 00014: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2518 - auc: 0.9793 - val_loss: 0.2493 - val_auc: 0.8640
# Epoch 15/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2487 - auc: 0.9804
# Epoch 00015: val_loss did not improve from 0.23087
#
# Epoch 00015: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2487 - auc: 0.9804 - val_loss: 0.2449 - val_auc: 0.8851
# Epoch 16/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2415 - auc: 0.9823
# Epoch 00016: val_loss did not improve from 0.23087
#
# Epoch 00016: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2415 - auc: 0.9823 - val_loss: 0.2401 - val_auc: 0.8983
# Epoch 17/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2371 - auc: 0.9832
# Epoch 00017: val_loss did not improve from 0.23087
#
# Epoch 00017: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2371 - auc: 0.9832 - val_loss: 0.2400 - val_auc: 0.8872
# Epoch 18/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2355 - auc: 0.9840
# Epoch 00018: val_loss did not improve from 0.23087
#
# Epoch 00018: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2355 - auc: 0.9840 - val_loss: 0.2363 - val_auc: 0.8851
# Epoch 19/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2277 - auc: 0.9855
# Epoch 00019: val_loss did not improve from 0.23087
#
# Epoch 00019: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2277 - auc: 0.9855 - val_loss: 0.2379 - val_auc: 0.8778
# Epoch 20/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2319 - auc: 0.9844
# Epoch 00020: val_loss did not improve from 0.23087
#
# Epoch 00020: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2319 - auc: 0.9844 - val_loss: 0.2471 - val_auc: 0.8743
# Epoch 21/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2279 - auc: 0.9858
# Epoch 00021: val_loss did not improve from 0.23087
#
# Epoch 00021: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2279 - auc: 0.9858 - val_loss: 0.2375 - val_auc: 0.8795
# Epoch 22/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2271 - auc: 0.9858
# Epoch 00022: val_loss did not improve from 0.23087
#
# Epoch 00022: val_auc did not improve from 0.90125
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2271 - auc: 0.9858 - val_loss: 0.2379 - val_auc: 0.8817
# Epoch 23/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2207 - auc: 0.9870
# Epoch 00023: val_loss improved from 0.23087 to 0.22781, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00023: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2207 - auc: 0.9870 - val_loss: 0.2278 - val_auc: 0.8907
# Epoch 24/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2224 - auc: 0.9871
# Epoch 00024: val_loss did not improve from 0.22781
#
# Epoch 00024: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2224 - auc: 0.9871 - val_loss: 0.2323 - val_auc: 0.8714
# Epoch 25/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2203 - auc: 0.9872
# Epoch 00025: val_loss did not improve from 0.22781
#
# Epoch 00025: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2203 - auc: 0.9872 - val_loss: 0.2363 - val_auc: 0.8446
# Epoch 26/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2206 - auc: 0.9873
# Epoch 00026: val_loss improved from 0.22781 to 0.22234, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00026: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2206 - auc: 0.9873 - val_loss: 0.2223 - val_auc: 0.8670
# Epoch 27/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2172 - auc: 0.9878
# Epoch 00027: val_loss improved from 0.22234 to 0.22211, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00027: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2172 - auc: 0.9878 - val_loss: 0.2221 - val_auc: 0.8470
# Epoch 28/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2193 - auc: 0.9882
# Epoch 00028: val_loss did not improve from 0.22211
#
# Epoch 00028: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2193 - auc: 0.9882 - val_loss: 0.2240 - val_auc: 0.8688
# Epoch 29/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2177 - auc: 0.9879
# Epoch 00029: val_loss improved from 0.22211 to 0.22077, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00029: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2177 - auc: 0.9879 - val_loss: 0.2208 - val_auc: 0.8781
# Epoch 30/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2170 - auc: 0.9882
# Epoch 00030: val_loss did not improve from 0.22077
#
# Epoch 00030: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2170 - auc: 0.9882 - val_loss: 0.2217 - val_auc: 0.8644
# Epoch 31/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2132 - auc: 0.9883
# Epoch 00031: val_loss improved from 0.22077 to 0.21786, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00031: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2132 - auc: 0.9883 - val_loss: 0.2179 - val_auc: 0.8707
# Epoch 32/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2158 - auc: 0.9886
# Epoch 00032: val_loss did not improve from 0.21786
#
# Epoch 00032: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2158 - auc: 0.9886 - val_loss: 0.2190 - val_auc: 0.8754
# Epoch 33/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2132 - auc: 0.9891
# Epoch 00033: val_loss did not improve from 0.21786
#
# Epoch 00033: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2132 - auc: 0.9891 - val_loss: 0.2210 - val_auc: 0.8600
# Epoch 34/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2159 - auc: 0.9883
# Epoch 00034: val_loss did not improve from 0.21786
#
# Epoch 00034: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2159 - auc: 0.9883 - val_loss: 0.2233 - val_auc: 0.8433
# Epoch 35/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2160 - auc: 0.9886
# Epoch 00035: val_loss improved from 0.21786 to 0.21729, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00035: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2160 - auc: 0.9886 - val_loss: 0.2173 - val_auc: 0.8783
# Epoch 36/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2142 - auc: 0.9888
# Epoch 00036: val_loss did not improve from 0.21729
#
# Epoch 00036: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2142 - auc: 0.9888 - val_loss: 0.2227 - val_auc: 0.8384
# Epoch 37/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2119 - auc: 0.9893
# Epoch 00037: val_loss improved from 0.21729 to 0.21559, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00037: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2119 - auc: 0.9893 - val_loss: 0.2156 - val_auc: 0.8563
# Epoch 38/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2112 - auc: 0.9895
# Epoch 00038: val_loss did not improve from 0.21559
#
# Epoch 00038: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2112 - auc: 0.9895 - val_loss: 0.2175 - val_auc: 0.8662
# Epoch 39/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2141 - auc: 0.9890
# Epoch 00039: val_loss did not improve from 0.21559
#
# Epoch 00039: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2141 - auc: 0.9890 - val_loss: 0.2175 - val_auc: 0.8451
# Epoch 40/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2146 - auc: 0.9886
# Epoch 00040: val_loss did not improve from 0.21559
#
# Epoch 00040: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2146 - auc: 0.9886 - val_loss: 0.2213 - val_auc: 0.8257
# Epoch 41/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2159 - auc: 0.9886
# Epoch 00041: val_loss did not improve from 0.21559
#
# Epoch 00041: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2159 - auc: 0.9886 - val_loss: 0.2186 - val_auc: 0.8650
# Epoch 42/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2099 - auc: 0.9894
# Epoch 00042: val_loss improved from 0.21559 to 0.21533, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00042: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2099 - auc: 0.9894 - val_loss: 0.2153 - val_auc: 0.8312
# Epoch 43/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2125 - auc: 0.9893
# Epoch 00043: val_loss did not improve from 0.21533
#
# Epoch 00043: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2125 - auc: 0.9893 - val_loss: 0.2169 - val_auc: 0.8513
# Epoch 44/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2115 - auc: 0.9893
# Epoch 00044: val_loss improved from 0.21533 to 0.21319, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00044: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2115 - auc: 0.9893 - val_loss: 0.2132 - val_auc: 0.8527
# Epoch 45/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2112 - auc: 0.9891
# Epoch 00045: val_loss did not improve from 0.21319
#
# Epoch 00045: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2112 - auc: 0.9891 - val_loss: 0.2159 - val_auc: 0.8489
# Epoch 46/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2119 - auc: 0.9890
# Epoch 00046: val_loss improved from 0.21319 to 0.21235, saving model to ./cv_folds/EB0-192-fold-4-loss.h5
#
# Epoch 00046: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 276ms/step - loss: 0.2119 - auc: 0.9890 - val_loss: 0.2124 - val_auc: 0.8525
# Epoch 47/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2111 - auc: 0.9896
# Epoch 00047: val_loss did not improve from 0.21235
#
# Epoch 00047: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2111 - auc: 0.9896 - val_loss: 0.2165 - val_auc: 0.8650
# Epoch 48/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2137 - auc: 0.9892
# Epoch 00048: val_loss did not improve from 0.21235
#
# Epoch 00048: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 274ms/step - loss: 0.2137 - auc: 0.9892 - val_loss: 0.2129 - val_auc: 0.8494
# Epoch 49/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2127 - auc: 0.9891
# Epoch 00049: val_loss did not improve from 0.21235
#
# Epoch 00049: val_auc did not improve from 0.90125
# 298/298 [==============================] - 82s 275ms/step - loss: 0.2127 - auc: 0.9891 - val_loss: 0.2195 - val_auc: 0.8566
# Epoch 50/50
# 298/298 [==============================] - ETA: 0s - loss: 0.2108 - auc: 0.9896
# Epoch 00050: val_loss did not improve from 0.21235
#
# Epoch 00050: val_auc did not improve from 0.90125
# 298/298 [==============================] - 81s 273ms/step - loss: 0.2108 - auc: 0.9896 - val_loss: 0.2195 - val_auc: 0.8553
# Loading best model...
# Predicting OOF with TTA...
# 641/640 [==============================] - 47s 73ms/step
# Predicting Test with TTA...
# 537/536 [==============================] - 74s 138ms/step
# #### FOLD 5 OOF AUC without TTA = 0.901, with TTA = 0.913
# Meta only AUC: 0.6659808551976875
# The best weight is 0.0, Meta and OOF AUC with TTA: 0.913

# %% [markdown]
# #### Show the optimal characteristics from CV

# %%
best_epoch_val_auc_mean = np.mean(np.array(best_epoch_val_auc_ls), axis=0)
best_epoch_val_loss_mean = np.mean(np.array(best_epoch_val_loss_ls), axis=0)

print("The best epoch value for AUC over the cv is: ",best_epoch_val_auc_mean)
print("The best epoch value for loss over the cv is: ",best_epoch_val_loss_mean)
# Out:
# The best epoch value for AUC over the cv is:  11.8
# The best epoch value for loss over the cv is:  31.8

# %%
cv_val_auc_mean = np.mean(np.array(best_val_auc_ls), axis=0)
cv_val_auc_std = np.std(np.array(best_val_auc_ls), axis=0)
cv_val_loss_mean = np.mean(np.array(best_val_loss_ls), axis=0)

print(f"The mean AUC score across CV folds is {cv_val_auc_mean:.2f} and the standard deviation is {cv_val_auc_std:.2%}")
# Out:
# The mean AUC score across CV folds is 0.90 and the standard deviation is 0.88%

# %% [markdown]
# #### Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred)
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names)
folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{CV_OOF_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.907
#      image_name  target      pred  fold
# 0  ISIC_0052212       0  0.017214     0
# 1  ISIC_0080817       0  0.099019     0
# 2  ISIC_0076262       0  0.031768     0
# 3  ISIC_0078712       0  0.049442     0
# 4  ISIC_0086349       0  0.103622     0

# %% [markdown]
# #### Calculate OOF AUC with Tabular Data
# Utilising a simple prediction model on the tabular data should add additional information when blending. This can be tested with the OOF data.

# %%
best_wgt = []
best_auc = []
for best in best_meta_wgts:
    best_wgt.append(best[0])
    best_auc.append(best[1])
avg_wgt = sum(best_wgt)/len(best_wgt)
avg_auc = sum(best_auc)/len(best_auc)
print(f"Average of best meta weights = {avg_wgt:.2f}")
print(f"Overall OOF and Meta AUC with TTA = {avg_auc:.3f}")
# Out:
# Average of best meta weights = 0.16
# Overall OOF and Meta AUC with TTA = 0.915

# %% [markdown]
# ### Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.

# %% [markdown]
# ### Log values from the cross validation process

# %%
if ENV == 'LOCAL':
    log_df = pd.read_csv('./logs/experiment_log.csv')
    headers = list(log_df.columns.values)
    
if ENV == 'KAGGLE':
    headers = ['Image Size',
             'Model',
             '2018 Data',
             'Batch Size',
             'Replicas',
             'Total Batch Size',
             'TTA Loops',
             'CV Folds',
             'Mean CV AUC',
             'Std CV AUC',
             'OOF AUC with TTA',
             'OOF AUC and Meta with TTA',
             'Best average Meta weighting' , 
             'Mean CV Loss',
             'Total Epochs',
             'Early Stop',
             'Best AUC Epoch',
             'Best Loss Epoch',
             'Kaggle LB AUC',
             'Kaggle LB AUC w Meta']
    log_df = pd.DataFrame(columns = headers)

# %%
log_items = [IMG_SIZES[0],
            str(f"EFNB{EFF_NETS[0]}"),
            INC2018[0],
            BATCH_SIZES[0],
            REPLICAS,
            BATCH_SIZES[0] * REPLICAS,
            TTA,
            FOLDS,
            cv_val_auc_mean,
            cv_val_auc_std, 
            auc,
            avg_auc,
            avg_wgt,
            cv_val_loss_mean,
            EPOCHS[0],
            EARLY_STOPPING,
            best_epoch_val_auc_mean,
            best_epoch_val_loss_mean,
            0.00,
            0.00]

# %%
for n in range(len(headers)):
    print(headers[n]+":", log_items[n])
    
log_data = pd.DataFrame([log_items], columns=headers)
log_df = log_df.append(log_data)
log_df.sort_values(by=['Model','Image Size'], inplace=True)
log_df.to_csv(f'{LOG_PATH}experiment_log.csv', index=False)
log_df.head(50)
# Out:
# Image Size: 192
# Model: EFNB0
# 2018 Data: 1
# Batch Size: 64
# Replicas: 2
# Total Batch Size: 128
# TTA Loops: 25
# CV Folds: 5
# Mean CV AUC: 0.9025285959243774
# Std CV AUC: 0.008819061100865673
# OOF AUC with TTA: 0.906528510640077
# OOF AUC and Meta with TTA: 0.9148777323746178
# Best average Meta weighting: 0.156
# Mean CV Loss: 0.21264392733573914
# Total Epochs: 50
# Early Stop: 0
# Best AUC Epoch: 11.8
# Best Loss Epoch: 31.8
# Kaggle LB AUC: 0.0
# Kaggle LB AUC w Meta: 0.0
#     Image Size     Model  2018 Data  Batch Size  Replicas  Total Batch Size  \
# 0          128     EFNB0          1         256         1               256
# 1          128     EFNB0          1         128         1               128
# 2          128     EFNB0          1         128         1               128
# 3          128     EFNB0          1         128         1               128
# 4          128     EFNB0          0         256         1               256
# 5          128     EFNB0          0         256         1               256
# 6          128     EFNB0          1         128         1               128
# 7          128     EFNB0          1         128         1               128
# 8          128     EFNB0          1          64         1                64
# 9          128     EFNB0          0         256         1               256
# 10         128     EFNB0          0         128         1               128
# 11         128     EFNB0          1         128         1               128
# 12         128     EFNB0          0         256         1               256
# 13         192     EFNB0          0         128         1               128
# 0          192     EFNB0          1          64         2               128
# 14         256     EFNB0          1         128         1               128
# 15         256     EFNB0          1         128         1               128
# 16         256     EFNB0          0         128         1               128
# 17         128  EFNB0EXP          1         128         1               128
# 18         192  EFNB0EXP          1          64         2               128
# 19         128     EFNB1          0         128         1               128
# 20         192     EFNB1          1         128         1               128
# 21         192     EFNB1          0         128         1               128
# 22         256     EFNB1          1          64         1                64
# 23         256     EFNB1          0          64         1                64
# 24         256  EFNB1EXP          1          32         2                64
# 25         256     EFNB2          1          64         1                64
# 26         256     EFNB2          1          64         1                64
# 27         256     EFNB2          1          64         1                64
# 28         256     EFNB2          1          64         1                64
# 29         256     EFNB2          0          64         1                64
# 30         256     EFNB2          1          64         8               512
# 31         384     EFNB2          0         128         1               128
# 32         512     EFNB2          0          64         8               512
# 33         256  EFNB2EXP          1          64         1                64
# 34         256  EFNB2EXP          1          64         1                64
# 35         192     EFNB3          0          32         1                32
# 36         256     EFNB3          0          16         1                16
# 37         384     EFNB3          0           8         1                 8
# 38         384     EFNB3          0         128         8              1024
# 39         384     EFNB3          1          16         1                16
# 40         384  EFNB3EXP          1           8         2                16
# 41         256     EFNB4          0          32         1                32
# 42         384     EFNB4          0          16         1                16
# 43         384     EFNB4          1         128         8              1024
# 44         384     EFNB4          0         128         8              1024
# 45         512     EFNB4          0          64         8               512
# 46         512     EFNB5          0          32         8               256
# 47         512     EFNB6          0           8         8                64
#
#     TTA Loops  CV Folds  Mean CV AUC  Std CV AUC  OOF AUC with TTA  \
# 0          25         5     0.862810    0.015301          0.899221
# 1          25         5     0.893108    0.009577          0.896964
# 2          25         5     0.894638    0.016115          0.899087
# 3          25         5     0.891281    0.012457          0.897615
# 4          25         5     0.858138    0.017181          0.892846
# 5          25         5     0.862265    0.021282          0.891697
# 6          25         3     0.868520    0.007854          0.891658
# 7          25         5     0.860609    0.011030          0.888065
# 8          25         5     0.892140    0.012269          0.881596
# 9          25         5     0.862378    0.000000          0.892097
# 10         50         5     0.869673    0.020289          0.893746
# 11         25         5     0.870027    0.019537          0.893820
# 12         25         5     0.862576    0.017381          0.895973
# 13         25         5     0.869117    0.000000          0.899562
# 0          25         5     0.902529    0.008819          0.906529
# 14         25         5     0.905725    0.013085          0.913515
# 15         25         5     0.880362    0.021434          0.911405
# 16         25         5     0.881442    0.000000          0.905685
# 17         25         5     0.912633    0.002593          0.912759
# 18         25         5     0.902832    0.004064          0.910726
# 19         25         5     0.857287    0.015800          0.890922
# 20         25         5     0.885721    0.022526          0.902849
# 21         25         5     0.872257    0.024584          0.898725
# 22         25         5     0.894408    0.012953          0.912732
# 23         25         5     0.886249    0.010748          0.907220
# 24         25         5     0.955029    0.018500          0.962169
# 25         25         5     0.956336    0.007296          0.961748
# 26         25         5     0.903819    0.017790          0.913861
# 27         25         5     0.888146    0.020124          0.909704
# 28         25         5     0.889753    0.014140          0.915927
# 29         25         5     0.884384    0.009332          0.909386
# 30         25         5     0.910257    0.010415          0.921064
# 31         25         5     0.828881    0.038663          0.842111
# 32         25         5     0.886565    0.012560          0.879694
# 33         25         5     0.938519    0.000000          0.946079
# 34         25         5     0.925376    0.021439          0.945415
# 35         25         5     0.867541    0.012185          0.898843
# 36         25         5     0.871538    0.011266          0.904422
# 37         25         5     0.876217    0.016871          0.898717
# 38         25         5     0.874759    0.019894          0.883070
# 39         25         5     0.898124    0.013586          0.910307
# 40         25         5     0.905761    0.005587          0.912990
# 41         25         5     0.889665    0.013592          0.914790
# 42         25         5     0.893494    0.025733          0.909297
# 43         25         5     0.896319    0.008178          0.902081
# 44         25         5     0.890323    0.009456          0.905070
# 45         25         5     0.885838    0.021590          0.876753
# 46         25         5     0.903188    0.015500          0.887710
# 47         25         3     0.889957    0.010651          0.890717
#
#     OOF AUC and Meta with TTA  Best average Meta weighting  Mean CV Loss  \
# 0                    0.899624                     0.028000      0.164090
# 1                    0.899278                     0.186000      0.471082
# 2                    0.899203                     0.074000      0.234308
# 3                    0.898825                     0.260000      0.430066
# 4                    0.893437                     0.058000      0.165035
# 5                    0.893361                     0.050000      0.164463
# 6                    0.891997                     0.013333      0.164465
# 7                    0.889803                     0.030000      0.164579
# 8                    0.883801                     0.106000      0.251114
# 9                    0.000000                     0.000000      0.164595
# 10                   0.000000                     0.000000      0.164480
# 11                   0.000000                     0.000000      0.163722
# 12                   0.000000                     0.000000      0.164683
# 13                   0.000000                     0.000000      0.163387
# 0                    0.914878                     0.156000      0.212644
# 14                   0.914208                     0.172000      0.365035
# 15                   0.000000                     0.000000      0.161010
# 16                   0.000000                     0.000000      0.162524
# 17                   0.918679                     0.290000      0.472791
# 18                   0.911090                     0.000000      0.245847
# 19                   0.000000                     0.000000      0.164851
# 20                   0.000000                     0.000000      0.162546
# 21                   0.000000                     0.000000      0.163616
# 22                   0.000000                     0.000000      0.160833
# 23                   0.000000                     0.000000      0.162028
# 24                   0.962298                     0.164000      0.208217
# 25                   0.962125                     0.038000      0.200851
# 26                   0.914280                     0.078000      0.207408
# 27                   0.910367                     0.050000      0.161091
# 28                   0.000000                     0.000000      0.161170
# 29                   0.000000                     0.000000      0.161911
# 30                   0.924116                     0.062000      0.179513
# 31                   0.000000                     0.000000      0.165045
# 32                   0.000000                     0.000000      0.161943
# 33                   0.946689                     0.180000      0.219144
# 34                   0.945607                     0.110000      0.213297
# 35                   0.000000                     0.000000      0.163563
# 36                   0.000000                     0.000000      0.162711
# 37                   0.000000                     0.000000      0.163969
# 38                   0.000000                     0.000000      0.161846
# 39                   0.000000                     0.000000      0.161235
# 40                   0.913461                     0.000000      0.237265
# 41                   0.000000                     0.000000      0.161829
# 42                   0.000000                     0.000000      0.161644
# 43                   0.000000                     0.000000      0.159346
# 44                   0.000000                     0.000000      0.161675
# 45                   0.000000                     0.000000      0.162841
# 46                   0.000000                     0.000000      0.161710
# 47                   0.000000                     0.000000      0.162821
#
#     Total Epochs  Early Stop  Best AUC Epoch  Best Loss Epoch  Kaggle LB AUC  \
# 0             12           0        8.800000         9.400000         0.0000
# 1             12           0       10.400000        10.400000         0.0000
# 2             12           0        9.200000         8.000000         0.0000
# 3             12           0       10.000000         9.000000         0.0000
# 4             12           0        7.400000         9.400000         0.0000
# 5             12           0        9.200000         9.400000         0.0000
# 6             20           0       10.000000        15.000000         0.0000
# 7             12           0        8.200000         9.800000         0.0000
# 8             15           0       12.000000         6.140000            NaN
# 9             15           1        9.400000        10.200000         0.0000
# 10            30           0       12.600000        11.400000         0.0000
# 11            15           0        8.800000        10.000000         0.0000
# 12            20           0        9.400000        12.000000         0.0000
# 13            15           1        9.800000        10.200000         0.0000
# 0             50           0       11.800000        31.800000         0.0000
# 14            12           0        8.600000         9.400000         0.0000
# 15            15           0        7.800000        12.000000         0.0000
# 16            15           1        9.400000        11.200000         0.0000
# 17            12           0        9.000000         9.666667         0.0000
# 18            20           0       10.666667        15.166667         0.0000
# 19            15           1       12.200000        11.200000         0.0000
# 20            15           0       10.200000         9.800000         0.0000
# 21            15           1       10.600000        10.800000         0.0000
# 22            15           0        8.800000        13.400000         0.0000
# 23            15           1        9.600000        10.200000         0.0000
# 24            60           0       43.600000        41.800000         0.0000
# 25            17           0       15.600000        10.400000         0.0000
# 26            12           0        7.200000         7.800000         0.0000
# 27            20           0       10.600000        10.600000         0.0000
# 28            15           0        9.200000        11.000000         0.9377
# 29            15           1        9.600000         9.400000         0.9296
# 30            20           0       14.000000         5.800000         0.9413
# 31            15           1       11.200000        11.400000         0.0000
# 32            15           1        8.200000         8.600000         0.0000
# 33            20           0       14.000000        17.000000         0.0000
# 34            15           0       11.800000        13.800000         0.0000
# 35            20           1        8.800000        10.400000         0.0000
# 36            15           1       11.600000        11.600000         0.0000
# 37            15           1        8.800000        10.200000         0.9235
# 38            20           0       13.000000        13.800000         0.9181
# 39            15           0       10.000000        11.600000         0.9467
# 40            20           0       14.666667        14.500000         0.0000
# 41            15           1       12.400000        12.800000         0.9262
# 42            15           1        9.800000        12.000000         0.0000
# 43            20           0       14.400000        11.200000         0.9350
# 44            20           0       17.000000        16.200000         0.9357
# 45            15           1        7.400000         7.600000         0.0000
# 46            15           1        5.800000         5.600000         0.9383
# 47            15           1       11.666667        10.666667         0.9358
#
#     Kaggle LB AUC w Meta
# 0                 0.0000
# 1                 0.0000
# 2                 0.0000
# 3                 0.0000
# 4                 0.0000
# 5                 0.0000
# 6                 0.0000
# 7                 0.0000
# 8                    NaN
# 9                 0.0000
# 10                0.0000
# 11                0.0000
# 12                0.0000
# 13                0.0000
# 0                 0.0000
# 14                0.0000
# 15                0.0000
# 16                0.0000
# 17                0.0000
# 18                0.0000
# 19                0.0000
# 20                0.0000
# 21                0.0000
# 22                0.0000
# 23                0.0000
# 24                0.0000
# 25                0.9428
# 26                0.9361
# 27                0.9407
# 28                0.0000
# 29                0.0000
# 30                0.9438
# 31                0.0000
# 32                0.0000
# 33                0.0000
# 34                0.0000
# 35                0.0000
# 36                0.0000
# 37                0.0000
# 38                0.0000
# 39                0.0000
# 40                0.0000
# 41                0.0000
# 42                0.0000
# 43                0.0000
# 44                0.0000
# 45                0.0000
# 46                0.0000
# 47                0.0000

# %% [markdown]
# ### Prepare Kaggle File

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}FCV-submission.csv', index=False)
submission.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.020446
# 723   ISIC_0052349  0.021361
# 1560  ISIC_0058510  0.020117
# 2438  ISIC_0073313  0.022537
# 2750  ISIC_0073502  0.026426

# %%
submission_meta = pd.DataFrame(dict(image_name=image_names, target=preds_meta_ls[:,0]))
submission_meta = submission_meta.sort_values('image_name') 
submission_meta.to_csv(f'{CV_TEST_PREDS_PATH}EB{EFF_NETS[0]}-{IMG_SIZES[0]}-{FOLDS}FCV-META-submission.csv', index=False)
submission_meta.head()
# Out:
#         image_name    target
# 4953  ISIC_0052060  0.051463
# 723   ISIC_0052349  0.021647
# 1560  ISIC_0058510  0.024753
# 2438  ISIC_0073313  0.025038
# 2750  ISIC_0073502  0.033092

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
plt.hist(submission_meta.target,bins=100)
plt.show()
